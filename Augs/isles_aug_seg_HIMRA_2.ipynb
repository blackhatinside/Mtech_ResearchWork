# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import keras.backend as K
from scipy.ndimage import gaussian_filter, map_coordinates
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# 2025-02-13 21:02:16.163375: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-13 21:02:16.204928: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-13 21:02:16.798360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Constants and Paths (unchanged)
BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
AUG_INPUT_PATH = os.path.join(AUG_PATH, "input")
AUG_MASK_PATH = os.path.join(AUG_PATH, "mask")
OUTPUT_DIRECTORY = "./output/ISLESfolder"
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)

# %%
IMG_SIZE = 112
BATCH_SIZE = 4
LEARNINGRATE = 0.001
EPOCHS = 100
EARLYSTOPPING = 40
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
def dice_coeff(y_true, y_pred):
	y_true_f = K.flatten(y_true)
	y_pred_f = K.flatten(y_pred)
	intersection = K.sum(y_true_f * y_pred_f)
	return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def iou(y_true, y_pred):
	intersection = K.sum(y_true * y_pred)
	union = K.sum(y_true + y_pred)
	return (intersection + 0.1) / (union - intersection + 0.1)

def dice_loss(y_true, y_pred):
	return tf.keras.losses.binary_crossentropy(y_true, y_pred) + (1 - dice_coeff(y_true, y_pred))

def single_dice_loss(y_true, y_pred):
    return 1.0 - dice_score(y_true, y_pred)

def binary_crossentropy_loss(y_true, y_pred):
    return tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

def binary_focal_loss(gamma=2., alpha=0.25):
    def focal_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        alpha_t = y_true * alpha + (K.ones_like(y_true) - y_true) * (1 - alpha)
        p_t = y_true * y_pred + (K.ones_like(y_true) - y_true) * (1 - y_pred)
        focal_loss = - alpha_t * K.pow((K.ones_like(y_true) - p_t), gamma) * K.log(p_t)
        return K.mean(focal_loss)
    return focal_loss

# %%
def load_and_preprocess(file_path, is_mask=False):
	img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
	img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
	if not is_mask:
		img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
	else:
		img = img / 255.0
	return img

# %%
# HIMRA Augmentation Functions
def biomechanical_deformation(image, mask):
	"""
	Applies biomechanically realistic deformation using stiffness-weighted elastic deformation.
	"""
	# Get lesion centroid
	lesion_pixels = np.where(mask > 0)
	if len(lesion_pixels[0]) == 0:
		return image  # No deformation if no lesion

	centroid = np.array([np.mean(lesion_pixels[0]), np.mean(lesion_pixels[1])])

	# Simulate tissue stiffness (higher stiffness near lesion)
	stiffness_map = np.exp(-0.01 * ((np.indices(image.shape)[0] - centroid[0])**2 +
								   (np.indices(image.shape)[1] - centroid[1])**2))

	# Create deformation field
	dx = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=3)
	dy = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=3)

	# Apply deformation
	y, x = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
	indices = np.reshape(y + dy, (-1, 1)), np.reshape(x + dx, (-1, 1))
	deformed_image = map_coordinates(image, indices, order=1, mode='reflect').reshape(image.shape)
	deformed_mask = map_coordinates(mask, indices, order=0, mode='constant').reshape(mask.shape)

	return deformed_image, deformed_mask

def simulate_hemodynamics(image, mask):
	"""
	Simulates hemodynamic effects using synthetic ADC map variations.
	"""
	# Create synthetic ADC map
	adc_map = np.random.normal(1.0, 0.2, size=image.shape)
	adc_map = gaussian_filter(adc_map, sigma=3)

	# Apply hemodynamic effect (stronger near lesions)
	if np.sum(mask) > 0:  # Only apply if lesion exists
		adc_map[mask > 0] *= np.random.uniform(0.7, 1.3)

	return image * adc_map, mask

def attention_occlusion(image, mask, attention_map=None):
	"""
	Applies attention-guided occlusion to simulate adversarial conditions.
	"""
	if attention_map is None:
		attention_map = gaussian_filter(np.random.rand(*image.shape), sigma=2)

	# Create occlusion mask
	occlusion_mask = (attention_map > np.percentile(attention_map, 75)).astype(np.float32)
	occlusion_mask = gaussian_filter(occlusion_mask, sigma=2)

	# Apply occlusion
	occluded_image = image * (1 - occlusion_mask)
	return occluded_image, mask

# %%
class HIMRADataGenerator(tf.keras.utils.Sequence):
	def __init__(self, list_IDs, aug_ids=None, batch_size=BATCH_SIZE, shuffle=True):
		self.batch_size = batch_size
		self.list_IDs = list_IDs
		self.aug_ids = aug_ids if aug_ids is not None else []
		self.all_ids = list_IDs + self.aug_ids
		self.shuffle = shuffle
		self.on_epoch_end()

	def __len__(self):
		return int(np.floor(len(self.all_ids) / self.batch_size))

	def __getitem__(self, index):
		indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
		batch_ids = [self.all_ids[k] for k in indexes]
		return self.__data_generation(batch_ids)

	def on_epoch_end(self):
		self.indexes = np.arange(len(self.all_ids))
		if self.shuffle:
			np.random.shuffle(self.indexes)

	def __data_generation(self, batch_ids):
		X, y = [], []
		for case_id in batch_ids:
			is_aug = case_id in self.aug_ids
			input_dir = AUG_INPUT_PATH if is_aug else INPUT_PATH
			mask_dir = AUG_MASK_PATH if is_aug else MASK_PATH

			input_files = sorted([f for f in os.listdir(input_dir)
								if f.startswith(f'slice_{case_id}') and f.endswith('.png')])

			for f in input_files:
				img_path = os.path.join(input_dir, f)
				mask_path = os.path.join(mask_dir, f)

				img = load_and_preprocess(img_path)
				mask = load_and_preprocess(mask_path, is_mask=True)

				# Apply HIMRA Augmentation
				if is_aug:
					img, mask = biomechanical_deformation(img, mask)
					img, mask = simulate_hemodynamics(img, mask)
					img, mask = attention_occlusion(img, mask)

				X.append(img)
				y.append(mask)

		return np.expand_dims(np.array(X), -1), np.array(y)

# %%
def conv_block(inp, filters):
	x = Conv2D(filters, 3, padding='same', use_bias=False)(inp)
	x = BatchNormalization()(x)
	return Activation('relu')(x)

def attention_gate(x, g, filters):
	g1 = Conv2D(filters, 1)(g)
	x1 = Conv2D(filters, 1)(x)
	out = Activation('relu')(add([g1, x1]))
	out = Conv2D(1, 1, activation='sigmoid')(out)
	return multiply([x, out])

# %%
def create_model():
	inputs = Input((IMG_SIZE, IMG_SIZE, 1))

	# Encoder with reduced filters
	x = conv_block(inputs, 32)
	skip1 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 64)
	skip2 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 128)
	skip3 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 256)
	skip4 = x
	x = MaxPooling2D()(x)

	# Bridge
	x = conv_block(x, 512)

	# Decoder with attention
	x = Conv2DTranspose(256, 3, strides=2, padding='same')(x)
	x = attention_gate(skip4, x, 256)
	x = concatenate([x, skip4])
	x = conv_block(x, 256)

	x = Conv2DTranspose(128, 3, strides=2, padding='same')(x)
	x = attention_gate(skip3, x, 128)
	x = concatenate([x, skip3])
	x = conv_block(x, 128)

	x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
	x = attention_gate(skip2, x, 64)
	x = concatenate([x, skip2])
	x = conv_block(x, 64)

	x = Conv2DTranspose(32, 3, strides=2, padding='same')(x)
	x = attention_gate(skip1, x, 32)
	x = concatenate([x, skip1])
	x = conv_block(x, 32)

	outputs = Conv2D(1, 1, activation='sigmoid')(x)

	model = Model(inputs, outputs)

	model.compile(
		optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNINGRATE),
		loss=dice_loss,
		metrics=['accuracy', dice_coeff, iou]
	)

	return model

# %%
def get_case_ids(path):
	files = sorted([f for f in os.listdir(path) if f.endswith('.png')])
	return sorted(list({f.split('_')[1] for f in files}))

# %%
def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_augmented_samples(train_gen, num_samples=3):
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

case_ids = get_case_ids(INPUT_PATH)
aug_case_ids = get_case_ids(AUG_INPUT_PATH) if os.path.exists(AUG_INPUT_PATH) else []

train_ids, test_ids = train_test_split(case_ids, test_size=0.2, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

print(f"Train: {len(train_ids)}, Val: {len(val_ids)}, Test: {len(test_ids)}, Aug: {len(aug_case_ids)}")

train_gen = HIMRADataGenerator(train_ids, aug_ids=aug_case_ids)
val_gen = HIMRADataGenerator(val_ids, shuffle=False)
test_gen = HIMRADataGenerator(test_ids, shuffle=False)

model = create_model()

print("Model Summary: ", model.summary())

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_dice_coeff', mode='max',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=EARLYSTOPPING, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    workers=4,
    use_multiprocessing=True
)

results = model.evaluate(test_gen)

print("\nGenerating Training Metrics Visualization...")
plot_training_metrics(history)
# Out:
# Train: 160, Val: 40, Test: 50, Aug: 63
# 2025-02-13 21:02:17.956580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14400 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:19:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  288         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   18432       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73728       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 512)    1179648     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  1179904    ['activation_4[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 256)  65792       ['conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  65792       ['activation_3[0][0]']
#
#  add (Add)                      (None, 14, 14, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 256)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 1)    257         ['activation_5[0][0]']
#
#  multiply (Multiply)            (None, 14, 14, 256)  0           ['activation_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 512)  0           ['multiply[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 256)  1179648     ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_6[0][0]']
#  spose)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  16512       ['conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  16512       ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 1)    129         ['activation_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 128)  0           ['activation_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 256)  0           ['multiply_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  294912      ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_8[0][0]']
#  spose)
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   4160        ['conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   4160        ['activation_1[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 1)    65          ['activation_9[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 64)   0           ['activation_1[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 128)  0           ['multiply_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   73728       ['concatenate_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_10[0][0]']
#  spose)                         )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  1056        ['conv2d_transpose_3[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 32  1056        ['activation[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_17[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 32  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  33          ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['activation[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 64  0           ['multiply_3[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 32  18432       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_20[0][0]']
#  rmalization)                   )
#
#  activation_12 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  33          ['activation_12[0][0]']
#
# ==================================================================================================
# Total params: 4,882,373
# Trainable params: 4,879,429
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Model Summary:  None
# Epoch 1/100
# 2025-02-13 21:02:19.191244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-13 21:02:24.573778: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-02-13 21:02:31.306905: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x3c160170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-13 21:02:31.306931: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2025-02-13 21:02:31.310914: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-13 21:02:31.445292: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-02-13 21:02:32.192374: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:02:32.384101: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.63GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:02:32.384169: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.63GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:02:33.693148: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.50GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  2/55 [>.............................] - ETA: 15:20 - loss: 1.6212 - accuracy: 0.5687 - dice_coeff: 0.0064 - iou: 0.0032
# 2025-02-13 21:03:16.839596: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:03:17.103303: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:03:17.103358: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:03:18.473999: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.49GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  3/55 [>.............................] - ETA: 18:04 - loss: 1.5817 - accuracy: 0.6844 - dice_coeff: 0.0088 - iou: 0.0044
# 2025-02-13 21:03:40.845060: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 21:03:40.845124: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 55/55 [==============================] - ETA: 0s - loss: 1.3248 - accuracy: 0.9653 - dice_coeff: 0.0187 - iou: 0.0095
# 2025-02-13 21:14:05.996358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_dice_coeff improved from -inf to 0.01107, saving model to best_model.h5
# 55/55 [==============================] - 729s 13s/step - loss: 1.3248 - accuracy: 0.9653 - dice_coeff: 0.0187 - iou: 0.0095 - val_loss: 1.2695 - val_accuracy: 0.9961 - val_dice_coeff: 0.0111 - val_iou: 0.0056 - lr: 0.0010
# Epoch 2/100
# 11/55 [=====>........................] - ETA: 3:16 - loss: 1.1608 - accuracy: 0.9930 - dice_coeff: 0.0388 - iou: 0.0199
# 2025-02-13 21:15:23.799293: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 55/55 [==============================] - ETA: 0s - loss: 1.1010 - accuracy: 0.9928 - dice_coeff: 0.0499 - iou: 0.0258
# Epoch 2: val_dice_coeff did not improve from 0.01107
# 55/55 [==============================] - 301s 6s/step - loss: 1.1010 - accuracy: 0.9928 - dice_coeff: 0.0499 - iou: 0.0258 - val_loss: 1.0957 - val_accuracy: 0.9961 - val_dice_coeff: 0.0104 - val_iou: 0.0052 - lr: 0.0010
# Epoch 3/100
# 55/55 [==============================] - ETA: 0s - loss: 0.9620 - accuracy: 0.9922 - dice_coeff: 0.1088 - iou: 0.0584
# Epoch 3: val_dice_coeff did not improve from 0.01107
# 55/55 [==============================] - 101s 2s/step - loss: 0.9620 - accuracy: 0.9922 - dice_coeff: 0.1088 - iou: 0.0584 - val_loss: 1.0518 - val_accuracy: 0.9961 - val_dice_coeff: 0.0066 - val_iou: 0.0033 - lr: 0.0010
# Epoch 4/100
# 55/55 [==============================] - ETA: 0s - loss: 0.8148 - accuracy: 0.9938 - dice_coeff: 0.2187 - iou: 0.1271
# Epoch 4: val_dice_coeff did not improve from 0.01107
# 55/55 [==============================] - 145s 3s/step - loss: 0.8148 - accuracy: 0.9938 - dice_coeff: 0.2187 - iou: 0.1271 - val_loss: 1.0310 - val_accuracy: 0.9961 - val_dice_coeff: 0.0036 - val_iou: 0.0018 - lr: 0.0010
# Epoch 5/100
# 55/55 [==============================] - ETA: 0s - loss: 0.6396 - accuracy: 0.9951 - dice_coeff: 0.3794 - iou: 0.2428
# Epoch 5: val_dice_coeff improved from 0.01107 to 0.15124, saving model to best_model.h5
# 55/55 [==============================] - 112s 2s/step - loss: 0.6396 - accuracy: 0.9951 - dice_coeff: 0.3794 - iou: 0.2428 - val_loss: 0.8717 - val_accuracy: 0.9968 - val_dice_coeff: 0.1512 - val_iou: 0.0844 - lr: 0.0010
# Epoch 6/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5245 - accuracy: 0.9958 - dice_coeff: 0.4913 - iou: 0.3384
# Epoch 6: val_dice_coeff improved from 0.15124 to 0.35267, saving model to best_model.h5
# 55/55 [==============================] - 102s 2s/step - loss: 0.5245 - accuracy: 0.9958 - dice_coeff: 0.4913 - iou: 0.3384 - val_loss: 0.6737 - val_accuracy: 0.9965 - val_dice_coeff: 0.3527 - val_iou: 0.2259 - lr: 0.0010
# Epoch 7/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4447 - accuracy: 0.9963 - dice_coeff: 0.5722 - iou: 0.4155
# Epoch 7: val_dice_coeff improved from 0.35267 to 0.38358, saving model to best_model.h5
# 55/55 [==============================] - 115s 2s/step - loss: 0.4447 - accuracy: 0.9963 - dice_coeff: 0.5722 - iou: 0.4155 - val_loss: 0.6401 - val_accuracy: 0.9973 - val_dice_coeff: 0.3836 - val_iou: 0.2490 - lr: 0.0010
# Epoch 8/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.9960 - dice_coeff: 0.5995 - iou: 0.4367
# Epoch 8: val_dice_coeff did not improve from 0.38358
# 55/55 [==============================] - 106s 2s/step - loss: 0.4224 - accuracy: 0.9960 - dice_coeff: 0.5995 - iou: 0.4367 - val_loss: 0.9342 - val_accuracy: 0.9804 - val_dice_coeff: 0.1775 - val_iou: 0.1021 - lr: 0.0010
# Epoch 9/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.9962 - dice_coeff: 0.5763 - iou: 0.4211
# Epoch 9: val_dice_coeff improved from 0.38358 to 0.40430, saving model to best_model.h5
# 55/55 [==============================] - 116s 2s/step - loss: 0.4461 - accuracy: 0.9962 - dice_coeff: 0.5763 - iou: 0.4211 - val_loss: 0.6326 - val_accuracy: 0.9949 - val_dice_coeff: 0.4043 - val_iou: 0.2673 - lr: 0.0010
# Epoch 10/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.9966 - dice_coeff: 0.6512 - iou: 0.4952
# Epoch 10: val_dice_coeff improved from 0.40430 to 0.54227, saving model to best_model.h5
# 55/55 [==============================] - 120s 2s/step - loss: 0.3711 - accuracy: 0.9966 - dice_coeff: 0.6512 - iou: 0.4952 - val_loss: 0.4818 - val_accuracy: 0.9976 - val_dice_coeff: 0.5423 - val_iou: 0.3899 - lr: 0.0010
# Epoch 11/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.9966 - dice_coeff: 0.6503 - iou: 0.4950
# Epoch 11: val_dice_coeff improved from 0.54227 to 0.61545, saving model to best_model.h5
# 55/55 [==============================] - 86s 2s/step - loss: 0.3726 - accuracy: 0.9966 - dice_coeff: 0.6503 - iou: 0.4950 - val_loss: 0.4029 - val_accuracy: 0.9980 - val_dice_coeff: 0.6155 - val_iou: 0.4686 - lr: 0.0010
# Epoch 12/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.9964 - dice_coeff: 0.6127 - iou: 0.4576
# Epoch 12: val_dice_coeff did not improve from 0.61545
# 55/55 [==============================] - 64s 1s/step - loss: 0.4099 - accuracy: 0.9964 - dice_coeff: 0.6127 - iou: 0.4576 - val_loss: 0.5181 - val_accuracy: 0.9976 - val_dice_coeff: 0.5035 - val_iou: 0.3552 - lr: 0.0010
# Epoch 13/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3757 - accuracy: 0.9966 - dice_coeff: 0.6484 - iou: 0.4895
# Epoch 13: val_dice_coeff did not improve from 0.61545
# 55/55 [==============================] - 72s 1s/step - loss: 0.3757 - accuracy: 0.9966 - dice_coeff: 0.6484 - iou: 0.4895 - val_loss: 0.4223 - val_accuracy: 0.9973 - val_dice_coeff: 0.6030 - val_iou: 0.4524 - lr: 0.0010
# Epoch 14/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.9966 - dice_coeff: 0.6521 - iou: 0.4941
# Epoch 14: val_dice_coeff improved from 0.61545 to 0.67223, saving model to best_model.h5
# 55/55 [==============================] - 53s 947ms/step - loss: 0.3692 - accuracy: 0.9966 - dice_coeff: 0.6521 - iou: 0.4941 - val_loss: 0.3445 - val_accuracy: 0.9980 - val_dice_coeff: 0.6722 - val_iou: 0.5213 - lr: 0.0010
# Epoch 15/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.9966 - dice_coeff: 0.6227 - iou: 0.4709
# Epoch 15: val_dice_coeff improved from 0.67223 to 0.68068, saving model to best_model.h5
# 55/55 [==============================] - 35s 625ms/step - loss: 0.3978 - accuracy: 0.9966 - dice_coeff: 0.6227 - iou: 0.4709 - val_loss: 0.3367 - val_accuracy: 0.9981 - val_dice_coeff: 0.6807 - val_iou: 0.5310 - lr: 0.0010
# Epoch 16/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.9967 - dice_coeff: 0.6713 - iou: 0.5129
# Epoch 16: val_dice_coeff did not improve from 0.68068
# 55/55 [==============================] - 52s 914ms/step - loss: 0.3492 - accuracy: 0.9967 - dice_coeff: 0.6713 - iou: 0.5129 - val_loss: 0.4794 - val_accuracy: 0.9966 - val_dice_coeff: 0.5510 - val_iou: 0.3999 - lr: 0.0010
# Epoch 17/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.9968 - dice_coeff: 0.6852 - iou: 0.5313
# Epoch 17: val_dice_coeff did not improve from 0.68068
# 55/55 [==============================] - 33s 572ms/step - loss: 0.3347 - accuracy: 0.9968 - dice_coeff: 0.6852 - iou: 0.5313 - val_loss: 0.4008 - val_accuracy: 0.9975 - val_dice_coeff: 0.6233 - val_iou: 0.4737 - lr: 0.0010
# Epoch 18/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.9967 - dice_coeff: 0.6741 - iou: 0.5209
# Epoch 18: val_dice_coeff improved from 0.68068 to 0.68904, saving model to best_model.h5
# 55/55 [==============================] - 38s 642ms/step - loss: 0.3464 - accuracy: 0.9967 - dice_coeff: 0.6741 - iou: 0.5209 - val_loss: 0.3267 - val_accuracy: 0.9981 - val_dice_coeff: 0.6890 - val_iou: 0.5437 - lr: 0.0010
# Epoch 19/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.9968 - dice_coeff: 0.6936 - iou: 0.5434
# Epoch 19: val_dice_coeff improved from 0.68904 to 0.70114, saving model to best_model.h5
# 55/55 [==============================] - 37s 630ms/step - loss: 0.3271 - accuracy: 0.9968 - dice_coeff: 0.6936 - iou: 0.5434 - val_loss: 0.3123 - val_accuracy: 0.9982 - val_dice_coeff: 0.7011 - val_iou: 0.5560 - lr: 0.0010
# Epoch 20/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.9970 - dice_coeff: 0.6949 - iou: 0.5417
# Epoch 20: val_dice_coeff did not improve from 0.70114
# 55/55 [==============================] - 48s 853ms/step - loss: 0.3274 - accuracy: 0.9970 - dice_coeff: 0.6949 - iou: 0.5417 - val_loss: 0.6499 - val_accuracy: 0.9926 - val_dice_coeff: 0.4085 - val_iou: 0.2714 - lr: 0.0010
# Epoch 21/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.9969 - dice_coeff: 0.7027 - iou: 0.5505
# Epoch 21: val_dice_coeff did not improve from 0.70114
# 55/55 [==============================] - 52s 940ms/step - loss: 0.3171 - accuracy: 0.9969 - dice_coeff: 0.7027 - iou: 0.5505 - val_loss: 0.3330 - val_accuracy: 0.9981 - val_dice_coeff: 0.6827 - val_iou: 0.5354 - lr: 0.0010
# Epoch 22/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.9969 - dice_coeff: 0.6842 - iou: 0.5343
# Epoch 22: val_dice_coeff did not improve from 0.70114
# 55/55 [==============================] - 84s 2s/step - loss: 0.3360 - accuracy: 0.9969 - dice_coeff: 0.6842 - iou: 0.5343 - val_loss: 0.3301 - val_accuracy: 0.9982 - val_dice_coeff: 0.6879 - val_iou: 0.5493 - lr: 0.0010
# Epoch 23/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.9969 - dice_coeff: 0.6935 - iou: 0.5431
# Epoch 23: val_dice_coeff improved from 0.70114 to 0.73985, saving model to best_model.h5
# 55/55 [==============================] - 36s 627ms/step - loss: 0.3277 - accuracy: 0.9969 - dice_coeff: 0.6935 - iou: 0.5431 - val_loss: 0.2723 - val_accuracy: 0.9983 - val_dice_coeff: 0.7398 - val_iou: 0.5998 - lr: 0.0010
# Epoch 24/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.9970 - dice_coeff: 0.7154 - iou: 0.5640
# Epoch 24: val_dice_coeff did not improve from 0.73985
# 55/55 [==============================] - 36s 630ms/step - loss: 0.3096 - accuracy: 0.9970 - dice_coeff: 0.7154 - iou: 0.5640 - val_loss: 0.2759 - val_accuracy: 0.9983 - val_dice_coeff: 0.7365 - val_iou: 0.5958 - lr: 0.0010
# Epoch 25/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9970 - dice_coeff: 0.7156 - iou: 0.5664
# Epoch 25: val_dice_coeff improved from 0.73985 to 0.74269, saving model to best_model.h5
# 55/55 [==============================] - 51s 918ms/step - loss: 0.3005 - accuracy: 0.9970 - dice_coeff: 0.7156 - iou: 0.5664 - val_loss: 0.2690 - val_accuracy: 0.9983 - val_dice_coeff: 0.7427 - val_iou: 0.6027 - lr: 0.0010
# Epoch 26/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.9971 - dice_coeff: 0.7094 - iou: 0.5616
# Epoch 26: val_dice_coeff did not improve from 0.74269
# 55/55 [==============================] - 51s 883ms/step - loss: 0.3101 - accuracy: 0.9971 - dice_coeff: 0.7094 - iou: 0.5616 - val_loss: 0.4457 - val_accuracy: 0.9970 - val_dice_coeff: 0.5834 - val_iou: 0.4338 - lr: 0.0010
# Epoch 27/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3042 - accuracy: 0.9970 - dice_coeff: 0.7136 - iou: 0.5657
# Epoch 27: val_dice_coeff improved from 0.74269 to 0.74646, saving model to best_model.h5
# 55/55 [==============================] - 33s 576ms/step - loss: 0.3042 - accuracy: 0.9970 - dice_coeff: 0.7136 - iou: 0.5657 - val_loss: 0.2673 - val_accuracy: 0.9984 - val_dice_coeff: 0.7465 - val_iou: 0.6088 - lr: 0.0010
# Epoch 28/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3085 - accuracy: 0.9970 - dice_coeff: 0.7136 - iou: 0.5650
# Epoch 28: val_dice_coeff did not improve from 0.74646
# 55/55 [==============================] - 54s 934ms/step - loss: 0.3085 - accuracy: 0.9970 - dice_coeff: 0.7136 - iou: 0.5650 - val_loss: 0.3423 - val_accuracy: 0.9979 - val_dice_coeff: 0.6667 - val_iou: 0.5195 - lr: 0.0010
# Epoch 29/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.9970 - dice_coeff: 0.7152 - iou: 0.5661
# Epoch 29: val_dice_coeff did not improve from 0.74646
# 55/55 [==============================] - 49s 863ms/step - loss: 0.3054 - accuracy: 0.9970 - dice_coeff: 0.7152 - iou: 0.5661 - val_loss: 0.2902 - val_accuracy: 0.9982 - val_dice_coeff: 0.7236 - val_iou: 0.5806 - lr: 0.0010
# Epoch 30/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9971 - dice_coeff: 0.7398 - iou: 0.5956
# Epoch 30: val_dice_coeff did not improve from 0.74646
# 55/55 [==============================] - 36s 641ms/step - loss: 0.2844 - accuracy: 0.9971 - dice_coeff: 0.7398 - iou: 0.5956 - val_loss: 0.3085 - val_accuracy: 0.9982 - val_dice_coeff: 0.7081 - val_iou: 0.5678 - lr: 0.0010
# Epoch 31/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.9971 - dice_coeff: 0.7043 - iou: 0.5582
# Epoch 31: val_dice_coeff did not improve from 0.74646
# 55/55 [==============================] - 36s 641ms/step - loss: 0.3152 - accuracy: 0.9971 - dice_coeff: 0.7043 - iou: 0.5582 - val_loss: 0.2828 - val_accuracy: 0.9983 - val_dice_coeff: 0.7314 - val_iou: 0.5895 - lr: 0.0010
# Epoch 32/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9971 - dice_coeff: 0.7164 - iou: 0.5683
# Epoch 32: val_dice_coeff did not improve from 0.74646
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 [==============================] - 33s 582ms/step - loss: 0.3053 - accuracy: 0.9971 - dice_coeff: 0.7164 - iou: 0.5683 - val_loss: 0.3959 - val_accuracy: 0.9974 - val_dice_coeff: 0.6322 - val_iou: 0.4857 - lr: 0.0010
# Epoch 33/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.9973 - dice_coeff: 0.7405 - iou: 0.5960
# Epoch 33: val_dice_coeff improved from 0.74646 to 0.74702, saving model to best_model.h5
# 55/55 [==============================] - 74s 1s/step - loss: 0.2797 - accuracy: 0.9973 - dice_coeff: 0.7405 - iou: 0.5960 - val_loss: 0.2670 - val_accuracy: 0.9984 - val_dice_coeff: 0.7470 - val_iou: 0.6107 - lr: 5.0000e-04
# Epoch 34/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.9972 - dice_coeff: 0.7249 - iou: 0.5770
# Epoch 34: val_dice_coeff did not improve from 0.74702
# 55/55 [==============================] - 51s 915ms/step - loss: 0.2909 - accuracy: 0.9972 - dice_coeff: 0.7249 - iou: 0.5770 - val_loss: 0.5083 - val_accuracy: 0.9962 - val_dice_coeff: 0.5280 - val_iou: 0.3786 - lr: 5.0000e-04
# Epoch 35/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.9972 - dice_coeff: 0.7417 - iou: 0.5985
# Epoch 35: val_dice_coeff improved from 0.74702 to 0.77127, saving model to best_model.h5
# 55/55 [==============================] - 91s 2s/step - loss: 0.2798 - accuracy: 0.9972 - dice_coeff: 0.7417 - iou: 0.5985 - val_loss: 0.2388 - val_accuracy: 0.9985 - val_dice_coeff: 0.7713 - val_iou: 0.6387 - lr: 5.0000e-04
# Epoch 36/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9973 - dice_coeff: 0.7451 - iou: 0.6039
# Epoch 36: val_dice_coeff did not improve from 0.77127
# 55/55 [==============================] - 46s 812ms/step - loss: 0.2730 - accuracy: 0.9973 - dice_coeff: 0.7451 - iou: 0.6039 - val_loss: 0.2539 - val_accuracy: 0.9985 - val_dice_coeff: 0.7574 - val_iou: 0.6208 - lr: 5.0000e-04
# Epoch 37/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.9973 - dice_coeff: 0.7535 - iou: 0.6152
# Epoch 37: val_dice_coeff improved from 0.77127 to 0.77697, saving model to best_model.h5
# 55/55 [==============================] - 36s 635ms/step - loss: 0.2662 - accuracy: 0.9973 - dice_coeff: 0.7535 - iou: 0.6152 - val_loss: 0.2340 - val_accuracy: 0.9985 - val_dice_coeff: 0.7770 - val_iou: 0.6455 - lr: 5.0000e-04
# Epoch 38/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.9973 - dice_coeff: 0.7494 - iou: 0.6077
# Epoch 38: val_dice_coeff improved from 0.77697 to 0.78027, saving model to best_model.h5
# 55/55 [==============================] - 36s 634ms/step - loss: 0.2673 - accuracy: 0.9973 - dice_coeff: 0.7494 - iou: 0.6077 - val_loss: 0.2300 - val_accuracy: 0.9986 - val_dice_coeff: 0.7803 - val_iou: 0.6490 - lr: 5.0000e-04
# Epoch 39/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9974 - dice_coeff: 0.7526 - iou: 0.6137
# Epoch 39: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 37s 625ms/step - loss: 0.2677 - accuracy: 0.9974 - dice_coeff: 0.7526 - iou: 0.6137 - val_loss: 0.2465 - val_accuracy: 0.9985 - val_dice_coeff: 0.7644 - val_iou: 0.6288 - lr: 5.0000e-04
# Epoch 40/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9974 - dice_coeff: 0.7511 - iou: 0.6095
# Epoch 40: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 37s 632ms/step - loss: 0.2636 - accuracy: 0.9974 - dice_coeff: 0.7511 - iou: 0.6095 - val_loss: 0.2456 - val_accuracy: 0.9986 - val_dice_coeff: 0.7653 - val_iou: 0.6336 - lr: 5.0000e-04
# Epoch 41/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9973 - dice_coeff: 0.7389 - iou: 0.5992
# Epoch 41: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 36s 632ms/step - loss: 0.2792 - accuracy: 0.9973 - dice_coeff: 0.7389 - iou: 0.5992 - val_loss: 0.3042 - val_accuracy: 0.9983 - val_dice_coeff: 0.7125 - val_iou: 0.5721 - lr: 5.0000e-04
# Epoch 42/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.9974 - dice_coeff: 0.7555 - iou: 0.6159
# Epoch 42: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 36s 649ms/step - loss: 0.2653 - accuracy: 0.9974 - dice_coeff: 0.7555 - iou: 0.6159 - val_loss: 0.2863 - val_accuracy: 0.9984 - val_dice_coeff: 0.7302 - val_iou: 0.5955 - lr: 5.0000e-04
# Epoch 43/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.9974 - dice_coeff: 0.7598 - iou: 0.6202
# Epoch 43: val_dice_coeff did not improve from 0.78027
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 [==============================] - 36s 639ms/step - loss: 0.2595 - accuracy: 0.9974 - dice_coeff: 0.7598 - iou: 0.6202 - val_loss: 0.2381 - val_accuracy: 0.9986 - val_dice_coeff: 0.7735 - val_iou: 0.6434 - lr: 5.0000e-04
# Epoch 44/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9975 - dice_coeff: 0.7656 - iou: 0.6312
# Epoch 44: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 43s 762ms/step - loss: 0.2513 - accuracy: 0.9975 - dice_coeff: 0.7656 - iou: 0.6312 - val_loss: 0.2421 - val_accuracy: 0.9986 - val_dice_coeff: 0.7695 - val_iou: 0.6384 - lr: 2.5000e-04
# Epoch 45/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9975 - dice_coeff: 0.7606 - iou: 0.6242
# Epoch 45: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 56s 1000ms/step - loss: 0.2568 - accuracy: 0.9975 - dice_coeff: 0.7606 - iou: 0.6242 - val_loss: 0.2390 - val_accuracy: 0.9986 - val_dice_coeff: 0.7710 - val_iou: 0.6407 - lr: 2.5000e-04
# Epoch 46/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9975 - dice_coeff: 0.7723 - iou: 0.6375
# Epoch 46: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 36s 648ms/step - loss: 0.2433 - accuracy: 0.9975 - dice_coeff: 0.7723 - iou: 0.6375 - val_loss: 0.2322 - val_accuracy: 0.9986 - val_dice_coeff: 0.7777 - val_iou: 0.6484 - lr: 2.5000e-04
# Epoch 47/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9975 - dice_coeff: 0.7713 - iou: 0.6340
# Epoch 47: val_dice_coeff did not improve from 0.78027
# 55/55 [==============================] - 37s 636ms/step - loss: 0.2458 - accuracy: 0.9975 - dice_coeff: 0.7713 - iou: 0.6340 - val_loss: 0.2312 - val_accuracy: 0.9986 - val_dice_coeff: 0.7796 - val_iou: 0.6507 - lr: 2.5000e-04
# Epoch 48/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.9976 - dice_coeff: 0.7727 - iou: 0.6382
# Epoch 48: val_dice_coeff improved from 0.78027 to 0.78376, saving model to best_model.h5
# 55/55 [==============================] - 37s 647ms/step - loss: 0.2465 - accuracy: 0.9976 - dice_coeff: 0.7727 - iou: 0.6382 - val_loss: 0.2266 - val_accuracy: 0.9986 - val_dice_coeff: 0.7838 - val_iou: 0.6562 - lr: 2.5000e-04
# Epoch 49/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9975 - dice_coeff: 0.7710 - iou: 0.6342
# Epoch 49: val_dice_coeff did not improve from 0.78376
# 55/55 [==============================] - 58s 1s/step - loss: 0.2447 - accuracy: 0.9975 - dice_coeff: 0.7710 - iou: 0.6342 - val_loss: 0.2332 - val_accuracy: 0.9986 - val_dice_coeff: 0.7780 - val_iou: 0.6487 - lr: 2.5000e-04
# Epoch 50/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.9975 - dice_coeff: 0.7673 - iou: 0.6315
# Epoch 50: val_dice_coeff improved from 0.78376 to 0.78597, saving model to best_model.h5
# 55/55 [==============================] - 38s 648ms/step - loss: 0.2496 - accuracy: 0.9975 - dice_coeff: 0.7673 - iou: 0.6315 - val_loss: 0.2244 - val_accuracy: 0.9986 - val_dice_coeff: 0.7860 - val_iou: 0.6591 - lr: 2.5000e-04
# Epoch 51/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.9976 - dice_coeff: 0.7678 - iou: 0.6287
# Epoch 51: val_dice_coeff did not improve from 0.78597
# 55/55 [==============================] - 37s 651ms/step - loss: 0.2489 - accuracy: 0.9976 - dice_coeff: 0.7678 - iou: 0.6287 - val_loss: 0.2351 - val_accuracy: 0.9986 - val_dice_coeff: 0.7756 - val_iou: 0.6452 - lr: 2.5000e-04
# Epoch 52/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9976 - dice_coeff: 0.7719 - iou: 0.6372
# Epoch 52: val_dice_coeff did not improve from 0.78597
# 55/55 [==============================] - 33s 560ms/step - loss: 0.2460 - accuracy: 0.9976 - dice_coeff: 0.7719 - iou: 0.6372 - val_loss: 0.2350 - val_accuracy: 0.9986 - val_dice_coeff: 0.7756 - val_iou: 0.6470 - lr: 2.5000e-04
# Epoch 53/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9976 - dice_coeff: 0.7802 - iou: 0.6459
# Epoch 53: val_dice_coeff did not improve from 0.78597
# 55/55 [==============================] - 63s 1s/step - loss: 0.2389 - accuracy: 0.9976 - dice_coeff: 0.7802 - iou: 0.6459 - val_loss: 0.2278 - val_accuracy: 0.9987 - val_dice_coeff: 0.7830 - val_iou: 0.6563 - lr: 2.5000e-04
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9976 - dice_coeff: 0.7786 - iou: 0.6451
# Epoch 54: val_dice_coeff did not improve from 0.78597
# 55/55 [==============================] - 56s 1s/step - loss: 0.2373 - accuracy: 0.9976 - dice_coeff: 0.7786 - iou: 0.6451 - val_loss: 0.2306 - val_accuracy: 0.9986 - val_dice_coeff: 0.7798 - val_iou: 0.6519 - lr: 2.5000e-04
# Epoch 55/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9976 - dice_coeff: 0.7852 - iou: 0.6529
# Epoch 55: val_dice_coeff did not improve from 0.78597
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 [==============================] - 37s 636ms/step - loss: 0.2336 - accuracy: 0.9976 - dice_coeff: 0.7852 - iou: 0.6529 - val_loss: 0.2323 - val_accuracy: 0.9986 - val_dice_coeff: 0.7791 - val_iou: 0.6525 - lr: 2.5000e-04
# Epoch 56/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2351 - accuracy: 0.9976 - dice_coeff: 0.7814 - iou: 0.6470
# Epoch 56: val_dice_coeff improved from 0.78597 to 0.78808, saving model to best_model.h5
# 55/55 [==============================] - 49s 862ms/step - loss: 0.2351 - accuracy: 0.9976 - dice_coeff: 0.7814 - iou: 0.6470 - val_loss: 0.2223 - val_accuracy: 0.9987 - val_dice_coeff: 0.7881 - val_iou: 0.6630 - lr: 1.2500e-04
# Epoch 57/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9977 - dice_coeff: 0.7768 - iou: 0.6440
# Epoch 57: val_dice_coeff did not improve from 0.78808
# 55/55 [==============================] - 33s 581ms/step - loss: 0.2414 - accuracy: 0.9977 - dice_coeff: 0.7768 - iou: 0.6440 - val_loss: 0.2270 - val_accuracy: 0.9987 - val_dice_coeff: 0.7838 - val_iou: 0.6575 - lr: 1.2500e-04
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9976 - dice_coeff: 0.7833 - iou: 0.6498
# Epoch 58: val_dice_coeff did not improve from 0.78808
# 55/55 [==============================] - 51s 905ms/step - loss: 0.2336 - accuracy: 0.9976 - dice_coeff: 0.7833 - iou: 0.6498 - val_loss: 0.2323 - val_accuracy: 0.9986 - val_dice_coeff: 0.7781 - val_iou: 0.6508 - lr: 1.2500e-04
# Epoch 59/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9977 - dice_coeff: 0.7898 - iou: 0.6605
# Epoch 59: val_dice_coeff did not improve from 0.78808
# 55/55 [==============================] - 36s 638ms/step - loss: 0.2291 - accuracy: 0.9977 - dice_coeff: 0.7898 - iou: 0.6605 - val_loss: 0.2327 - val_accuracy: 0.9986 - val_dice_coeff: 0.7778 - val_iou: 0.6506 - lr: 1.2500e-04
# Epoch 60/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9977 - dice_coeff: 0.7874 - iou: 0.6561
# Epoch 60: val_dice_coeff did not improve from 0.78808
# 55/55 [==============================] - 47s 838ms/step - loss: 0.2309 - accuracy: 0.9977 - dice_coeff: 0.7874 - iou: 0.6561 - val_loss: 0.2312 - val_accuracy: 0.9986 - val_dice_coeff: 0.7791 - val_iou: 0.6510 - lr: 1.2500e-04
# Epoch 61/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9977 - dice_coeff: 0.7917 - iou: 0.6608
# Epoch 61: val_dice_coeff did not improve from 0.78808
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# ...
# Epoch 65/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9977 - dice_coeff: 0.7984 - iou: 0.6728
# Epoch 65: val_dice_coeff improved from 0.78808 to 0.78845, saving model to best_model.h5
# 55/55 [==============================] - 56s 992ms/step - loss: 0.2186 - accuracy: 0.9977 - dice_coeff: 0.7984 - iou: 0.6728 - val_loss: 0.2222 - val_accuracy: 0.9987 - val_dice_coeff: 0.7884 - val_iou: 0.6638 - lr: 6.2500e-05
# Epoch 66/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9977 - dice_coeff: 0.7997 - iou: 0.6726
# Epoch 66: val_dice_coeff did not improve from 0.78845
# 55/55 [==============================] - 48s 857ms/step - loss: 0.2208 - accuracy: 0.9977 - dice_coeff: 0.7997 - iou: 0.6726 - val_loss: 0.2236 - val_accuracy: 0.9987 - val_dice_coeff: 0.7867 - val_iou: 0.6606 - lr: 6.2500e-05
# Epoch 67/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9977 - dice_coeff: 0.7806 - iou: 0.6484
# Epoch 67: val_dice_coeff improved from 0.78845 to 0.79126, saving model to best_model.h5
# 55/55 [==============================] - 38s 661ms/step - loss: 0.2320 - accuracy: 0.9977 - dice_coeff: 0.7806 - iou: 0.6484 - val_loss: 0.2188 - val_accuracy: 0.9987 - val_dice_coeff: 0.7913 - val_iou: 0.6665 - lr: 6.2500e-05
# Epoch 68/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9977 - dice_coeff: 0.7913 - iou: 0.6600
# Epoch 68: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 631ms/step - loss: 0.2257 - accuracy: 0.9977 - dice_coeff: 0.7913 - iou: 0.6600 - val_loss: 0.2233 - val_accuracy: 0.9987 - val_dice_coeff: 0.7870 - val_iou: 0.6617 - lr: 6.2500e-05
# Epoch 69/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9978 - dice_coeff: 0.7971 - iou: 0.6692
# Epoch 69: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 33s 569ms/step - loss: 0.2172 - accuracy: 0.9978 - dice_coeff: 0.7971 - iou: 0.6692 - val_loss: 0.2288 - val_accuracy: 0.9986 - val_dice_coeff: 0.7813 - val_iou: 0.6540 - lr: 6.2500e-05
# Epoch 70/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9977 - dice_coeff: 0.7943 - iou: 0.6657
# Epoch 70: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 34s 585ms/step - loss: 0.2238 - accuracy: 0.9977 - dice_coeff: 0.7943 - iou: 0.6657 - val_loss: 0.2215 - val_accuracy: 0.9987 - val_dice_coeff: 0.7886 - val_iou: 0.6633 - lr: 6.2500e-05
# Epoch 71/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9978 - dice_coeff: 0.7895 - iou: 0.6590
# Epoch 71: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 34s 590ms/step - loss: 0.2256 - accuracy: 0.9978 - dice_coeff: 0.7895 - iou: 0.6590 - val_loss: 0.2209 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6651 - lr: 6.2500e-05
# Epoch 72/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9977 - dice_coeff: 0.7965 - iou: 0.6687
# Epoch 72: val_dice_coeff did not improve from 0.79126
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 55/55 [==============================] - 38s 652ms/step - loss: 0.2210 - accuracy: 0.9977 - dice_coeff: 0.7965 - iou: 0.6687 - val_loss: 0.2212 - val_accuracy: 0.9987 - val_dice_coeff: 0.7890 - val_iou: 0.6637 - lr: 6.2500e-05
# Epoch 73/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9977 - dice_coeff: 0.7953 - iou: 0.6666
# Epoch 73: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 32s 554ms/step - loss: 0.2210 - accuracy: 0.9977 - dice_coeff: 0.7953 - iou: 0.6666 - val_loss: 0.2226 - val_accuracy: 0.9987 - val_dice_coeff: 0.7877 - val_iou: 0.6622 - lr: 3.1250e-05
# Epoch 74/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9978 - dice_coeff: 0.7953 - iou: 0.6686
# Epoch 74: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 644ms/step - loss: 0.2205 - accuracy: 0.9978 - dice_coeff: 0.7953 - iou: 0.6686 - val_loss: 0.2267 - val_accuracy: 0.9987 - val_dice_coeff: 0.7836 - val_iou: 0.6572 - lr: 3.1250e-05
# Epoch 75/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9978 - dice_coeff: 0.7955 - iou: 0.6682
# Epoch 75: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 36s 644ms/step - loss: 0.2214 - accuracy: 0.9978 - dice_coeff: 0.7955 - iou: 0.6682 - val_loss: 0.2214 - val_accuracy: 0.9987 - val_dice_coeff: 0.7888 - val_iou: 0.6635 - lr: 3.1250e-05
# Epoch 76/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9978 - dice_coeff: 0.7989 - iou: 0.6709
# Epoch 76: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 650ms/step - loss: 0.2169 - accuracy: 0.9978 - dice_coeff: 0.7989 - iou: 0.6709 - val_loss: 0.2220 - val_accuracy: 0.9987 - val_dice_coeff: 0.7884 - val_iou: 0.6633 - lr: 3.1250e-05
# Epoch 77/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9978 - dice_coeff: 0.7948 - iou: 0.6658
# Epoch 77: val_dice_coeff did not improve from 0.79126
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 55/55 [==============================] - 33s 567ms/step - loss: 0.2218 - accuracy: 0.9978 - dice_coeff: 0.7948 - iou: 0.6658 - val_loss: 0.2206 - val_accuracy: 0.9987 - val_dice_coeff: 0.7896 - val_iou: 0.6645 - lr: 3.1250e-05
# Epoch 78/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9978 - dice_coeff: 0.7948 - iou: 0.6650
# Epoch 78: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 44s 760ms/step - loss: 0.2235 - accuracy: 0.9978 - dice_coeff: 0.7948 - iou: 0.6650 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7894 - val_iou: 0.6645 - lr: 1.5625e-05
# Epoch 79/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9978 - dice_coeff: 0.7936 - iou: 0.6650
# Epoch 79: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 38s 657ms/step - loss: 0.2200 - accuracy: 0.9978 - dice_coeff: 0.7936 - iou: 0.6650 - val_loss: 0.2210 - val_accuracy: 0.9987 - val_dice_coeff: 0.7893 - val_iou: 0.6645 - lr: 1.5625e-05
# Epoch 80/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9978 - dice_coeff: 0.7939 - iou: 0.6654
# Epoch 80: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 641ms/step - loss: 0.2186 - accuracy: 0.9978 - dice_coeff: 0.7939 - iou: 0.6654 - val_loss: 0.2201 - val_accuracy: 0.9987 - val_dice_coeff: 0.7901 - val_iou: 0.6654 - lr: 1.5625e-05
# Epoch 81/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9978 - dice_coeff: 0.7983 - iou: 0.6698
# Epoch 81: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 36s 640ms/step - loss: 0.2186 - accuracy: 0.9978 - dice_coeff: 0.7983 - iou: 0.6698 - val_loss: 0.2204 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_iou: 0.6652 - lr: 1.5625e-05
# Epoch 82/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9978 - dice_coeff: 0.7908 - iou: 0.6616
# Epoch 82: val_dice_coeff did not improve from 0.79126
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 55/55 [==============================] - 36s 635ms/step - loss: 0.2247 - accuracy: 0.9978 - dice_coeff: 0.7908 - iou: 0.6616 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7894 - val_iou: 0.6645 - lr: 1.5625e-05
# Epoch 83/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7975 - iou: 0.6682
# Epoch 83: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 32s 564ms/step - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7975 - iou: 0.6682 - val_loss: 0.2206 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6647 - lr: 7.8125e-06
# Epoch 84/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9978 - dice_coeff: 0.7959 - iou: 0.6668
# Epoch 84: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 649ms/step - loss: 0.2190 - accuracy: 0.9978 - dice_coeff: 0.7959 - iou: 0.6668 - val_loss: 0.2209 - val_accuracy: 0.9987 - val_dice_coeff: 0.7892 - val_iou: 0.6642 - lr: 7.8125e-06
# Epoch 85/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9978 - dice_coeff: 0.7893 - iou: 0.6585
# Epoch 85: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 633ms/step - loss: 0.2232 - accuracy: 0.9978 - dice_coeff: 0.7893 - iou: 0.6585 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6647 - lr: 7.8125e-06
# Epoch 86/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9978 - dice_coeff: 0.8006 - iou: 0.6728
# Epoch 86: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 638ms/step - loss: 0.2160 - accuracy: 0.9978 - dice_coeff: 0.8006 - iou: 0.6728 - val_loss: 0.2210 - val_accuracy: 0.9987 - val_dice_coeff: 0.7892 - val_iou: 0.6642 - lr: 7.8125e-06
# Epoch 87/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9978 - dice_coeff: 0.7930 - iou: 0.6632
# Epoch 87: val_dice_coeff did not improve from 0.79126
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 55/55 [==============================] - 33s 570ms/step - loss: 0.2194 - accuracy: 0.9978 - dice_coeff: 0.7930 - iou: 0.6632 - val_loss: 0.2205 - val_accuracy: 0.9987 - val_dice_coeff: 0.7896 - val_iou: 0.6648 - lr: 7.8125e-06
# Epoch 88/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9978 - dice_coeff: 0.8053 - iou: 0.6812
# Epoch 88: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 38s 646ms/step - loss: 0.2135 - accuracy: 0.9978 - dice_coeff: 0.8053 - iou: 0.6812 - val_loss: 0.2203 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_iou: 0.6651 - lr: 3.9063e-06
# Epoch 89/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9978 - dice_coeff: 0.8032 - iou: 0.6774
# Epoch 89: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 641ms/step - loss: 0.2158 - accuracy: 0.9978 - dice_coeff: 0.8032 - iou: 0.6774 - val_loss: 0.2204 - val_accuracy: 0.9987 - val_dice_coeff: 0.7897 - val_iou: 0.6651 - lr: 3.9063e-06
# Epoch 90/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9978 - dice_coeff: 0.8030 - iou: 0.6760
# Epoch 90: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 643ms/step - loss: 0.2133 - accuracy: 0.9978 - dice_coeff: 0.8030 - iou: 0.6760 - val_loss: 0.2206 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6647 - lr: 3.9063e-06
# Epoch 91/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9978 - dice_coeff: 0.7941 - iou: 0.6655
# Epoch 91: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 34s 572ms/step - loss: 0.2225 - accuracy: 0.9978 - dice_coeff: 0.7941 - iou: 0.6655 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6647 - lr: 3.9063e-06
# Epoch 92/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2132 - accuracy: 0.9978 - dice_coeff: 0.8047 - iou: 0.6798
# Epoch 92: val_dice_coeff did not improve from 0.79126
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 55/55 [==============================] - 33s 591ms/step - loss: 0.2132 - accuracy: 0.9978 - dice_coeff: 0.8047 - iou: 0.6798 - val_loss: 0.2204 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_iou: 0.6652 - lr: 3.9063e-06
# Epoch 93/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9978 - dice_coeff: 0.8021 - iou: 0.6771
# Epoch 93: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 52s 913ms/step - loss: 0.2168 - accuracy: 0.9978 - dice_coeff: 0.8021 - iou: 0.6771 - val_loss: 0.2206 - val_accuracy: 0.9987 - val_dice_coeff: 0.7896 - val_iou: 0.6648 - lr: 1.9531e-06
# Epoch 94/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2207 - accuracy: 0.9978 - dice_coeff: 0.7959 - iou: 0.6667
# Epoch 94: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 33s 577ms/step - loss: 0.2207 - accuracy: 0.9978 - dice_coeff: 0.7959 - iou: 0.6667 - val_loss: 0.2205 - val_accuracy: 0.9987 - val_dice_coeff: 0.7897 - val_iou: 0.6649 - lr: 1.9531e-06
# Epoch 95/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2196 - accuracy: 0.9978 - dice_coeff: 0.7947 - iou: 0.6650
# Epoch 95: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 34s 585ms/step - loss: 0.2196 - accuracy: 0.9978 - dice_coeff: 0.7947 - iou: 0.6650 - val_loss: 0.2203 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_iou: 0.6651 - lr: 1.9531e-06
# Epoch 96/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2145 - accuracy: 0.9978 - dice_coeff: 0.7995 - iou: 0.6713
# Epoch 96: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 658ms/step - loss: 0.2145 - accuracy: 0.9978 - dice_coeff: 0.7995 - iou: 0.6713 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7895 - val_iou: 0.6646 - lr: 1.9531e-06
# Epoch 97/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9978 - dice_coeff: 0.7989 - iou: 0.6709
# Epoch 97: val_dice_coeff did not improve from 0.79126
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 55/55 [==============================] - 37s 630ms/step - loss: 0.2175 - accuracy: 0.9978 - dice_coeff: 0.7989 - iou: 0.6709 - val_loss: 0.2204 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_iou: 0.6650 - lr: 1.9531e-06
# Epoch 98/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9978 - dice_coeff: 0.8022 - iou: 0.6757
# Epoch 98: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 48s 848ms/step - loss: 0.2159 - accuracy: 0.9978 - dice_coeff: 0.8022 - iou: 0.6757 - val_loss: 0.2206 - val_accuracy: 0.9987 - val_dice_coeff: 0.7896 - val_iou: 0.6648 - lr: 9.7656e-07
# Epoch 99/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9978 - dice_coeff: 0.7980 - iou: 0.6696
# Epoch 99: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 36s 632ms/step - loss: 0.2189 - accuracy: 0.9978 - dice_coeff: 0.7980 - iou: 0.6696 - val_loss: 0.2207 - val_accuracy: 0.9987 - val_dice_coeff: 0.7894 - val_iou: 0.6646 - lr: 9.7656e-07
# Epoch 100/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9978 - dice_coeff: 0.7976 - iou: 0.6697
# Epoch 100: val_dice_coeff did not improve from 0.79126
# 55/55 [==============================] - 37s 644ms/step - loss: 0.2165 - accuracy: 0.9978 - dice_coeff: 0.7976 - iou: 0.6697 - val_loss: 0.2208 - val_accuracy: 0.9987 - val_dice_coeff: 0.7893 - val_iou: 0.6644 - lr: 9.7656e-07
# 2025-02-13 22:39:07.310048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 13s 1s/step - loss: 0.3163 - accuracy: 0.9985 - dice_coeff: 0.7014 - iou: 0.5523
#
# Generating Training Metrics Visualization...

# %%
print("\nTest Results:")
print(f"Loss: {results[0]:.4f}")
print(f"Accuracy: {results[1]:.4f}")
print(f"Dice Score: {results[2]:.4f}")
print(f"IoU: {results[3]:.4f}")
# Out:
# Test Results:
# Loss: 0.3163
# Accuracy: 0.9985
# Dice Score: 0.7014
# IoU: 0.5523

# %%
print("Generating Augmentation Samples Visualization...")
visualize_augmented_samples(train_gen)
# Out:
# Generating Augmentation Samples Visualization...

# %%
def numpy_dice_coeff(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)

def numpy_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f)
    return (intersection + 0.1) / (union - intersection + 0.1)

def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
print("\nGenerating Segmentation Results Visualization...")
visualize_segmentation_results(model, test_gen)
# Out:
# Generating Segmentation Results Visualization...
# 10/10 [==============================] - 2s 87ms/step

# %%
print(f"\nAll visualizations have been saved to: {OUTPUT_DIRECTORY}")
# Out:
# All visualizations have been saved to: ./output/ISLESfolder

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0009_0038.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0009_0038.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 1s 600ms/step
# Dice Score: 0.9462
# IoU Score: 0.8972

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0013_0045.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0013_0045.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Dice Score: 0.9391
# IoU Score: 0.8849

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0015_0041.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0015_0041.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Dice Score: 0.9674
# IoU Score: 0.9367

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0024_0039.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0024_0039.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Dice Score: 0.8728
# IoU Score: 0.7739

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0031_0036.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0031_0036.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Dice Score: 0.8694
# IoU Score: 0.7688
