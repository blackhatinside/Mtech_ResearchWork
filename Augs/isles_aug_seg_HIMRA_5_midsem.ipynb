# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import keras.backend as K
from scipy import ndimage
from scipy.ndimage import gaussian_filter, map_coordinates
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# 2025-02-18 09:51:05.402898: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-18 09:51:05.444891: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-18 09:51:06.048680: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Constants and Paths (unchanged)
BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
AUG_INPUT_PATH = os.path.join(AUG_PATH, "input")
AUG_MASK_PATH = os.path.join(AUG_PATH, "mask")
OUTPUT_DIRECTORY = "./output/ISLESfolder"
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)

# %%
IMG_SIZE = 112
BATCH_SIZE = 4
LEARNINGRATE = 0.001
EPOCHS = 150
EARLYSTOPPING = 60
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
def dice_coeff(y_true, y_pred):
	y_true_f = K.flatten(y_true)
	y_pred_f = K.flatten(y_pred)
	intersection = K.sum(y_true_f * y_pred_f)
	return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def iou(y_true, y_pred):
	intersection = K.sum(y_true * y_pred)
	union = K.sum(y_true + y_pred)
	return (intersection + 0.1) / (union - intersection + 0.1)

def dice_loss(y_true, y_pred):
	return tf.keras.losses.binary_crossentropy(y_true, y_pred) + (1 - dice_coeff(y_true, y_pred))

def single_dice_loss(y_true, y_pred):
    return 1.0 - dice_score(y_true, y_pred)

def binary_crossentropy_loss(y_true, y_pred):
    return tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

def binary_focal_loss(gamma=2., alpha=0.25):
    def focal_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        alpha_t = y_true * alpha + (K.ones_like(y_true) - y_true) * (1 - alpha)
        p_t = y_true * y_pred + (K.ones_like(y_true) - y_true) * (1 - y_pred)
        focal_loss = - alpha_t * K.pow((K.ones_like(y_true) - p_t), gamma) * K.log(p_t)
        return K.mean(focal_loss)
    return focal_loss

# %%
def load_and_preprocess(file_path, is_mask=False):
	img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
	img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
	if not is_mask:
		img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
	else:
		img = img / 255.0
	return img

# %%
# HIMRA Augmentation Functions
def grow_small_lesion(image, mask, target_size=45):
	"""Grow small lesions to approach 50 pixels while staying within brain boundaries"""
	brain_mask = (image != -1)
	current_size = np.sum(mask > 0)
	if current_size == 0 or current_size >= 25: # upto 25 pixel lesions only
		return image, mask
		
	iterations = 0
	grown_mask = mask.copy()
	grown_image = image.copy()
	
	while np.sum(grown_mask > 0) < target_size and iterations < 10:
		kernel = np.ones((3,3), np.uint8)
		dilated = ndimage.binary_dilation(grown_mask, kernel)
		# Only grow within brain boundaries
		dilated = dilated & brain_mask
		new_size = np.sum(dilated > 0)
		
		if new_size > 12:
			break
			
		# Update both mask and image
		grown_mask = dilated
		# Adjust image intensity in grown regions
		new_lesion_area = dilated & ~(mask > 0)
		grown_image[new_lesion_area] = np.mean(image[mask > 0])
		
		iterations += 1
	
	return grown_image, grown_mask.astype(mask.dtype)

def biomechanical_deformation(image, mask, lesion_class):
	"""
	Applies biomechanically realistic deformation using stiffness-weighted elastic deformation.
	"""
	if lesion_class == 1:  # Less than 50 pixels
		image, mask = grow_small_lesion(image, mask)
	
	lesion_pixels = np.where(mask > 0) # Store all (x, y) coordinates of lesion pixels
	if len(lesion_pixels[0]) == 0:
		return image, mask
	
	scales = {1: 15, 2: 12, 3: 9, 4: 7, 5: 5}
	deform_scale = scales[lesion_class]
	
	centroid = np.array([np.mean(lesion_pixels[0]), np.mean(lesion_pixels[1])])
	y_dist = np.abs(np.indices(image.shape)[0] - centroid[0])
	x_dist = np.abs(np.indices(image.shape)[1] - centroid[1])
	
	tissue_stiffness = np.exp(-0.02 * (x_dist**2 + 0.5*y_dist**2))
	dx = deform_scale * tissue_stiffness * gaussian_filter(np.random.randn(*image.shape), sigma=3)
	dy = deform_scale * tissue_stiffness * gaussian_filter(np.random.randn(*image.shape), sigma=3)
	
	y, x = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
	deformed_coords = np.stack([y + dy * 5, x + dx * 5])
	
	return map_coordinates(image, deformed_coords, order=1, mode='reflect'), map_coordinates(mask, deformed_coords, order=0, mode='constant')

def simulate_hemodynamics(image, mask, lesion_class):
	"""
	Simulates hemodynamic effects using synthetic ADC map variations.
	"""
	contrasts = {
		1: (0.5, 1.7),  # Increased contrast for small lesions
		2: (0.4, 1.6), 
		3: (0.5, 1.5),
		4: (0.6, 1.4),
		5: (0.7, 1.3)
	}
	min_contrast, max_contrast = contrasts[lesion_class]
	
	# Create brain mask
	brain_mask = (image != -1)
	
	vessel_mask = gaussian_filter(np.random.binomial(1, 0.03, size=image.shape), sigma=1)
	perfusion_map = gaussian_filter(np.random.normal(1.0, 0.3, size=image.shape), sigma=2)
	
	perfusion_map[vessel_mask > 0.5] *= np.random.uniform(max_contrast - 0.2, max_contrast)
	
	if np.sum(mask > 0) > 0:
		# Enhance lesion visibility
		lesion_area = mask > 0
		perfusion_map[lesion_area] = np.random.uniform(1.3, 1.5)  # Make lesions brighter
		
		distance = ndimage.distance_transform_edt(1 - mask)
		penumbra = (distance < 7) & (mask == 0) & brain_mask
		perfusion_map[penumbra] *= np.random.uniform(min_contrast + 0.3, min_contrast + 0.5)
	
	# Apply perfusion only within brain
	enhanced_image = image.copy()
	enhanced_image[brain_mask] = image[brain_mask] * perfusion_map[brain_mask]
	enhanced_image[~brain_mask] = -1.0
	
	return np.clip(enhanced_image, -1, 1), mask

def attention_occlusion(image, mask):
	"""
	Applies attention-guided occlusion to simulate adversarial conditions.
	"""
	# Create brain mask (all non-zero pixels)
	brain_mask = (image != -1)
	
	noise_scale = np.random.uniform(3, 6)
	attention_field = gaussian_filter(np.random.randn(*image.shape), sigma=noise_scale)
	attention_field = np.abs(attention_field)
	attention_field = (attention_field - attention_field.min()) / (attention_field.max() - attention_field.min())
	attention_field = attention_field * 0.3 + 0.7  # Reduce effect strength
	
	# Only apply attention field within brain region
	attention_field[~brain_mask] = 1.0
	
	# Apply modulation
	modulated_image = image * attention_field
	
	# Preserve background
	modulated_image[~brain_mask] = image[~brain_mask]
	
	return modulated_image, mask

# %%
class HIMRADataGenerator(tf.keras.utils.Sequence):
	def __init__(self, list_IDs, aug_ids=None, batch_size=BATCH_SIZE, shuffle=True):
		self.batch_size = batch_size
		self.list_IDs = list_IDs
		self.aug_ids = aug_ids if aug_ids is not None else []
		self.all_ids = list_IDs + self.aug_ids
		self.shuffle = shuffle
		self.on_epoch_end()

	def __len__(self):
		return int(np.floor(len(self.all_ids) / self.batch_size))

	def __getitem__(self, index):
		indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
		batch_ids = [self.all_ids[k] for k in indexes]
		return self.__data_generation(batch_ids)

	def on_epoch_end(self):
		self.indexes = np.arange(len(self.all_ids))
		if self.shuffle:
			np.random.shuffle(self.indexes)

	def __data_generation(self, batch_ids):
		X, y = [], []
		for case_id in batch_ids:
			is_aug = case_id in self.aug_ids
			input_dir = AUG_INPUT_PATH if is_aug else INPUT_PATH
			mask_dir = AUG_MASK_PATH if is_aug else MASK_PATH

			input_files = sorted([f for f in os.listdir(input_dir)
								if f.startswith(f'slice_{case_id}') and f.endswith('.png')])

			for f in input_files:
				img_path = os.path.join(input_dir, f)
				mask_path = os.path.join(mask_dir, f)

				img = load_and_preprocess(img_path)
				mask = load_and_preprocess(mask_path, is_mask=True)

				# Determine lesion class for class-aware augmentation
				lesion_size = np.sum(mask)
				lesion_class = 1 if lesion_size < 50 else 2 if lesion_size < 100 else 3 if lesion_size < 150 else 4 if lesion_size < 200 else 5

				# HIMRA Augmentation
				if is_aug:
					img, mask = biomechanical_deformation(img, mask, lesion_class)
					img, mask = simulate_hemodynamics(img, mask, lesion_class)
					# img, mask = attention_occlusion(img, mask)

				X.append(img)
				y.append(mask)

		return np.expand_dims(np.array(X), -1), np.array(y)

# %%
# def conv_block(inp, filters):
# 	x = Conv2D(filters, 3, padding='same', use_bias=False)(inp)
# 	x = BatchNormalization()(x)
# 	return Activation('relu')(x)

# def attention_gate(x, g, filters):
# 	g1 = Conv2D(filters, 1)(g)
# 	x1 = Conv2D(filters, 1)(x)
# 	out = Activation('relu')(add([g1, x1]))
# 	out = Conv2D(1, 1, activation='sigmoid')(out)
# 	return multiply([x, out])


def dice_score(y_true, y_pred):
	intersection = tf.reduce_sum(y_true * y_pred)
	union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
	dice = (2.0 * intersection + 1e-5) / (union + 1e-5)
	return dice

def conv_block(inp, filters):
	x = Conv2D(filters, (3,3), padding='same', activation='relu')(inp)
	x = Conv2D(filters, (3,3), padding='same')(x)
	x = BatchNormalization(axis=3)(x)
	x = Activation('relu')(x)
	return x

def encoder_block(inp, filters):
	x = conv_block(inp, filters)
	p = MaxPooling2D(pool_size=(2,2))(x)
	return x, p

def attention_block(l_layer, h_layer):
	phi = Conv2D(h_layer.shape[-1], (1,1), padding='same')(l_layer)
	theta = Conv2D(h_layer.shape[-1], (1,1), strides=(2,2), padding='same')(h_layer)
	x = tf.keras.layers.add([phi, theta])
	x = Activation('relu')(x)
	x = Conv2D(1, (1,1), padding='same', activation='sigmoid')(x)
	x = UpSampling2D(size=(2,2))(x)
	x = tf.keras.layers.multiply([h_layer, x])
	x = BatchNormalization(axis=3)(x)
	return x

def decoder_block(inp, filters, concat_layer):
	x = Conv2DTranspose(filters, (2,2), strides=(2,2), padding='same')(inp)
	x = concatenate([x, concat_layer])
	x = conv_block(x, filters)
	return x

# %%
# def create_model():
# 	inputs = Input((IMG_SIZE, IMG_SIZE, 1))

# 	# Encoder with reduced filters
# 	x = conv_block(inputs, 32)
# 	skip1 = x
# 	x = MaxPooling2D()(x)

# 	x = conv_block(x, 64)
# 	skip2 = x
# 	x = MaxPooling2D()(x)

# 	x = conv_block(x, 128)
# 	skip3 = x
# 	x = MaxPooling2D()(x)

# 	x = conv_block(x, 256)
# 	skip4 = x
# 	x = MaxPooling2D()(x)

# 	# Bridge
# 	x = conv_block(x, 512)

# 	# Decoder with attention
# 	x = Conv2DTranspose(256, 3, strides=2, padding='same')(x)
# 	x = attention_gate(skip4, x, 256)
# 	x = concatenate([x, skip4])
# 	x = conv_block(x, 256)

# 	x = Conv2DTranspose(128, 3, strides=2, padding='same')(x)
# 	x = attention_gate(skip3, x, 128)
# 	x = concatenate([x, skip3])
# 	x = conv_block(x, 128)

# 	x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
# 	x = attention_gate(skip2, x, 64)
# 	x = concatenate([x, skip2])
# 	x = conv_block(x, 64)

# 	x = Conv2DTranspose(32, 3, strides=2, padding='same')(x)
# 	x = attention_gate(skip1, x, 32)
# 	x = concatenate([x, skip1])
# 	x = conv_block(x, 32)

# 	outputs = Conv2D(1, 1, activation='sigmoid')(x)

# 	model = Model(inputs, outputs)

# 	model.compile(
# 		optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNINGRATE),
# 		loss=dice_loss,
# 		metrics=['accuracy', dice_coeff, iou]
# 	)

# 	return model


def create_model():
    inputs = Input((112,112,1))

    d1, p1 = encoder_block(inputs, 32)
    d2, p2 = encoder_block(p1, 64)
    d3, p3 = encoder_block(p2, 128)
    d4, p4 = encoder_block(p3, 256)

    b1 = conv_block(p4, 1024)

    e2 = decoder_block(b1, 256, d4)
    e3 = decoder_block(e2, 128, d3)
    e4 = decoder_block(e3, 64, d2)
    e5 = decoder_block(e4, 32, d1)

    outputs = Conv2D(1, (1,1), activation="sigmoid")(e5)

    model = Model(inputs=[inputs], outputs=[outputs], name='AttentionUnet')

    model.compile(
        loss=single_dice_loss,
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy', dice_coeff, dice_score, iou]
    )

    return model

# %%
def get_case_ids(path):
	files = sorted([f for f in os.listdir(path) if f.endswith('.png')])
	return sorted(list({f.split('_')[1] for f in files}))

# %%
def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_augmented_samples(train_gen, num_samples=3):
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

case_ids = get_case_ids(INPUT_PATH)
aug_case_ids = get_case_ids(AUG_INPUT_PATH) if os.path.exists(AUG_INPUT_PATH) else []

train_ids, test_ids = train_test_split(case_ids, test_size=0.2, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

print(f"Train: {len(train_ids)}, Val: {len(val_ids)}, Test: {len(test_ids)}, Aug: {len(aug_case_ids)}")

train_gen = HIMRADataGenerator(train_ids, aug_ids=aug_case_ids)
val_gen = HIMRADataGenerator(val_ids, shuffle=False)
test_gen = HIMRADataGenerator(test_ids, shuffle=False)

model = create_model()

print("Model Summary: ", model.summary())

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_dice_coeff', mode='max',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=EARLYSTOPPING, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    workers=4,
    use_multiprocessing=True
)

results = model.evaluate(test_gen)

print("\nGenerating Training Metrics Visualization...")
plot_training_metrics(history)
# Out:
# Train: 160, Val: 40, Test: 50, Aug: 63
# 2025-02-18 09:51:07.270095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14400 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:19:00.0, compute capability: 8.6
# Model: "AttentionUnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d_1[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 64)   36928       ['conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  147584      ['conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 256)  590080      ['conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 1024)   2360320     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 1024)   9438208     ['conv2d_8[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 1024)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  1048832    ['activation_4[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 14, 14, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 256)  590080      ['conv2d_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 128)  131200     ['activation_5[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 128)  147584      ['conv2d_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 64)  32832       ['activation_6[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   73792       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 64)   36928       ['conv2d_14[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 32  8224       ['activation_7[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 112, 112, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 1)  33          ['activation_8[0][0]']
#
# ==================================================================================================
# Total params: 16,550,305
# Trainable params: 16,546,337
# Non-trainable params: 3,968
# __________________________________________________________________________________________________
# Model Summary:  None
# Epoch 1/150
# 2025-02-18 09:51:08.031431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-18 09:51:12.233342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-02-18 09:51:16.471316: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f45ee268c60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-18 09:51:16.471345: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2025-02-18 09:51:16.475274: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-18 09:51:16.619929: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  1/55 [..............................] - ETA: 25:43 - loss: 0.9967 - accuracy: 0.6080 - dice_coeff: 0.0033 - dice_score: 0.0033 - iou: 0.0017
# 2025-02-18 09:51:43.772206: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:51:43.953321: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.35GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:51:43.953363: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.35GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  5/55 [=>............................] - ETA: 14:29 - loss: 0.9794 - accuracy: 0.7333 - dice_coeff: 0.0205 - dice_score: 0.0205 - iou: 0.0104
# 2025-02-18 09:52:55.557408: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:52:55.843506: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:52:55.843555: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  9/55 [===>..........................] - ETA: 15:41 - loss: 0.9766 - accuracy: 0.7568 - dice_coeff: 0.0226 - dice_score: 0.0226 - iou: 0.0115
# 2025-02-18 09:54:29.227258: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:54:29.469197: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-18 09:54:29.469245: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 10/55 [====>.........................] - ETA: 15:56 - loss: 0.9751 - accuracy: 0.7631 - dice_coeff: 0.0240 - dice_score: 0.0240 - iou: 0.0122
# 2025-02-18 09:54:54.263168: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.87GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 19/55 [=========>....................] - ETA: 12:42 - loss: 0.9727 - accuracy: 0.7801 - dice_coeff: 0.0261 - dice_score: 0.0261 - iou: 0.0133
# 2025-02-18 09:58:08.103671: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 55/55 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.8580 - dice_coeff: 0.0356 - dice_score: 0.0356 - iou: 0.0182
# 2025-02-18 10:03:40.698785: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_dice_coeff improved from -inf to 0.01626, saving model to best_model.h5
# 55/55 [==============================] - 775s 14s/step - loss: 0.9635 - accuracy: 0.8580 - dice_coeff: 0.0356 - dice_score: 0.0356 - iou: 0.0182 - val_loss: 0.9845 - val_accuracy: 0.9938 - val_dice_coeff: 0.0163 - val_dice_score: 0.0163 - val_iou: 0.0082 - lr: 0.0010
# Epoch 2/150
# 55/55 [==============================] - ETA: 0s - loss: 0.9414 - accuracy: 0.9565 - dice_coeff: 0.0568 - dice_score: 0.0568 - iou: 0.0296
# Epoch 2: val_dice_coeff improved from 0.01626 to 0.04108, saving model to best_model.h5
# 55/55 [==============================] - 308s 6s/step - loss: 0.9414 - accuracy: 0.9565 - dice_coeff: 0.0568 - dice_score: 0.0568 - iou: 0.0296 - val_loss: 0.9610 - val_accuracy: 0.9337 - val_dice_coeff: 0.0411 - val_dice_score: 0.0411 - val_iou: 0.0212 - lr: 0.0010
# Epoch 3/150
# 55/55 [==============================] - ETA: 0s - loss: 0.8280 - accuracy: 0.9872 - dice_coeff: 0.1697 - dice_score: 0.1697 - iou: 0.0953
# Epoch 3: val_dice_coeff did not improve from 0.04108
# 55/55 [==============================] - 215s 4s/step - loss: 0.8280 - accuracy: 0.9872 - dice_coeff: 0.1697 - dice_score: 0.1697 - iou: 0.0953 - val_loss: 0.9844 - val_accuracy: 0.8097 - val_dice_coeff: 0.0161 - val_dice_score: 0.0161 - val_iou: 0.0082 - lr: 0.0010
# Epoch 4/150
# 55/55 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.9948 - dice_coeff: 0.3754 - dice_score: 0.3754 - iou: 0.2403
# Epoch 4: val_dice_coeff did not improve from 0.04108
# 55/55 [==============================] - 208s 4s/step - loss: 0.6181 - accuracy: 0.9948 - dice_coeff: 0.3754 - dice_score: 0.3754 - iou: 0.2403 - val_loss: 0.9938 - val_accuracy: 0.9961 - val_dice_coeff: 0.0064 - val_dice_score: 0.0063 - val_iou: 0.0032 - lr: 0.0010
# Epoch 5/150
# 55/55 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.9957 - dice_coeff: 0.5208 - dice_score: 0.5208 - iou: 0.3603
# Epoch 5: val_dice_coeff did not improve from 0.04108
# 55/55 [==============================] - 199s 4s/step - loss: 0.4805 - accuracy: 0.9957 - dice_coeff: 0.5208 - dice_score: 0.5208 - iou: 0.3603 - val_loss: 0.9972 - val_accuracy: 0.9961 - val_dice_coeff: 0.0029 - val_dice_score: 0.0028 - val_iou: 0.0014 - lr: 0.0010
# Epoch 6/150
# 55/55 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.9957 - dice_coeff: 0.5418 - dice_score: 0.5418 - iou: 0.3817
# Epoch 6: val_dice_coeff improved from 0.04108 to 0.43482, saving model to best_model.h5
# 55/55 [==============================] - 80s 1s/step - loss: 0.4590 - accuracy: 0.9957 - dice_coeff: 0.5418 - dice_score: 0.5418 - iou: 0.3817 - val_loss: 0.5753 - val_accuracy: 0.9953 - val_dice_coeff: 0.4348 - val_dice_score: 0.4348 - val_iou: 0.2940 - lr: 0.0010
# Epoch 7/150
# 55/55 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.9965 - dice_coeff: 0.5901 - dice_score: 0.5901 - iou: 0.4284
# Epoch 7: val_dice_coeff improved from 0.43482 to 0.54596, saving model to best_model.h5
# 55/55 [==============================] - 63s 1s/step - loss: 0.4059 - accuracy: 0.9965 - dice_coeff: 0.5901 - dice_score: 0.5901 - iou: 0.4284 - val_loss: 0.4572 - val_accuracy: 0.9974 - val_dice_coeff: 0.5460 - val_dice_score: 0.5459 - val_iou: 0.3939 - lr: 0.0010
# Epoch 8/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.9967 - dice_coeff: 0.6429 - dice_score: 0.6428 - iou: 0.4822
# Epoch 8: val_dice_coeff did not improve from 0.54596
# 55/55 [==============================] - 138s 3s/step - loss: 0.3547 - accuracy: 0.9967 - dice_coeff: 0.6429 - dice_score: 0.6428 - iou: 0.4822 - val_loss: 0.5122 - val_accuracy: 0.9961 - val_dice_coeff: 0.4985 - val_dice_score: 0.4984 - val_iou: 0.3495 - lr: 0.0010
# Epoch 9/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3948 - accuracy: 0.9965 - dice_coeff: 0.6065 - dice_score: 0.6065 - iou: 0.4452
# Epoch 9: val_dice_coeff did not improve from 0.54596
# 55/55 [==============================] - 82s 1s/step - loss: 0.3948 - accuracy: 0.9965 - dice_coeff: 0.6065 - dice_score: 0.6065 - iou: 0.4452 - val_loss: 0.6995 - val_accuracy: 0.9871 - val_dice_coeff: 0.3104 - val_dice_score: 0.3103 - val_iou: 0.1933 - lr: 0.0010
# Epoch 10/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.9967 - dice_coeff: 0.6348 - dice_score: 0.6347 - iou: 0.4767
# Epoch 10: val_dice_coeff did not improve from 0.54596
# 55/55 [==============================] - 152s 3s/step - loss: 0.3656 - accuracy: 0.9967 - dice_coeff: 0.6348 - dice_score: 0.6347 - iou: 0.4767 - val_loss: 0.4935 - val_accuracy: 0.9973 - val_dice_coeff: 0.5035 - val_dice_score: 0.5034 - val_iou: 0.3598 - lr: 0.0010
# Epoch 11/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.9970 - dice_coeff: 0.6669 - dice_score: 0.6669 - iou: 0.5124
# Epoch 11: val_dice_coeff did not improve from 0.54596
# 55/55 [==============================] - 61s 1s/step - loss: 0.3316 - accuracy: 0.9970 - dice_coeff: 0.6669 - dice_score: 0.6669 - iou: 0.5124 - val_loss: 0.5290 - val_accuracy: 0.9949 - val_dice_coeff: 0.4818 - val_dice_score: 0.4818 - val_iou: 0.3337 - lr: 0.0010
# Epoch 12/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3296 - accuracy: 0.9970 - dice_coeff: 0.6731 - dice_score: 0.6731 - iou: 0.5159
# Epoch 12: val_dice_coeff improved from 0.54596 to 0.67831, saving model to best_model.h5
# 55/55 [==============================] - 79s 1s/step - loss: 0.3296 - accuracy: 0.9970 - dice_coeff: 0.6731 - dice_score: 0.6731 - iou: 0.5159 - val_loss: 0.3303 - val_accuracy: 0.9980 - val_dice_coeff: 0.6783 - val_dice_score: 0.6783 - val_iou: 0.5348 - lr: 0.0010
# Epoch 13/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.9971 - dice_coeff: 0.6774 - dice_score: 0.6773 - iou: 0.5256
# Epoch 13: val_dice_coeff did not improve from 0.67831
# 55/55 [==============================] - 80s 1s/step - loss: 0.3265 - accuracy: 0.9971 - dice_coeff: 0.6774 - dice_score: 0.6773 - iou: 0.5256 - val_loss: 0.3324 - val_accuracy: 0.9980 - val_dice_coeff: 0.6746 - val_dice_score: 0.6745 - val_iou: 0.5280 - lr: 0.0010
# Epoch 14/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.9972 - dice_coeff: 0.7058 - dice_score: 0.7058 - iou: 0.5552
# Epoch 14: val_dice_coeff improved from 0.67831 to 0.70970, saving model to best_model.h5
# 55/55 [==============================] - 54s 967ms/step - loss: 0.2930 - accuracy: 0.9972 - dice_coeff: 0.7058 - dice_score: 0.7058 - iou: 0.5552 - val_loss: 0.2959 - val_accuracy: 0.9983 - val_dice_coeff: 0.7097 - val_dice_score: 0.7097 - val_iou: 0.5687 - lr: 0.0010
# Epoch 15/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9973 - dice_coeff: 0.7356 - dice_score: 0.7356 - iou: 0.5897
# Epoch 15: val_dice_coeff did not improve from 0.70970
# 55/55 [==============================] - 65s 1s/step - loss: 0.2677 - accuracy: 0.9973 - dice_coeff: 0.7356 - dice_score: 0.7356 - iou: 0.5897 - val_loss: 0.3133 - val_accuracy: 0.9981 - val_dice_coeff: 0.6954 - val_dice_score: 0.6953 - val_iou: 0.5580 - lr: 0.0010
# Epoch 16/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.9972 - dice_coeff: 0.6972 - dice_score: 0.6972 - iou: 0.5471
# Epoch 16: val_dice_coeff did not improve from 0.70970
# 55/55 [==============================] - 40s 699ms/step - loss: 0.3001 - accuracy: 0.9972 - dice_coeff: 0.6972 - dice_score: 0.6972 - iou: 0.5471 - val_loss: 0.3724 - val_accuracy: 0.9981 - val_dice_coeff: 0.6321 - val_dice_score: 0.6320 - val_iou: 0.4892 - lr: 0.0010
# Epoch 17/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9972 - dice_coeff: 0.6899 - dice_score: 0.6899 - iou: 0.5385
# Epoch 17: val_dice_coeff did not improve from 0.70970
# 55/55 [==============================] - 67s 1s/step - loss: 0.3088 - accuracy: 0.9972 - dice_coeff: 0.6899 - dice_score: 0.6899 - iou: 0.5385 - val_loss: 0.4213 - val_accuracy: 0.9975 - val_dice_coeff: 0.5880 - val_dice_score: 0.5880 - val_iou: 0.4443 - lr: 0.0010
# Epoch 18/150
# 55/55 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9972 - dice_coeff: 0.6965 - dice_score: 0.6965 - iou: 0.5465
# Epoch 18: val_dice_coeff did not improve from 0.70970
# 55/55 [==============================] - 69s 1s/step - loss: 0.3069 - accuracy: 0.9972 - dice_coeff: 0.6965 - dice_score: 0.6965 - iou: 0.5465 - val_loss: 0.3059 - val_accuracy: 0.9981 - val_dice_coeff: 0.6993 - val_dice_score: 0.6992 - val_iou: 0.5538 - lr: 0.0010
# Epoch 19/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2941 - accuracy: 0.9973 - dice_coeff: 0.7022 - dice_score: 0.7022 - iou: 0.5535
# Epoch 19: val_dice_coeff did not improve from 0.70970
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 [==============================] - 72s 1s/step - loss: 0.2941 - accuracy: 0.9973 - dice_coeff: 0.7022 - dice_score: 0.7022 - iou: 0.5535 - val_loss: 0.3705 - val_accuracy: 0.9981 - val_dice_coeff: 0.6262 - val_dice_score: 0.6261 - val_iou: 0.4857 - lr: 0.0010
# Epoch 20/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.9974 - dice_coeff: 0.7284 - dice_score: 0.7284 - iou: 0.5834
# Epoch 20: val_dice_coeff improved from 0.70970 to 0.78982, saving model to best_model.h5
# 55/55 [==============================] - 38s 685ms/step - loss: 0.2736 - accuracy: 0.9974 - dice_coeff: 0.7284 - dice_score: 0.7284 - iou: 0.5834 - val_loss: 0.2114 - val_accuracy: 0.9987 - val_dice_coeff: 0.7898 - val_dice_score: 0.7898 - val_iou: 0.6651 - lr: 5.0000e-04
# Epoch 21/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.9975 - dice_coeff: 0.7366 - dice_score: 0.7366 - iou: 0.5921
# Epoch 21: val_dice_coeff did not improve from 0.78982
# 55/55 [==============================] - 41s 709ms/step - loss: 0.2659 - accuracy: 0.9975 - dice_coeff: 0.7366 - dice_score: 0.7366 - iou: 0.5921 - val_loss: 0.2160 - val_accuracy: 0.9987 - val_dice_coeff: 0.7867 - val_dice_score: 0.7867 - val_iou: 0.6616 - lr: 5.0000e-04
# Epoch 22/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9975 - dice_coeff: 0.7407 - dice_score: 0.7406 - iou: 0.5984
# Epoch 22: val_dice_coeff did not improve from 0.78982
# 55/55 [==============================] - 87s 2s/step - loss: 0.2608 - accuracy: 0.9975 - dice_coeff: 0.7407 - dice_score: 0.7406 - iou: 0.5984 - val_loss: 0.2165 - val_accuracy: 0.9987 - val_dice_coeff: 0.7854 - val_dice_score: 0.7853 - val_iou: 0.6594 - lr: 5.0000e-04
# Epoch 23/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9975 - dice_coeff: 0.7382 - dice_score: 0.7382 - iou: 0.5944
# Epoch 23: val_dice_coeff did not improve from 0.78982
# 55/55 [==============================] - 82s 1s/step - loss: 0.2632 - accuracy: 0.9975 - dice_coeff: 0.7382 - dice_score: 0.7382 - iou: 0.5944 - val_loss: 0.3225 - val_accuracy: 0.9980 - val_dice_coeff: 0.6871 - val_dice_score: 0.6871 - val_iou: 0.5480 - lr: 5.0000e-04
# Epoch 24/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9976 - dice_coeff: 0.7530 - dice_score: 0.7530 - iou: 0.6156
# Epoch 24: val_dice_coeff did not improve from 0.78982
# 55/55 [==============================] - 63s 1s/step - loss: 0.2478 - accuracy: 0.9976 - dice_coeff: 0.7530 - dice_score: 0.7530 - iou: 0.6156 - val_loss: 0.2784 - val_accuracy: 0.9984 - val_dice_coeff: 0.7195 - val_dice_score: 0.7194 - val_iou: 0.5882 - lr: 5.0000e-04
# Epoch 25/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.9976 - dice_coeff: 0.7521 - dice_score: 0.7521 - iou: 0.6126
# Epoch 25: val_dice_coeff did not improve from 0.78982
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 [==============================] - 63s 1s/step - loss: 0.2497 - accuracy: 0.9976 - dice_coeff: 0.7521 - dice_score: 0.7521 - iou: 0.6126 - val_loss: 0.2124 - val_accuracy: 0.9987 - val_dice_coeff: 0.7886 - val_dice_score: 0.7886 - val_iou: 0.6643 - lr: 5.0000e-04
# Epoch 26/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9976 - dice_coeff: 0.7546 - dice_score: 0.7546 - iou: 0.6169
# Epoch 26: val_dice_coeff improved from 0.78982 to 0.79716, saving model to best_model.h5
# 55/55 [==============================] - 40s 709ms/step - loss: 0.2448 - accuracy: 0.9976 - dice_coeff: 0.7546 - dice_score: 0.7546 - iou: 0.6169 - val_loss: 0.2043 - val_accuracy: 0.9987 - val_dice_coeff: 0.7972 - val_dice_score: 0.7971 - val_iou: 0.6739 - lr: 2.5000e-04
# Epoch 27/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9977 - dice_coeff: 0.7607 - dice_score: 0.7607 - iou: 0.6217
# Epoch 27: val_dice_coeff did not improve from 0.79716
# 55/55 [==============================] - 36s 635ms/step - loss: 0.2415 - accuracy: 0.9977 - dice_coeff: 0.7607 - dice_score: 0.7607 - iou: 0.6217 - val_loss: 0.2294 - val_accuracy: 0.9986 - val_dice_coeff: 0.7714 - val_dice_score: 0.7713 - val_iou: 0.6455 - lr: 2.5000e-04
# Epoch 28/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9977 - dice_coeff: 0.7616 - dice_score: 0.7616 - iou: 0.6232
# Epoch 28: val_dice_coeff improved from 0.79716 to 0.81597, saving model to best_model.h5
# 55/55 [==============================] - 42s 730ms/step - loss: 0.2413 - accuracy: 0.9977 - dice_coeff: 0.7616 - dice_score: 0.7616 - iou: 0.6232 - val_loss: 0.1860 - val_accuracy: 0.9989 - val_dice_coeff: 0.8160 - val_dice_score: 0.8159 - val_iou: 0.6990 - lr: 2.5000e-04
# Epoch 29/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9977 - dice_coeff: 0.7581 - dice_score: 0.7581 - iou: 0.6226
# Epoch 29: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 40s 696ms/step - loss: 0.2416 - accuracy: 0.9977 - dice_coeff: 0.7581 - dice_score: 0.7581 - iou: 0.6226 - val_loss: 0.1996 - val_accuracy: 0.9988 - val_dice_coeff: 0.8014 - val_dice_score: 0.8013 - val_iou: 0.6805 - lr: 2.5000e-04
# Epoch 30/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9976 - dice_coeff: 0.7638 - dice_score: 0.7638 - iou: 0.6266
# Epoch 30: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2391 - accuracy: 0.9976 - dice_coeff: 0.7638 - dice_score: 0.7638 - iou: 0.6266 - val_loss: 0.1974 - val_accuracy: 0.9988 - val_dice_coeff: 0.8036 - val_dice_score: 0.8035 - val_iou: 0.6832 - lr: 2.5000e-04
# Epoch 31/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9977 - dice_coeff: 0.7762 - dice_score: 0.7762 - iou: 0.6406
# Epoch 31: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 60s 1s/step - loss: 0.2278 - accuracy: 0.9977 - dice_coeff: 0.7762 - dice_score: 0.7762 - iou: 0.6406 - val_loss: 0.2045 - val_accuracy: 0.9988 - val_dice_coeff: 0.7963 - val_dice_score: 0.7963 - val_iou: 0.6730 - lr: 2.5000e-04
# Epoch 32/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9977 - dice_coeff: 0.7696 - dice_score: 0.7696 - iou: 0.6338
# Epoch 32: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 41s 705ms/step - loss: 0.2346 - accuracy: 0.9977 - dice_coeff: 0.7696 - dice_score: 0.7696 - iou: 0.6338 - val_loss: 0.2080 - val_accuracy: 0.9987 - val_dice_coeff: 0.7920 - val_dice_score: 0.7920 - val_iou: 0.6675 - lr: 2.5000e-04
# Epoch 33/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9977 - dice_coeff: 0.7634 - dice_score: 0.7634 - iou: 0.6280
# Epoch 33: val_dice_coeff did not improve from 0.81597
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 [==============================] - 41s 700ms/step - loss: 0.2342 - accuracy: 0.9977 - dice_coeff: 0.7634 - dice_score: 0.7634 - iou: 0.6280 - val_loss: 0.1996 - val_accuracy: 0.9988 - val_dice_coeff: 0.8015 - val_dice_score: 0.8014 - val_iou: 0.6806 - lr: 2.5000e-04
# Epoch 34/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9977 - dice_coeff: 0.7769 - dice_score: 0.7769 - iou: 0.6430
# Epoch 34: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 41s 713ms/step - loss: 0.2270 - accuracy: 0.9977 - dice_coeff: 0.7769 - dice_score: 0.7769 - iou: 0.6430 - val_loss: 0.1865 - val_accuracy: 0.9989 - val_dice_coeff: 0.8147 - val_dice_score: 0.8146 - val_iou: 0.6974 - lr: 1.2500e-04
# Epoch 35/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9977 - dice_coeff: 0.7670 - dice_score: 0.7670 - iou: 0.6325
# Epoch 35: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 40s 707ms/step - loss: 0.2339 - accuracy: 0.9977 - dice_coeff: 0.7670 - dice_score: 0.7670 - iou: 0.6325 - val_loss: 0.2308 - val_accuracy: 0.9986 - val_dice_coeff: 0.7683 - val_dice_score: 0.7682 - val_iou: 0.6431 - lr: 1.2500e-04
# Epoch 36/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9977 - dice_coeff: 0.7671 - dice_score: 0.7671 - iou: 0.6327
# Epoch 36: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 41s 717ms/step - loss: 0.2362 - accuracy: 0.9977 - dice_coeff: 0.7671 - dice_score: 0.7671 - iou: 0.6327 - val_loss: 0.2049 - val_accuracy: 0.9988 - val_dice_coeff: 0.7961 - val_dice_score: 0.7960 - val_iou: 0.6734 - lr: 1.2500e-04
# Epoch 37/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9979 - dice_coeff: 0.7770 - dice_score: 0.7770 - iou: 0.6425
# Epoch 37: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 40s 718ms/step - loss: 0.2267 - accuracy: 0.9979 - dice_coeff: 0.7770 - dice_score: 0.7770 - iou: 0.6425 - val_loss: 0.1969 - val_accuracy: 0.9988 - val_dice_coeff: 0.8040 - val_dice_score: 0.8039 - val_iou: 0.6836 - lr: 1.2500e-04
# Epoch 38/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9977 - dice_coeff: 0.7831 - dice_score: 0.7831 - iou: 0.6496
# Epoch 38: val_dice_coeff did not improve from 0.81597
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 55/55 [==============================] - 73s 1s/step - loss: 0.2212 - accuracy: 0.9977 - dice_coeff: 0.7831 - dice_score: 0.7831 - iou: 0.6496 - val_loss: 0.2063 - val_accuracy: 0.9988 - val_dice_coeff: 0.7943 - val_dice_score: 0.7943 - val_iou: 0.6719 - lr: 1.2500e-04
# Epoch 39/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9978 - dice_coeff: 0.7664 - dice_score: 0.7664 - iou: 0.6328
# Epoch 39: val_dice_coeff did not improve from 0.81597
# 55/55 [==============================] - 58s 1s/step - loss: 0.2336 - accuracy: 0.9978 - dice_coeff: 0.7664 - dice_score: 0.7664 - iou: 0.6328 - val_loss: 0.1870 - val_accuracy: 0.9988 - val_dice_coeff: 0.8143 - val_dice_score: 0.8142 - val_iou: 0.6968 - lr: 6.2500e-05
# Epoch 40/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9978 - dice_coeff: 0.7784 - dice_score: 0.7784 - iou: 0.6446
# Epoch 40: val_dice_coeff improved from 0.81597 to 0.81837, saving model to best_model.h5
# 55/55 [==============================] - 43s 765ms/step - loss: 0.2267 - accuracy: 0.9978 - dice_coeff: 0.7784 - dice_score: 0.7784 - iou: 0.6446 - val_loss: 0.1831 - val_accuracy: 0.9989 - val_dice_coeff: 0.8184 - val_dice_score: 0.8183 - val_iou: 0.7023 - lr: 6.2500e-05
# Epoch 41/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9978 - dice_coeff: 0.7758 - dice_score: 0.7758 - iou: 0.6405
# Epoch 41: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 46s 815ms/step - loss: 0.2283 - accuracy: 0.9978 - dice_coeff: 0.7758 - dice_score: 0.7758 - iou: 0.6405 - val_loss: 0.1859 - val_accuracy: 0.9989 - val_dice_coeff: 0.8156 - val_dice_score: 0.8156 - val_iou: 0.6984 - lr: 6.2500e-05
# Epoch 42/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9978 - dice_coeff: 0.7715 - dice_score: 0.7715 - iou: 0.6367
# Epoch 42: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 54s 965ms/step - loss: 0.2284 - accuracy: 0.9978 - dice_coeff: 0.7715 - dice_score: 0.7715 - iou: 0.6367 - val_loss: 0.1834 - val_accuracy: 0.9989 - val_dice_coeff: 0.8179 - val_dice_score: 0.8178 - val_iou: 0.7016 - lr: 6.2500e-05
# Epoch 43/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9978 - dice_coeff: 0.7695 - dice_score: 0.7695 - iou: 0.6357
# Epoch 43: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 61s 1s/step - loss: 0.2321 - accuracy: 0.9978 - dice_coeff: 0.7695 - dice_score: 0.7695 - iou: 0.6357 - val_loss: 0.1886 - val_accuracy: 0.9989 - val_dice_coeff: 0.8126 - val_dice_score: 0.8125 - val_iou: 0.6950 - lr: 6.2500e-05
# Epoch 44/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9978 - dice_coeff: 0.7741 - dice_score: 0.7741 - iou: 0.6392
# Epoch 44: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 40s 695ms/step - loss: 0.2283 - accuracy: 0.9978 - dice_coeff: 0.7741 - dice_score: 0.7741 - iou: 0.6392 - val_loss: 0.1983 - val_accuracy: 0.9988 - val_dice_coeff: 0.8021 - val_dice_score: 0.8021 - val_iou: 0.6819 - lr: 6.2500e-05
# Epoch 45/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9978 - dice_coeff: 0.7773 - dice_score: 0.7773 - iou: 0.6445
# Epoch 45: val_dice_coeff did not improve from 0.81837
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 55/55 [==============================] - 40s 696ms/step - loss: 0.2260 - accuracy: 0.9978 - dice_coeff: 0.7773 - dice_score: 0.7773 - iou: 0.6445 - val_loss: 0.1906 - val_accuracy: 0.9988 - val_dice_coeff: 0.8103 - val_dice_score: 0.8103 - val_iou: 0.6921 - lr: 6.2500e-05
# Epoch 46/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9978 - dice_coeff: 0.7859 - dice_score: 0.7859 - iou: 0.6537
# Epoch 46: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 52s 909ms/step - loss: 0.2181 - accuracy: 0.9978 - dice_coeff: 0.7859 - dice_score: 0.7859 - iou: 0.6537 - val_loss: 0.1890 - val_accuracy: 0.9988 - val_dice_coeff: 0.8119 - val_dice_score: 0.8119 - val_iou: 0.6942 - lr: 3.1250e-05
# Epoch 47/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9978 - dice_coeff: 0.7655 - dice_score: 0.7655 - iou: 0.6302
# Epoch 47: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 38s 671ms/step - loss: 0.2317 - accuracy: 0.9978 - dice_coeff: 0.7655 - dice_score: 0.7655 - iou: 0.6302 - val_loss: 0.1857 - val_accuracy: 0.9989 - val_dice_coeff: 0.8156 - val_dice_score: 0.8155 - val_iou: 0.6987 - lr: 3.1250e-05
# Epoch 48/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2244 - accuracy: 0.9978 - dice_coeff: 0.7779 - dice_score: 0.7779 - iou: 0.6460
# Epoch 48: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 38s 645ms/step - loss: 0.2244 - accuracy: 0.9978 - dice_coeff: 0.7779 - dice_score: 0.7779 - iou: 0.6460 - val_loss: 0.1848 - val_accuracy: 0.9989 - val_dice_coeff: 0.8165 - val_dice_score: 0.8164 - val_iou: 0.7000 - lr: 3.1250e-05
# Epoch 49/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9978 - dice_coeff: 0.7771 - dice_score: 0.7770 - iou: 0.6425
# Epoch 49: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 55s 973ms/step - loss: 0.2261 - accuracy: 0.9978 - dice_coeff: 0.7771 - dice_score: 0.7770 - iou: 0.6425 - val_loss: 0.1893 - val_accuracy: 0.9988 - val_dice_coeff: 0.8118 - val_dice_score: 0.8118 - val_iou: 0.6938 - lr: 3.1250e-05
# Epoch 50/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2202 - accuracy: 0.9978 - dice_coeff: 0.7806 - dice_score: 0.7805 - iou: 0.6502
# Epoch 50: val_dice_coeff did not improve from 0.81837
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 55/55 [==============================] - 41s 721ms/step - loss: 0.2202 - accuracy: 0.9978 - dice_coeff: 0.7806 - dice_score: 0.7805 - iou: 0.6502 - val_loss: 0.1871 - val_accuracy: 0.9988 - val_dice_coeff: 0.8141 - val_dice_score: 0.8141 - val_iou: 0.6967 - lr: 3.1250e-05
# Epoch 51/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9978 - dice_coeff: 0.7851 - dice_score: 0.7851 - iou: 0.6513
# Epoch 51: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 710ms/step - loss: 0.2175 - accuracy: 0.9978 - dice_coeff: 0.7851 - dice_score: 0.7851 - iou: 0.6513 - val_loss: 0.1862 - val_accuracy: 0.9989 - val_dice_coeff: 0.8151 - val_dice_score: 0.8151 - val_iou: 0.6982 - lr: 1.5625e-05
# Epoch 52/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9978 - dice_coeff: 0.7811 - dice_score: 0.7811 - iou: 0.6486
# Epoch 52: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 709ms/step - loss: 0.2211 - accuracy: 0.9978 - dice_coeff: 0.7811 - dice_score: 0.7811 - iou: 0.6486 - val_loss: 0.1842 - val_accuracy: 0.9989 - val_dice_coeff: 0.8171 - val_dice_score: 0.8170 - val_iou: 0.7007 - lr: 1.5625e-05
# Epoch 53/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9978 - dice_coeff: 0.7904 - dice_score: 0.7904 - iou: 0.6593
# Epoch 53: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 55s 985ms/step - loss: 0.2125 - accuracy: 0.9978 - dice_coeff: 0.7904 - dice_score: 0.7904 - iou: 0.6593 - val_loss: 0.1848 - val_accuracy: 0.9989 - val_dice_coeff: 0.8165 - val_dice_score: 0.8164 - val_iou: 0.6999 - lr: 1.5625e-05
# Epoch 54/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9978 - dice_coeff: 0.7800 - dice_score: 0.7800 - iou: 0.6455
# Epoch 54: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 51s 909ms/step - loss: 0.2208 - accuracy: 0.9978 - dice_coeff: 0.7800 - dice_score: 0.7800 - iou: 0.6455 - val_loss: 0.1854 - val_accuracy: 0.9989 - val_dice_coeff: 0.8159 - val_dice_score: 0.8158 - val_iou: 0.6992 - lr: 1.5625e-05
# Epoch 55/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9978 - dice_coeff: 0.7888 - dice_score: 0.7888 - iou: 0.6587
# Epoch 55: val_dice_coeff did not improve from 0.81837
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 55/55 [==============================] - 41s 728ms/step - loss: 0.2150 - accuracy: 0.9978 - dice_coeff: 0.7888 - dice_score: 0.7888 - iou: 0.6587 - val_loss: 0.1887 - val_accuracy: 0.9988 - val_dice_coeff: 0.8124 - val_dice_score: 0.8124 - val_iou: 0.6948 - lr: 1.5625e-05
# Epoch 56/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.9978 - dice_coeff: 0.7807 - dice_score: 0.7807 - iou: 0.6459
# Epoch 56: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 55s 982ms/step - loss: 0.2229 - accuracy: 0.9978 - dice_coeff: 0.7807 - dice_score: 0.7807 - iou: 0.6459 - val_loss: 0.1856 - val_accuracy: 0.9989 - val_dice_coeff: 0.8156 - val_dice_score: 0.8156 - val_iou: 0.6989 - lr: 7.8125e-06
# Epoch 57/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9978 - dice_coeff: 0.7737 - dice_score: 0.7737 - iou: 0.6407
# Epoch 57: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 64s 1s/step - loss: 0.2273 - accuracy: 0.9978 - dice_coeff: 0.7737 - dice_score: 0.7737 - iou: 0.6407 - val_loss: 0.1853 - val_accuracy: 0.9989 - val_dice_coeff: 0.8159 - val_dice_score: 0.8159 - val_iou: 0.6993 - lr: 7.8125e-06
# Epoch 58/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9978 - dice_coeff: 0.7757 - dice_score: 0.7757 - iou: 0.6408
# Epoch 58: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 642ms/step - loss: 0.2258 - accuracy: 0.9978 - dice_coeff: 0.7757 - dice_score: 0.7757 - iou: 0.6408 - val_loss: 0.1833 - val_accuracy: 0.9989 - val_dice_coeff: 0.8180 - val_dice_score: 0.8179 - val_iou: 0.7019 - lr: 7.8125e-06
# Epoch 59/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9978 - dice_coeff: 0.7873 - dice_score: 0.7873 - iou: 0.6555
# Epoch 59: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 42s 726ms/step - loss: 0.2161 - accuracy: 0.9978 - dice_coeff: 0.7873 - dice_score: 0.7873 - iou: 0.6555 - val_loss: 0.1844 - val_accuracy: 0.9989 - val_dice_coeff: 0.8167 - val_dice_score: 0.8167 - val_iou: 0.7003 - lr: 7.8125e-06
# Epoch 60/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9978 - dice_coeff: 0.7788 - dice_score: 0.7788 - iou: 0.6442
# Epoch 60: val_dice_coeff did not improve from 0.81837
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# ...
# Epoch 98/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9978 - dice_coeff: 0.7854 - dice_score: 0.7853 - iou: 0.6531
# Epoch 98: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 729ms/step - loss: 0.2148 - accuracy: 0.9978 - dice_coeff: 0.7854 - dice_score: 0.7853 - iou: 0.6531 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8175 - val_iou: 0.7012 - lr: 3.0518e-08
# Epoch 99/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9978 - dice_coeff: 0.7867 - dice_score: 0.7867 - iou: 0.6542
# Epoch 99: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 730ms/step - loss: 0.2128 - accuracy: 0.9978 - dice_coeff: 0.7867 - dice_score: 0.7867 - iou: 0.6542 - val_loss: 0.1837 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8175 - val_iou: 0.7013 - lr: 3.0518e-08
# Epoch 100/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9978 - dice_coeff: 0.7765 - dice_score: 0.7765 - iou: 0.6447
# Epoch 100: val_dice_coeff did not improve from 0.81837
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 55/55 [==============================] - 40s 716ms/step - loss: 0.2228 - accuracy: 0.9978 - dice_coeff: 0.7765 - dice_score: 0.7765 - iou: 0.6447 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8175 - val_iou: 0.7013 - lr: 3.0518e-08
# Epoch 101/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9978 - dice_coeff: 0.7825 - dice_score: 0.7825 - iou: 0.6497
# Epoch 101: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 723ms/step - loss: 0.2220 - accuracy: 0.9978 - dice_coeff: 0.7825 - dice_score: 0.7825 - iou: 0.6497 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 1.5259e-08
# Epoch 102/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9978 - dice_coeff: 0.7882 - dice_score: 0.7882 - iou: 0.6560
# Epoch 102: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 718ms/step - loss: 0.2153 - accuracy: 0.9978 - dice_coeff: 0.7882 - dice_score: 0.7882 - iou: 0.6560 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 1.5259e-08
# Epoch 103/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9978 - dice_coeff: 0.7833 - dice_score: 0.7833 - iou: 0.6512
# Epoch 103: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 647ms/step - loss: 0.2178 - accuracy: 0.9978 - dice_coeff: 0.7833 - dice_score: 0.7833 - iou: 0.6512 - val_loss: 0.1837 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8175 - val_iou: 0.7013 - lr: 1.5259e-08
# Epoch 104/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9978 - dice_coeff: 0.7821 - dice_score: 0.7821 - iou: 0.6517
# Epoch 104: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 63s 1s/step - loss: 0.2199 - accuracy: 0.9978 - dice_coeff: 0.7821 - dice_score: 0.7821 - iou: 0.6517 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 1.5259e-08
# Epoch 105/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9978 - dice_coeff: 0.7753 - dice_score: 0.7753 - iou: 0.6404
# Epoch 105: val_dice_coeff did not improve from 0.81837
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 55/55 [==============================] - 40s 715ms/step - loss: 0.2232 - accuracy: 0.9978 - dice_coeff: 0.7753 - dice_score: 0.7753 - iou: 0.6404 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 1.5259e-08
# Epoch 106/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9978 - dice_coeff: 0.7807 - dice_score: 0.7807 - iou: 0.6492
# Epoch 106: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 715ms/step - loss: 0.2200 - accuracy: 0.9978 - dice_coeff: 0.7807 - dice_score: 0.7807 - iou: 0.6492 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8173 - val_dice_score: 0.8173 - val_iou: 0.7010 - lr: 7.6294e-09
# Epoch 107/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9978 - dice_coeff: 0.7774 - dice_score: 0.7774 - iou: 0.6454
# Epoch 107: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 40s 711ms/step - loss: 0.2241 - accuracy: 0.9978 - dice_coeff: 0.7774 - dice_score: 0.7774 - iou: 0.6454 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8173 - val_dice_score: 0.8173 - val_iou: 0.7010 - lr: 7.6294e-09
# Epoch 108/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9978 - dice_coeff: 0.7767 - dice_score: 0.7766 - iou: 0.6408
# Epoch 108: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 722ms/step - loss: 0.2247 - accuracy: 0.9978 - dice_coeff: 0.7767 - dice_score: 0.7766 - iou: 0.6408 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 7.6294e-09
# Epoch 109/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9978 - dice_coeff: 0.7780 - dice_score: 0.7780 - iou: 0.6462
# Epoch 109: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 38s 646ms/step - loss: 0.2228 - accuracy: 0.9978 - dice_coeff: 0.7780 - dice_score: 0.7780 - iou: 0.6462 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 7.6294e-09
# Epoch 110/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9978 - dice_coeff: 0.7850 - dice_score: 0.7850 - iou: 0.6530
# Epoch 110: val_dice_coeff did not improve from 0.81837
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 55/55 [==============================] - 43s 728ms/step - loss: 0.2170 - accuracy: 0.9978 - dice_coeff: 0.7850 - dice_score: 0.7850 - iou: 0.6530 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8173 - val_iou: 0.7011 - lr: 7.6294e-09
# Epoch 111/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2244 - accuracy: 0.9978 - dice_coeff: 0.7774 - dice_score: 0.7774 - iou: 0.6462
# Epoch 111: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 640ms/step - loss: 0.2244 - accuracy: 0.9978 - dice_coeff: 0.7774 - dice_score: 0.7774 - iou: 0.6462 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8173 - val_iou: 0.7011 - lr: 3.8147e-09
# Epoch 112/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9978 - dice_coeff: 0.7859 - dice_score: 0.7859 - iou: 0.6550
# Epoch 112: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 42s 737ms/step - loss: 0.2160 - accuracy: 0.9978 - dice_coeff: 0.7859 - dice_score: 0.7859 - iou: 0.6550 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 3.8147e-09
# Epoch 113/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9979 - dice_coeff: 0.7856 - dice_score: 0.7856 - iou: 0.6523
# Epoch 113: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 720ms/step - loss: 0.2154 - accuracy: 0.9979 - dice_coeff: 0.7856 - dice_score: 0.7856 - iou: 0.6523 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 3.8147e-09
# Epoch 114/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9978 - dice_coeff: 0.7824 - dice_score: 0.7824 - iou: 0.6491
# Epoch 114: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 648ms/step - loss: 0.2194 - accuracy: 0.9978 - dice_coeff: 0.7824 - dice_score: 0.7824 - iou: 0.6491 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 3.8147e-09
# Epoch 115/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9978 - dice_coeff: 0.7872 - dice_score: 0.7872 - iou: 0.6555
# Epoch 115: val_dice_coeff did not improve from 0.81837
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 55/55 [==============================] - 39s 679ms/step - loss: 0.2162 - accuracy: 0.9978 - dice_coeff: 0.7872 - dice_score: 0.7872 - iou: 0.6555 - val_loss: 0.1837 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8175 - val_iou: 0.7013 - lr: 3.8147e-09
# Epoch 116/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9978 - dice_coeff: 0.7866 - dice_score: 0.7865 - iou: 0.6541
# Epoch 116: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 39s 673ms/step - loss: 0.2157 - accuracy: 0.9978 - dice_coeff: 0.7866 - dice_score: 0.7865 - iou: 0.6541 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 1.9073e-09
# Epoch 117/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9978 - dice_coeff: 0.7729 - dice_score: 0.7729 - iou: 0.6391
# Epoch 117: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 718ms/step - loss: 0.2272 - accuracy: 0.9978 - dice_coeff: 0.7729 - dice_score: 0.7729 - iou: 0.6391 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 1.9073e-09
# Epoch 118/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9978 - dice_coeff: 0.7805 - dice_score: 0.7805 - iou: 0.6462
# Epoch 118: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 647ms/step - loss: 0.2210 - accuracy: 0.9978 - dice_coeff: 0.7805 - dice_score: 0.7805 - iou: 0.6462 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 1.9073e-09
# Epoch 119/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9978 - dice_coeff: 0.7886 - dice_score: 0.7886 - iou: 0.6569
# Epoch 119: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 38s 667ms/step - loss: 0.2120 - accuracy: 0.9978 - dice_coeff: 0.7886 - dice_score: 0.7886 - iou: 0.6569 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 1.9073e-09
# Epoch 120/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7852 - dice_score: 0.7852 - iou: 0.6516
# Epoch 120: val_dice_coeff did not improve from 0.81837
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 55/55 [==============================] - 38s 682ms/step - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7852 - dice_score: 0.7852 - iou: 0.6516 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 1.9073e-09
# Epoch 121/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7826 - dice_score: 0.7826 - iou: 0.6495
# Epoch 121: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 52s 937ms/step - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7826 - dice_score: 0.7826 - iou: 0.6495 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 9.5367e-10
# Epoch 122/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9978 - dice_coeff: 0.7833 - dice_score: 0.7833 - iou: 0.6504
# Epoch 122: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 42s 724ms/step - loss: 0.2167 - accuracy: 0.9978 - dice_coeff: 0.7833 - dice_score: 0.7833 - iou: 0.6504 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 9.5367e-10
# Epoch 123/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9978 - dice_coeff: 0.7908 - dice_score: 0.7907 - iou: 0.6569
# Epoch 123: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 40s 702ms/step - loss: 0.2117 - accuracy: 0.9978 - dice_coeff: 0.7908 - dice_score: 0.7907 - iou: 0.6569 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 9.5367e-10
# Epoch 124/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9978 - dice_coeff: 0.7847 - dice_score: 0.7847 - iou: 0.6515
# Epoch 124: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 723ms/step - loss: 0.2163 - accuracy: 0.9978 - dice_coeff: 0.7847 - dice_score: 0.7847 - iou: 0.6515 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8175 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 9.5367e-10
# Epoch 125/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7825 - dice_score: 0.7825 - iou: 0.6497
# Epoch 125: val_dice_coeff did not improve from 0.81837
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 55/55 [==============================] - 41s 697ms/step - loss: 0.2198 - accuracy: 0.9978 - dice_coeff: 0.7825 - dice_score: 0.7825 - iou: 0.6497 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8173 - val_iou: 0.7011 - lr: 9.5367e-10
# Epoch 126/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.9978 - dice_coeff: 0.7745 - dice_score: 0.7745 - iou: 0.6387
# Epoch 126: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 41s 724ms/step - loss: 0.2246 - accuracy: 0.9978 - dice_coeff: 0.7745 - dice_score: 0.7745 - iou: 0.6387 - val_loss: 0.1839 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 4.7684e-10
# Epoch 127/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9978 - dice_coeff: 0.7826 - dice_score: 0.7826 - iou: 0.6521
# Epoch 127: val_dice_coeff did not improve from 0.81837
# 55/55 [==============================] - 37s 651ms/step - loss: 0.2215 - accuracy: 0.9978 - dice_coeff: 0.7826 - dice_score: 0.7826 - iou: 0.6521 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7011 - lr: 4.7684e-10
# Epoch 128/150
# 55/55 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9978 - dice_coeff: 0.7757 - dice_score: 0.7757 - iou: 0.6437
# Epoch 128: val_dice_coeff did not improve from 0.81837
# Restoring model weights from the end of the best epoch: 68.
# 55/55 [==============================] - 39s 665ms/step - loss: 0.2255 - accuracy: 0.9978 - dice_coeff: 0.7757 - dice_score: 0.7757 - iou: 0.6437 - val_loss: 0.1838 - val_accuracy: 0.9989 - val_dice_coeff: 0.8174 - val_dice_score: 0.8174 - val_iou: 0.7012 - lr: 4.7684e-10
# Epoch 128: early stopping
# 2025-02-18 11:59:15.718576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 12s 999ms/step - loss: 0.3073 - accuracy: 0.9986 - dice_coeff: 0.7026 - dice_score: 0.7025 - iou: 0.5603
#
# Generating Training Metrics Visualization...

# %%
print("\nTest Results:")
print(f"Loss: {results[0]:.4f}")
print(f"Accuracy: {results[1]:.4f}")
print(f"Dice Score: {results[2]:.4f}")
print(f"IoU: {results[3]:.4f}")
# Out:
# Test Results:
# Loss: 0.3073
# Accuracy: 0.9986
# Dice Score: 0.7026
# IoU: 0.7025

# %%
print("Generating Augmentation Samples Visualization...")
visualize_augmented_samples(train_gen)
# Out:
# Generating Augmentation Samples Visualization...

# %%
def numpy_dice_coeff(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)

def numpy_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f)
    return (intersection + 0.1) / (union - intersection + 0.1)

def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
print("\nGenerating Segmentation Results Visualization...")
visualize_segmentation_results(model, test_gen)
# Out:
# Generating Segmentation Results Visualization...
# 10/10 [==============================] - 2s 57ms/step

# %%
print(f"\nAll visualizations have been saved to: {OUTPUT_DIRECTORY}")
# Out:
# All visualizations have been saved to: ./output/ISLESfolder

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0009_0038.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0009_0038.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 380ms/step
# Dice Score: 0.9024
# IoU Score: 0.8212

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0013_0045.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0013_0045.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Dice Score: 0.9541
# IoU Score: 0.9120

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0015_0041.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0015_0041.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Dice Score: 0.9601
# IoU Score: 0.9231

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0024_0039.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0024_0039.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Dice Score: 0.8653
# IoU Score: 0.7623

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0031_0036.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0031_0036.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Dice Score: 0.8506
# IoU Score: 0.7399

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0240_0068.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0240_0068.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Dice Score: 1.0000
# IoU Score: 1.0000

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0036_0056.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0036_0056.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Dice Score: 0.3333
# IoU Score: 0.1549

# %%
def grow_small_lesion(image, mask, target_size=45):
    """Grow small lesions to approach 50 pixels while staying within brain boundaries"""
    brain_mask = (image != -1)
    current_size = np.sum(mask > 0)
    if current_size == 0 or current_size >= 50:
        return image, mask
        
    iterations = 0
    grown_mask = mask.copy()
    grown_image = image.copy()
    
    while np.sum(grown_mask > 0) < target_size and iterations < 10:
        kernel = np.ones((3,3), np.uint8)
        dilated = ndimage.binary_dilation(grown_mask, kernel)
        # Only grow within brain boundaries
        dilated = dilated & brain_mask
        new_size = np.sum(dilated > 0)
        
        if new_size > 12: # lesions with minimmal pixels
            break
            
        # Update both mask and image
        grown_mask = dilated
        # Adjust image intensity in grown regions
        new_lesion_area = dilated & ~(mask > 0)
        grown_image[new_lesion_area] = np.mean(image[mask > 0])
        
        iterations += 1
    
    return grown_image, grown_mask.astype(mask.dtype)

def biomechanical_deformation(image, mask, lesion_class):
    """Process small lesions differently"""
    if lesion_class == 1:  # Less than 50 pixels
        image, mask = grow_small_lesion(image, mask)
    
    lesion_pixels = np.where(mask > 0)
    if len(lesion_pixels[0]) == 0:
        return image, mask
    
    scales = {1: 15, 2: 12, 3: 9, 4: 7, 5: 5}
    deform_scale = scales[lesion_class]
    
    centroid = np.array([np.mean(lesion_pixels[0]), np.mean(lesion_pixels[1])])
    y_dist = np.abs(np.indices(image.shape)[0] - centroid[0])
    x_dist = np.abs(np.indices(image.shape)[1] - centroid[1])
    
    tissue_stiffness = np.exp(-0.02 * (x_dist**2 + 0.5*y_dist**2))
    dx = deform_scale * tissue_stiffness * gaussian_filter(np.random.randn(*image.shape), sigma=3)
    dy = deform_scale * tissue_stiffness * gaussian_filter(np.random.randn(*image.shape), sigma=3)
    
    y, x = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
    deformed_coords = np.stack([y + dy * 5, x + dx * 5])
    
    return map_coordinates(image, deformed_coords, order=1, mode='reflect'), map_coordinates(mask, deformed_coords, order=0, mode='constant')

def simulate_hemodynamics(image, mask, lesion_class):
    contrasts = {
        1: (0.5, 1.7),  # Increased contrast for small lesions
        2: (0.4, 1.6), 
        3: (0.5, 1.5),
        4: (0.6, 1.4),
        5: (0.7, 1.3)
    }
    min_contrast, max_contrast = contrasts[lesion_class]
    
    # Create brain mask
    brain_mask = (image != -1)
    
    vessel_mask = gaussian_filter(np.random.binomial(1, 0.03, size=image.shape), sigma=1)
    perfusion_map = gaussian_filter(np.random.normal(1.0, 0.3, size=image.shape), sigma=2)
    
    perfusion_map[vessel_mask > 0.5] *= np.random.uniform(max_contrast - 0.2, max_contrast)
    
    if np.sum(mask > 0) > 0:
        # Enhance lesion visibility
        lesion_area = mask > 0
        perfusion_map[lesion_area] = np.random.uniform(1.3, 1.5)  # Make lesions brighter
        
        distance = ndimage.distance_transform_edt(1 - mask)
        penumbra = (distance < 7) & (mask == 0) & brain_mask
        perfusion_map[penumbra] *= np.random.uniform(min_contrast + 0.3, min_contrast + 0.5)
    
    # Apply perfusion only within brain
    enhanced_image = image.copy()
    enhanced_image[brain_mask] = image[brain_mask] * perfusion_map[brain_mask]
    enhanced_image[~brain_mask] = -1.0
    
    return np.clip(enhanced_image, -1, 1), mask

def attention_occlusion(image, mask):
    # Create precise brain mask
    brain_mask = (image != -1)
    # brain_mask = ndimage.binary_erosion(brain_mask, structure=np.ones((3,3)))
    
    noise_scale = np.random.uniform(3, 6)
    attention_field = gaussian_filter(np.random.randn(*image.shape), sigma=noise_scale)
    attention_field = np.abs(attention_field)
    attention_field = (attention_field - attention_field.min()) / (attention_field.max() - attention_field.min())
    attention_field = attention_field * 0.3 + 0.7  # Reduce effect strength
    
    # Strictly preserve background
    attention_field[~brain_mask] = 1.0
    modulated_image = image * attention_field
    modulated_image[~brain_mask] = -1.0  # Set to background value
    
    return modulated_image, mask

# %%
def visualize_himra_augmentation(image_path, mask_path, output_dir):
    """
    Visualize the original image and the three HIMRA augmentation steps side by side.
    """
    # Load and preprocess original image and mask
    original_image = load_and_preprocess(image_path)
    original_mask = load_and_preprocess(mask_path, is_mask=True)

    # Determine lesion class for class-aware augmentation
    lesion_size = np.sum(original_mask)
    lesion_class = 1 if lesion_size < 50 else 2 if lesion_size < 100 else 3 if lesion_size < 150 else 4 if lesion_size < 200 else 5

    # Apply HIMRA augmentation steps
    biomech_image, biomech_mask = biomechanical_deformation(original_image.copy(), original_mask.copy(), lesion_class)
    hemo_image, hemo_mask = simulate_hemodynamics(biomech_image.copy(), biomech_mask.copy(), lesion_class)
    occluded_image, occluded_mask = attention_occlusion(hemo_image.copy(), hemo_mask.copy())

    # Plot the original image and the three HIMRA steps
    plt.figure(figsize=(20, 10))
    plt.suptitle("HIMRA Augmentation Steps", fontsize=16, y=1.05)

    # Original Image and Mask
    plt.subplot(2, 4, 1)
    plt.imshow(original_image, cmap='gray')
    plt.title("Original Image")
    plt.axis('off')

    # Biomechanical Deformation
    plt.subplot(2, 4, 2)
    plt.imshow(biomech_image, cmap='gray')
    plt.title("Biomechanical Deformation")
    plt.axis('off')

    # Hemodynamic Simulation
    plt.subplot(2, 4, 3)
    plt.imshow(hemo_image, cmap='gray')
    plt.title("Hemodynamic Simulation")
    plt.axis('off')

    # Attention-Guided Occlusion
    plt.subplot(2, 4, 4)
    plt.imshow(occluded_image, cmap='gray')
    plt.title("Attention Occlusion")
    plt.axis('off')
    
    # Masks row
    plt.subplot(2, 4, 5)
    plt.imshow(original_mask, cmap='gray')
    plt.title("Original Mask")
    plt.axis('off')
    
    plt.subplot(2, 4, 6)
    plt.imshow(biomech_mask, cmap='gray')
    plt.title("Deformed Mask")
    plt.axis('off')
    
    plt.subplot(2, 4, 7)
    plt.imshow(hemo_mask, cmap='gray')
    plt.title("Hemodynamic Mask")
    plt.axis('off')
    
    plt.subplot(2, 4, 8)
    plt.imshow(occluded_mask, cmap='gray')
    plt.title("Occluded Mask")
    plt.axis('off')
    
    filename = os.path.basename(image_path).replace('.png', '_himra_steps.png')
    save_path = os.path.join(output_dir, filename)
    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.close()
    return save_path


# Directory to save visualizations
output_dir = os.path.join(OUTPUT_DIRECTORY, 'himra_visualizations')
os.makedirs(output_dir, exist_ok=True)

# Test samples to visualize
test_samples = [
    "slice_sub-strokecase0009_0038.png",
    "slice_sub-strokecase0013_0045.png",
    "slice_sub-strokecase0015_0041.png",
    "slice_sub-strokecase0024_0039.png",
    "slice_sub-strokecase0031_0036.png",
    "slice_sub-strokecase0036_0056.png"
]

# Generate and save visualizations
for sample in test_samples:
    image_path = os.path.join(INPUT_PATH, sample)
    mask_path = os.path.join(MASK_PATH, sample)
    save_path = visualize_himra_augmentation(image_path, mask_path, output_dir)
    print(f"Saved HIMRA visualization for {sample} to {save_path}")
# Out:
# Saved HIMRA visualization for slice_sub-strokecase0009_0038.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0009_0038_himra_steps.png
# Saved HIMRA visualization for slice_sub-strokecase0013_0045.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0013_0045_himra_steps.png
# Saved HIMRA visualization for slice_sub-strokecase0015_0041.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0015_0041_himra_steps.png
# Saved HIMRA visualization for slice_sub-strokecase0024_0039.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0024_0039_himra_steps.png
# Saved HIMRA visualization for slice_sub-strokecase0031_0036.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0031_0036_himra_steps.png
# Saved HIMRA visualization for slice_sub-strokecase0036_0056.png to ./output/ISLESfolder/himra_visualizations/slice_sub-strokecase0036_0056_himra_steps.png
