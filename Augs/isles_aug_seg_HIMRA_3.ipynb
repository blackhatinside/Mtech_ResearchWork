# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import keras.backend as K
from scipy.ndimage import gaussian_filter, map_coordinates
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# 2025-02-14 10:11:48.358588: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-14 10:11:48.400807: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-14 10:11:49.000476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Constants and Paths (unchanged)
BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
AUG_INPUT_PATH = os.path.join(AUG_PATH, "input")
AUG_MASK_PATH = os.path.join(AUG_PATH, "mask")
OUTPUT_DIRECTORY = "./output/ISLESfolder"
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)

# %%
IMG_SIZE = 112
BATCH_SIZE = 4
LEARNINGRATE = 0.0005
EPOCHS = 200
EARLYSTOPPING = 60
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
def dice_coeff(y_true, y_pred):
	y_true_f = K.flatten(y_true)
	y_pred_f = K.flatten(y_pred)
	intersection = K.sum(y_true_f * y_pred_f)
	return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def iou(y_true, y_pred):
	intersection = K.sum(y_true * y_pred)
	union = K.sum(y_true + y_pred)
	return (intersection + 0.1) / (union - intersection + 0.1)

def dice_loss(y_true, y_pred):
	return tf.keras.losses.binary_crossentropy(y_true, y_pred) + (1 - dice_coeff(y_true, y_pred))

def single_dice_loss(y_true, y_pred):
    return 1.0 - dice_score(y_true, y_pred)

def binary_crossentropy_loss(y_true, y_pred):
    return tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

def binary_focal_loss(gamma=2., alpha=0.25):
    def focal_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        alpha_t = y_true * alpha + (K.ones_like(y_true) - y_true) * (1 - alpha)
        p_t = y_true * y_pred + (K.ones_like(y_true) - y_true) * (1 - y_pred)
        focal_loss = - alpha_t * K.pow((K.ones_like(y_true) - p_t), gamma) * K.log(p_t)
        return K.mean(focal_loss)
    return focal_loss

# %%
def load_and_preprocess(file_path, is_mask=False):
	img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
	img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
	if not is_mask:
		img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
	else:
		img = img / 255.0
	return img

# %%
# HIMRA Augmentation Functions
def biomechanical_deformation(image, mask):
	"""
	Applies biomechanically realistic deformation using stiffness-weighted elastic deformation.
	"""
	# Get lesion centroid
	lesion_pixels = np.where(mask > 0)
	if len(lesion_pixels[0]) == 0:
		return image  # No deformation if no lesion

	centroid = np.array([np.mean(lesion_pixels[0]), np.mean(lesion_pixels[1])])

	# Simulate tissue stiffness (higher stiffness near lesion)
	stiffness_map = np.exp(-0.01 * ((np.indices(image.shape)[0] - centroid[0])**2 +
								   (np.indices(image.shape)[1] - centroid[1])**2))

	# Create deformation field
	dx = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=3)
	dy = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=3)

	# Apply deformation
	y, x = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
	indices = np.reshape(y + dy, (-1, 1)), np.reshape(x + dx, (-1, 1))
	deformed_image = map_coordinates(image, indices, order=1, mode='reflect').reshape(image.shape)
	deformed_mask = map_coordinates(mask, indices, order=0, mode='constant').reshape(mask.shape)

	return deformed_image, deformed_mask

def simulate_hemodynamics(image, mask):
	"""
	Simulates hemodynamic effects using synthetic ADC map variations.
	"""
	# Create synthetic ADC map
	adc_map = np.random.normal(1.0, 0.2, size=image.shape)
	adc_map = gaussian_filter(adc_map, sigma=3)

	# Apply hemodynamic effect (stronger near lesions)
	if np.sum(mask) > 0:  # Only apply if lesion exists
		adc_map[mask > 0] *= np.random.uniform(0.7, 1.3)

	return image * adc_map, mask

def attention_occlusion(image, mask, attention_map=None):
	"""
	Applies attention-guided occlusion to simulate adversarial conditions.
	"""
	if attention_map is None:
		attention_map = gaussian_filter(np.random.rand(*image.shape), sigma=2)

	# Create occlusion mask
	occlusion_mask = (attention_map > np.percentile(attention_map, 75)).astype(np.float32)
	occlusion_mask = gaussian_filter(occlusion_mask, sigma=2)

	# Apply occlusion
	occluded_image = image * (1 - occlusion_mask)
	return occluded_image, mask

# %%
class HIMRADataGenerator(tf.keras.utils.Sequence):
	def __init__(self, list_IDs, aug_ids=None, batch_size=BATCH_SIZE, shuffle=True):
		self.batch_size = batch_size
		self.list_IDs = list_IDs
		self.aug_ids = aug_ids if aug_ids is not None else []
		self.all_ids = list_IDs + self.aug_ids
		self.shuffle = shuffle
		self.on_epoch_end()

	def __len__(self):
		return int(np.floor(len(self.all_ids) / self.batch_size))

	def __getitem__(self, index):
		indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
		batch_ids = [self.all_ids[k] for k in indexes]
		return self.__data_generation(batch_ids)

	def on_epoch_end(self):
		self.indexes = np.arange(len(self.all_ids))
		if self.shuffle:
			np.random.shuffle(self.indexes)

	def __data_generation(self, batch_ids):
		X, y = [], []
		for case_id in batch_ids:
			is_aug = case_id in self.aug_ids
			input_dir = AUG_INPUT_PATH if is_aug else INPUT_PATH
			mask_dir = AUG_MASK_PATH if is_aug else MASK_PATH

			input_files = sorted([f for f in os.listdir(input_dir)
								if f.startswith(f'slice_{case_id}') and f.endswith('.png')])

			for f in input_files:
				img_path = os.path.join(input_dir, f)
				mask_path = os.path.join(mask_dir, f)

				img = load_and_preprocess(img_path)
				mask = load_and_preprocess(mask_path, is_mask=True)

				# Apply HIMRA Augmentation
				if is_aug:
					img, mask = biomechanical_deformation(img, mask)
					img, mask = simulate_hemodynamics(img, mask)
					img, mask = attention_occlusion(img, mask)

				X.append(img)
				y.append(mask)

		return np.expand_dims(np.array(X), -1), np.array(y)

# %%
def conv_block(inp, filters):
	x = Conv2D(filters, 3, padding='same', use_bias=False)(inp)
	x = BatchNormalization()(x)
	return Activation('relu')(x)

def attention_gate(x, g, filters):
	g1 = Conv2D(filters, 1)(g)
	x1 = Conv2D(filters, 1)(x)
	out = Activation('relu')(add([g1, x1]))
	out = Conv2D(1, 1, activation='sigmoid')(out)
	return multiply([x, out])

# %%
def create_model():
	inputs = Input((IMG_SIZE, IMG_SIZE, 1))

	# Encoder with reduced filters
	x = conv_block(inputs, 32)
	skip1 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 64)
	skip2 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 128)
	skip3 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 256)
	skip4 = x
	x = MaxPooling2D()(x)

	# Bridge
	x = conv_block(x, 512)

	# Decoder with attention
	x = Conv2DTranspose(256, 3, strides=2, padding='same')(x)
	x = attention_gate(skip4, x, 256)
	x = concatenate([x, skip4])
	x = conv_block(x, 256)

	x = Conv2DTranspose(128, 3, strides=2, padding='same')(x)
	x = attention_gate(skip3, x, 128)
	x = concatenate([x, skip3])
	x = conv_block(x, 128)

	x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
	x = attention_gate(skip2, x, 64)
	x = concatenate([x, skip2])
	x = conv_block(x, 64)

	x = Conv2DTranspose(32, 3, strides=2, padding='same')(x)
	x = attention_gate(skip1, x, 32)
	x = concatenate([x, skip1])
	x = conv_block(x, 32)

	outputs = Conv2D(1, 1, activation='sigmoid')(x)

	model = Model(inputs, outputs)

	model.compile(
		optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNINGRATE),
		loss=dice_loss,
		metrics=['accuracy', dice_coeff, iou]
	)

	return model

# %%
def get_case_ids(path):
	files = sorted([f for f in os.listdir(path) if f.endswith('.png')])
	return sorted(list({f.split('_')[1] for f in files}))

# %%
def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_augmented_samples(train_gen, num_samples=3):
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

case_ids = get_case_ids(INPUT_PATH)
aug_case_ids = get_case_ids(AUG_INPUT_PATH) if os.path.exists(AUG_INPUT_PATH) else []

train_ids, test_ids = train_test_split(case_ids, test_size=0.2, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

print(f"Train: {len(train_ids)}, Val: {len(val_ids)}, Test: {len(test_ids)}, Aug: {len(aug_case_ids)}")

train_gen = HIMRADataGenerator(train_ids, aug_ids=aug_case_ids)
val_gen = HIMRADataGenerator(val_ids, shuffle=False)
test_gen = HIMRADataGenerator(test_ids, shuffle=False)

model = create_model()

print("Model Summary: ", model.summary())

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_dice_coeff', mode='max',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=EARLYSTOPPING, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    workers=4,
    use_multiprocessing=True
)

results = model.evaluate(test_gen)

print("\nGenerating Training Metrics Visualization...")
plot_training_metrics(history)
# Out:
# Train: 160, Val: 40, Test: 50, Aug: 63
# 2025-02-14 10:11:50.199054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14400 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:19:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  288         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   18432       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73728       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 512)    1179648     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  1179904    ['activation_4[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 256)  65792       ['conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  65792       ['activation_3[0][0]']
#
#  add (Add)                      (None, 14, 14, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 256)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 1)    257         ['activation_5[0][0]']
#
#  multiply (Multiply)            (None, 14, 14, 256)  0           ['activation_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 512)  0           ['multiply[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 256)  1179648     ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_6[0][0]']
#  spose)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  16512       ['conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  16512       ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 1)    129         ['activation_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 128)  0           ['activation_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 256)  0           ['multiply_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  294912      ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_8[0][0]']
#  spose)
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   4160        ['conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   4160        ['activation_1[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 1)    65          ['activation_9[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 64)   0           ['activation_1[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 128)  0           ['multiply_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   73728       ['concatenate_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_10[0][0]']
#  spose)                         )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  1056        ['conv2d_transpose_3[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 32  1056        ['activation[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_17[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 32  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  33          ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['activation[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 64  0           ['multiply_3[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 32  18432       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_20[0][0]']
#  rmalization)                   )
#
#  activation_12 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  33          ['activation_12[0][0]']
#
# ==================================================================================================
# Total params: 4,882,373
# Trainable params: 4,879,429
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Model Summary:  None
# Epoch 1/200
# 2025-02-14 10:11:51.198334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-14 10:11:55.260615: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-02-14 10:12:00.324875: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7efb0dc92560 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-14 10:12:00.324902: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2025-02-14 10:12:00.328796: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-14 10:12:00.494964: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  2/55 [>.............................] - ETA: 14:37 - loss: 1.5708 - accuracy: 0.8523 - dice_coeff: 0.0253 - iou: 0.0130
# 2025-02-14 10:12:39.793542: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.793589: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.793605: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.793620: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.793634: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.816719: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.816743: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.816758: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.816773: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-14 10:12:39.816787: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 55/55 [==============================] - ETA: 0s - loss: 1.3504 - accuracy: 0.9420 - dice_coeff: 0.0188 - iou: 0.0095
# 2025-02-14 10:23:08.344399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_dice_coeff improved from -inf to 0.00807, saving model to best_model.h5
# 55/55 [==============================] - 709s 13s/step - loss: 1.3504 - accuracy: 0.9420 - dice_coeff: 0.0188 - iou: 0.0095 - val_loss: 1.4493 - val_accuracy: 0.9961 - val_dice_coeff: 0.0081 - val_iou: 0.0041 - lr: 5.0000e-04
# Epoch 2/200
# 55/55 [==============================] - ETA: 0s - loss: 1.1683 - accuracy: 0.9892 - dice_coeff: 0.0359 - iou: 0.0184
# Epoch 2: val_dice_coeff did not improve from 0.00807
# 55/55 [==============================] - 258s 5s/step - loss: 1.1683 - accuracy: 0.9892 - dice_coeff: 0.0359 - iou: 0.0184 - val_loss: 1.3404 - val_accuracy: 0.9961 - val_dice_coeff: 0.0069 - val_iou: 0.0035 - lr: 5.0000e-04
# Epoch 3/200
# 55/55 [==============================] - ETA: 0s - loss: 1.0787 - accuracy: 0.9923 - dice_coeff: 0.0570 - iou: 0.0295
# Epoch 3: val_dice_coeff did not improve from 0.00807
# 55/55 [==============================] - 168s 3s/step - loss: 1.0787 - accuracy: 0.9923 - dice_coeff: 0.0570 - iou: 0.0295 - val_loss: 1.2465 - val_accuracy: 0.9961 - val_dice_coeff: 0.0064 - val_iou: 0.0032 - lr: 5.0000e-04
# Epoch 4/200
# 55/55 [==============================] - ETA: 0s - loss: 1.0097 - accuracy: 0.9930 - dice_coeff: 0.0849 - iou: 0.0449
# Epoch 4: val_dice_coeff improved from 0.00807 to 0.01072, saving model to best_model.h5
# 55/55 [==============================] - 134s 2s/step - loss: 1.0097 - accuracy: 0.9930 - dice_coeff: 0.0849 - iou: 0.0449 - val_loss: 1.1019 - val_accuracy: 0.9961 - val_dice_coeff: 0.0107 - val_iou: 0.0054 - lr: 5.0000e-04
# Epoch 5/200
# 55/55 [==============================] - ETA: 0s - loss: 0.9505 - accuracy: 0.9935 - dice_coeff: 0.1158 - iou: 0.0624
# Epoch 5: val_dice_coeff improved from 0.01072 to 0.01855, saving model to best_model.h5
# 55/55 [==============================] - 104s 2s/step - loss: 0.9505 - accuracy: 0.9935 - dice_coeff: 0.1158 - iou: 0.0624 - val_loss: 1.0428 - val_accuracy: 0.9963 - val_dice_coeff: 0.0185 - val_iou: 0.0094 - lr: 5.0000e-04
# Epoch 6/200
# 55/55 [==============================] - ETA: 0s - loss: 0.8832 - accuracy: 0.9944 - dice_coeff: 0.1597 - iou: 0.0892
# Epoch 6: val_dice_coeff improved from 0.01855 to 0.07418, saving model to best_model.h5
# 55/55 [==============================] - 120s 2s/step - loss: 0.8832 - accuracy: 0.9944 - dice_coeff: 0.1597 - iou: 0.0892 - val_loss: 0.9629 - val_accuracy: 0.9965 - val_dice_coeff: 0.0742 - val_iou: 0.0392 - lr: 5.0000e-04
# Epoch 7/200
# 40/55 [====================>.........] - ETA: 11s - loss: 0.8269 - accuracy: 0.9941 - dice_coeff: 0.2061 - iou: 0.1178
# 2025-02-14 10:37:25.559755: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 55/55 [==============================] - ETA: 0s - loss: 0.8177 - accuracy: 0.9943 - dice_coeff: 0.2117 - iou: 0.1217
# Epoch 7: val_dice_coeff improved from 0.07418 to 0.09492, saving model to best_model.h5
# 55/55 [==============================] - 85s 2s/step - loss: 0.8177 - accuracy: 0.9943 - dice_coeff: 0.2117 - iou: 0.1217 - val_loss: 0.9436 - val_accuracy: 0.9972 - val_dice_coeff: 0.0949 - val_iou: 0.0509 - lr: 5.0000e-04
# Epoch 8/200
# 55/55 [==============================] - ETA: 0s - loss: 0.7345 - accuracy: 0.9952 - dice_coeff: 0.2903 - iou: 0.1754
# Epoch 8: val_dice_coeff improved from 0.09492 to 0.14411, saving model to best_model.h5
# 55/55 [==============================] - 118s 2s/step - loss: 0.7345 - accuracy: 0.9952 - dice_coeff: 0.2903 - iou: 0.1754 - val_loss: 0.8911 - val_accuracy: 0.9976 - val_dice_coeff: 0.1441 - val_iou: 0.0801 - lr: 5.0000e-04
# Epoch 9/200
# 55/55 [==============================] - ETA: 0s - loss: 0.6364 - accuracy: 0.9957 - dice_coeff: 0.3816 - iou: 0.2455
# Epoch 9: val_dice_coeff improved from 0.14411 to 0.23584, saving model to best_model.h5
# 55/55 [==============================] - 91s 2s/step - loss: 0.6364 - accuracy: 0.9957 - dice_coeff: 0.3816 - iou: 0.2455 - val_loss: 0.7875 - val_accuracy: 0.9975 - val_dice_coeff: 0.2358 - val_iou: 0.1385 - lr: 5.0000e-04
# Epoch 10/200
# 55/55 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.9961 - dice_coeff: 0.4354 - iou: 0.2896
# Epoch 10: val_dice_coeff improved from 0.23584 to 0.31980, saving model to best_model.h5
# 55/55 [==============================] - 71s 1s/step - loss: 0.5789 - accuracy: 0.9961 - dice_coeff: 0.4354 - iou: 0.2896 - val_loss: 0.7052 - val_accuracy: 0.9978 - val_dice_coeff: 0.3198 - val_iou: 0.2007 - lr: 5.0000e-04
# Epoch 11/200
# 55/55 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.9964 - dice_coeff: 0.5086 - iou: 0.3527
# Epoch 11: val_dice_coeff improved from 0.31980 to 0.39833, saving model to best_model.h5
# 55/55 [==============================] - 65s 1s/step - loss: 0.4958 - accuracy: 0.9964 - dice_coeff: 0.5086 - iou: 0.3527 - val_loss: 0.6152 - val_accuracy: 0.9972 - val_dice_coeff: 0.3983 - val_iou: 0.2625 - lr: 5.0000e-04
# Epoch 12/200
# 55/55 [==============================] - ETA: 0s - loss: 0.4463 - accuracy: 0.9967 - dice_coeff: 0.5656 - iou: 0.4053
# Epoch 12: val_dice_coeff improved from 0.39833 to 0.54009, saving model to best_model.h5
# 55/55 [==============================] - 54s 960ms/step - loss: 0.4463 - accuracy: 0.9967 - dice_coeff: 0.5656 - iou: 0.4053 - val_loss: 0.4816 - val_accuracy: 0.9978 - val_dice_coeff: 0.5401 - val_iou: 0.3886 - lr: 5.0000e-04
# Epoch 13/200
# 55/55 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.9967 - dice_coeff: 0.6004 - iou: 0.4412
# Epoch 13: val_dice_coeff improved from 0.54009 to 0.59042, saving model to best_model.h5
# 55/55 [==============================] - 83s 2s/step - loss: 0.4114 - accuracy: 0.9967 - dice_coeff: 0.6004 - iou: 0.4412 - val_loss: 0.4263 - val_accuracy: 0.9981 - val_dice_coeff: 0.5904 - val_iou: 0.4374 - lr: 5.0000e-04
# Epoch 14/200
# 55/55 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.9964 - dice_coeff: 0.5843 - iou: 0.4296
# Epoch 14: val_dice_coeff improved from 0.59042 to 0.61028, saving model to best_model.h5
# 55/55 [==============================] - 36s 626ms/step - loss: 0.4319 - accuracy: 0.9964 - dice_coeff: 0.5843 - iou: 0.4296 - val_loss: 0.4054 - val_accuracy: 0.9979 - val_dice_coeff: 0.6103 - val_iou: 0.4596 - lr: 5.0000e-04
# Epoch 15/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3904 - accuracy: 0.9967 - dice_coeff: 0.6218 - iou: 0.4694
# Epoch 15: val_dice_coeff did not improve from 0.61028
# 55/55 [==============================] - 48s 849ms/step - loss: 0.3904 - accuracy: 0.9967 - dice_coeff: 0.6218 - iou: 0.4694 - val_loss: 0.4959 - val_accuracy: 0.9975 - val_dice_coeff: 0.5226 - val_iou: 0.3791 - lr: 5.0000e-04
# Epoch 16/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.9969 - dice_coeff: 0.6552 - iou: 0.4996
# Epoch 16: val_dice_coeff improved from 0.61028 to 0.67567, saving model to best_model.h5
# 55/55 [==============================] - 44s 778ms/step - loss: 0.3595 - accuracy: 0.9969 - dice_coeff: 0.6552 - iou: 0.4996 - val_loss: 0.3423 - val_accuracy: 0.9983 - val_dice_coeff: 0.6757 - val_iou: 0.5356 - lr: 5.0000e-04
# Epoch 17/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.9968 - dice_coeff: 0.6685 - iou: 0.5127
# Epoch 17: val_dice_coeff did not improve from 0.67567
# 55/55 [==============================] - 90s 2s/step - loss: 0.3491 - accuracy: 0.9968 - dice_coeff: 0.6685 - iou: 0.5127 - val_loss: 0.4126 - val_accuracy: 0.9978 - val_dice_coeff: 0.6022 - val_iou: 0.4525 - lr: 5.0000e-04
# Epoch 18/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.9969 - dice_coeff: 0.6907 - iou: 0.5371
# Epoch 18: val_dice_coeff did not improve from 0.67567
# 55/55 [==============================] - 35s 617ms/step - loss: 0.3274 - accuracy: 0.9969 - dice_coeff: 0.6907 - iou: 0.5371 - val_loss: 0.3685 - val_accuracy: 0.9980 - val_dice_coeff: 0.6464 - val_iou: 0.4955 - lr: 5.0000e-04
# Epoch 19/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.9969 - dice_coeff: 0.6588 - iou: 0.5046
# Epoch 19: val_dice_coeff did not improve from 0.67567
# 55/55 [==============================] - 35s 631ms/step - loss: 0.3540 - accuracy: 0.9969 - dice_coeff: 0.6588 - iou: 0.5046 - val_loss: 0.3559 - val_accuracy: 0.9980 - val_dice_coeff: 0.6613 - val_iou: 0.5126 - lr: 5.0000e-04
# Epoch 20/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.9971 - dice_coeff: 0.6962 - iou: 0.5422
# Epoch 20: val_dice_coeff did not improve from 0.67567
# 55/55 [==============================] - 36s 626ms/step - loss: 0.3174 - accuracy: 0.9971 - dice_coeff: 0.6962 - iou: 0.5422 - val_loss: 0.3990 - val_accuracy: 0.9977 - val_dice_coeff: 0.6142 - val_iou: 0.4633 - lr: 5.0000e-04
# Epoch 21/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9971 - dice_coeff: 0.7095 - iou: 0.5588
# Epoch 21: val_dice_coeff improved from 0.67567 to 0.68991, saving model to best_model.h5
# 55/55 [==============================] - 60s 1s/step - loss: 0.3091 - accuracy: 0.9971 - dice_coeff: 0.7095 - iou: 0.5588 - val_loss: 0.3240 - val_accuracy: 0.9982 - val_dice_coeff: 0.6899 - val_iou: 0.5433 - lr: 5.0000e-04
# Epoch 22/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.9971 - dice_coeff: 0.6800 - iou: 0.5268
# Epoch 22: val_dice_coeff did not improve from 0.68991
# 55/55 [==============================] - 57s 1s/step - loss: 0.3360 - accuracy: 0.9971 - dice_coeff: 0.6800 - iou: 0.5268 - val_loss: 0.4144 - val_accuracy: 0.9980 - val_dice_coeff: 0.6037 - val_iou: 0.4547 - lr: 5.0000e-04
# Epoch 23/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.9970 - dice_coeff: 0.7007 - iou: 0.5510
# Epoch 23: val_dice_coeff improved from 0.68991 to 0.71202, saving model to best_model.h5
# 55/55 [==============================] - 46s 826ms/step - loss: 0.3195 - accuracy: 0.9970 - dice_coeff: 0.7007 - iou: 0.5510 - val_loss: 0.3033 - val_accuracy: 0.9983 - val_dice_coeff: 0.7120 - val_iou: 0.5695 - lr: 5.0000e-04
# Epoch 24/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.9975 - dice_coeff: 0.7339 - iou: 0.5875
# Epoch 24: val_dice_coeff did not improve from 0.71202
# 55/55 [==============================] - 36s 630ms/step - loss: 0.2815 - accuracy: 0.9975 - dice_coeff: 0.7339 - iou: 0.5875 - val_loss: 0.3280 - val_accuracy: 0.9981 - val_dice_coeff: 0.6845 - val_iou: 0.5380 - lr: 5.0000e-04
# Epoch 25/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.9971 - dice_coeff: 0.7170 - iou: 0.5693
# Epoch 25: val_dice_coeff did not improve from 0.71202
# 55/55 [==============================] - 47s 841ms/step - loss: 0.2973 - accuracy: 0.9971 - dice_coeff: 0.7170 - iou: 0.5693 - val_loss: 0.3573 - val_accuracy: 0.9979 - val_dice_coeff: 0.6639 - val_iou: 0.5205 - lr: 5.0000e-04
# Epoch 26/200
# 55/55 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.9971 - dice_coeff: 0.7088 - iou: 0.5569
# Epoch 26: val_dice_coeff did not improve from 0.71202
# 55/55 [==============================] - 53s 945ms/step - loss: 0.3094 - accuracy: 0.9971 - dice_coeff: 0.7088 - iou: 0.5569 - val_loss: 0.3211 - val_accuracy: 0.9981 - val_dice_coeff: 0.6933 - val_iou: 0.5502 - lr: 5.0000e-04
# Epoch 27/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.9972 - dice_coeff: 0.7163 - iou: 0.5682
# Epoch 27: val_dice_coeff did not improve from 0.71202
# 55/55 [==============================] - 36s 622ms/step - loss: 0.2992 - accuracy: 0.9972 - dice_coeff: 0.7163 - iou: 0.5682 - val_loss: 0.3451 - val_accuracy: 0.9979 - val_dice_coeff: 0.6751 - val_iou: 0.5338 - lr: 5.0000e-04
# Epoch 28/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.9973 - dice_coeff: 0.7311 - iou: 0.5846
# Epoch 28: val_dice_coeff improved from 0.71202 to 0.75482, saving model to best_model.h5
# 55/55 [==============================] - 77s 1s/step - loss: 0.2840 - accuracy: 0.9973 - dice_coeff: 0.7311 - iou: 0.5846 - val_loss: 0.2574 - val_accuracy: 0.9985 - val_dice_coeff: 0.7548 - val_iou: 0.6213 - lr: 5.0000e-04
# Epoch 29/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.9973 - dice_coeff: 0.7349 - iou: 0.5908
# Epoch 29: val_dice_coeff did not improve from 0.75482
# 55/55 [==============================] - 52s 937ms/step - loss: 0.2801 - accuracy: 0.9973 - dice_coeff: 0.7349 - iou: 0.5908 - val_loss: 0.2611 - val_accuracy: 0.9985 - val_dice_coeff: 0.7509 - val_iou: 0.6170 - lr: 5.0000e-04
# Epoch 30/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2712 - accuracy: 0.9973 - dice_coeff: 0.7449 - iou: 0.6005
# Epoch 30: val_dice_coeff did not improve from 0.75482
# 55/55 [==============================] - 54s 973ms/step - loss: 0.2712 - accuracy: 0.9973 - dice_coeff: 0.7449 - iou: 0.6005 - val_loss: 0.3327 - val_accuracy: 0.9981 - val_dice_coeff: 0.6845 - val_iou: 0.5401 - lr: 5.0000e-04
# Epoch 31/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9973 - dice_coeff: 0.7433 - iou: 0.6047
# Epoch 31: val_dice_coeff improved from 0.75482 to 0.75583, saving model to best_model.h5
# 55/55 [==============================] - 47s 844ms/step - loss: 0.2731 - accuracy: 0.9973 - dice_coeff: 0.7433 - iou: 0.6047 - val_loss: 0.2548 - val_accuracy: 0.9985 - val_dice_coeff: 0.7558 - val_iou: 0.6223 - lr: 5.0000e-04
# Epoch 32/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9974 - dice_coeff: 0.7299 - iou: 0.5861
# Epoch 32: val_dice_coeff did not improve from 0.75583
# 55/55 [==============================] - 35s 620ms/step - loss: 0.2842 - accuracy: 0.9974 - dice_coeff: 0.7299 - iou: 0.5861 - val_loss: 0.3239 - val_accuracy: 0.9983 - val_dice_coeff: 0.6916 - val_iou: 0.5496 - lr: 5.0000e-04
# Epoch 33/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.9974 - dice_coeff: 0.7343 - iou: 0.5897
# Epoch 33: val_dice_coeff improved from 0.75583 to 0.75705, saving model to best_model.h5
# 55/55 [==============================] - 58s 1s/step - loss: 0.2822 - accuracy: 0.9974 - dice_coeff: 0.7343 - iou: 0.5897 - val_loss: 0.2543 - val_accuracy: 0.9985 - val_dice_coeff: 0.7570 - val_iou: 0.6242 - lr: 5.0000e-04
# Epoch 34/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.9974 - dice_coeff: 0.7505 - iou: 0.6104
# Epoch 34: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 55s 977ms/step - loss: 0.2688 - accuracy: 0.9974 - dice_coeff: 0.7505 - iou: 0.6104 - val_loss: 0.3431 - val_accuracy: 0.9979 - val_dice_coeff: 0.6656 - val_iou: 0.5177 - lr: 5.0000e-04
# Epoch 35/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.9973 - dice_coeff: 0.7309 - iou: 0.5860
# Epoch 35: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 63s 1s/step - loss: 0.2880 - accuracy: 0.9973 - dice_coeff: 0.7309 - iou: 0.5860 - val_loss: 0.3476 - val_accuracy: 0.9979 - val_dice_coeff: 0.6654 - val_iou: 0.5160 - lr: 5.0000e-04
# Epoch 36/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9974 - dice_coeff: 0.7597 - iou: 0.6193
# Epoch 36: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 37s 643ms/step - loss: 0.2599 - accuracy: 0.9974 - dice_coeff: 0.7597 - iou: 0.6193 - val_loss: 0.2632 - val_accuracy: 0.9984 - val_dice_coeff: 0.7485 - val_iou: 0.6118 - lr: 5.0000e-04
# Epoch 37/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.9975 - dice_coeff: 0.7528 - iou: 0.6120
# Epoch 37: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 36s 617ms/step - loss: 0.2620 - accuracy: 0.9975 - dice_coeff: 0.7528 - iou: 0.6120 - val_loss: 0.3668 - val_accuracy: 0.9978 - val_dice_coeff: 0.6470 - val_iou: 0.4995 - lr: 5.0000e-04
# Epoch 38/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9973 - dice_coeff: 0.7446 - iou: 0.6004
# Epoch 38: val_dice_coeff did not improve from 0.75705
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 [==============================] - 35s 622ms/step - loss: 0.2738 - accuracy: 0.9973 - dice_coeff: 0.7446 - iou: 0.6004 - val_loss: 0.3183 - val_accuracy: 0.9982 - val_dice_coeff: 0.7019 - val_iou: 0.5666 - lr: 5.0000e-04
# Epoch 39/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.9975 - dice_coeff: 0.7592 - iou: 0.6181
# Epoch 39: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 31s 550ms/step - loss: 0.2562 - accuracy: 0.9975 - dice_coeff: 0.7592 - iou: 0.6181 - val_loss: 0.2713 - val_accuracy: 0.9983 - val_dice_coeff: 0.7409 - val_iou: 0.6019 - lr: 2.5000e-04
# Epoch 40/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9975 - dice_coeff: 0.7697 - iou: 0.6318
# Epoch 40: val_dice_coeff did not improve from 0.75705
# 55/55 [==============================] - 63s 1s/step - loss: 0.2475 - accuracy: 0.9975 - dice_coeff: 0.7697 - iou: 0.6318 - val_loss: 0.2569 - val_accuracy: 0.9985 - val_dice_coeff: 0.7544 - val_iou: 0.6201 - lr: 2.5000e-04
# Epoch 41/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9976 - dice_coeff: 0.7697 - iou: 0.6342
# Epoch 41: val_dice_coeff improved from 0.75705 to 0.76884, saving model to best_model.h5
# 55/55 [==============================] - 37s 633ms/step - loss: 0.2452 - accuracy: 0.9976 - dice_coeff: 0.7697 - iou: 0.6342 - val_loss: 0.2418 - val_accuracy: 0.9985 - val_dice_coeff: 0.7688 - val_iou: 0.6363 - lr: 2.5000e-04
# Epoch 42/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.9976 - dice_coeff: 0.7677 - iou: 0.6317
# Epoch 42: val_dice_coeff improved from 0.76884 to 0.77907, saving model to best_model.h5
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2483 - accuracy: 0.9976 - dice_coeff: 0.7677 - iou: 0.6317 - val_loss: 0.2305 - val_accuracy: 0.9986 - val_dice_coeff: 0.7791 - val_iou: 0.6494 - lr: 2.5000e-04
# Epoch 43/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9976 - dice_coeff: 0.7803 - iou: 0.6480
# Epoch 43: val_dice_coeff did not improve from 0.77907
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2366 - accuracy: 0.9976 - dice_coeff: 0.7803 - iou: 0.6480 - val_loss: 0.2420 - val_accuracy: 0.9985 - val_dice_coeff: 0.7682 - val_iou: 0.6368 - lr: 2.5000e-04
# Epoch 44/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9976 - dice_coeff: 0.7806 - iou: 0.6472
# Epoch 44: val_dice_coeff did not improve from 0.77907
# 55/55 [==============================] - 36s 636ms/step - loss: 0.2355 - accuracy: 0.9976 - dice_coeff: 0.7806 - iou: 0.6472 - val_loss: 0.2396 - val_accuracy: 0.9985 - val_dice_coeff: 0.7712 - val_iou: 0.6393 - lr: 2.5000e-04
# Epoch 45/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9976 - dice_coeff: 0.7788 - iou: 0.6452
# Epoch 45: val_dice_coeff improved from 0.77907 to 0.77912, saving model to best_model.h5
# 55/55 [==============================] - 52s 915ms/step - loss: 0.2368 - accuracy: 0.9976 - dice_coeff: 0.7788 - iou: 0.6452 - val_loss: 0.2311 - val_accuracy: 0.9986 - val_dice_coeff: 0.7791 - val_iou: 0.6505 - lr: 2.5000e-04
# Epoch 46/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9977 - dice_coeff: 0.7869 - iou: 0.6551
# Epoch 46: val_dice_coeff did not improve from 0.77912
# 55/55 [==============================] - 52s 918ms/step - loss: 0.2288 - accuracy: 0.9977 - dice_coeff: 0.7869 - iou: 0.6551 - val_loss: 0.2610 - val_accuracy: 0.9983 - val_dice_coeff: 0.7504 - val_iou: 0.6128 - lr: 2.5000e-04
# Epoch 47/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2313 - accuracy: 0.9977 - dice_coeff: 0.7832 - iou: 0.6501
# Epoch 47: val_dice_coeff did not improve from 0.77912
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 [==============================] - 72s 1s/step - loss: 0.2313 - accuracy: 0.9977 - dice_coeff: 0.7832 - iou: 0.6501 - val_loss: 0.2562 - val_accuracy: 0.9984 - val_dice_coeff: 0.7556 - val_iou: 0.6196 - lr: 2.5000e-04
# Epoch 48/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9978 - dice_coeff: 0.7856 - iou: 0.6555
# Epoch 48: val_dice_coeff did not improve from 0.77912
# 55/55 [==============================] - 36s 610ms/step - loss: 0.2282 - accuracy: 0.9978 - dice_coeff: 0.7856 - iou: 0.6555 - val_loss: 0.2422 - val_accuracy: 0.9985 - val_dice_coeff: 0.7690 - val_iou: 0.6379 - lr: 1.2500e-04
# Epoch 49/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9977 - dice_coeff: 0.7950 - iou: 0.6669
# Epoch 49: val_dice_coeff did not improve from 0.77912
# 55/55 [==============================] - 66s 1s/step - loss: 0.2204 - accuracy: 0.9977 - dice_coeff: 0.7950 - iou: 0.6669 - val_loss: 0.2453 - val_accuracy: 0.9985 - val_dice_coeff: 0.7658 - val_iou: 0.6326 - lr: 1.2500e-04
# Epoch 50/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.9978 - dice_coeff: 0.7824 - iou: 0.6514
# Epoch 50: val_dice_coeff did not improve from 0.77912
# 55/55 [==============================] - 53s 931ms/step - loss: 0.2298 - accuracy: 0.9978 - dice_coeff: 0.7824 - iou: 0.6514 - val_loss: 0.2341 - val_accuracy: 0.9986 - val_dice_coeff: 0.7758 - val_iou: 0.6456 - lr: 1.2500e-04
# Epoch 51/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9978 - dice_coeff: 0.7962 - iou: 0.6679
# Epoch 51: val_dice_coeff improved from 0.77912 to 0.78546, saving model to best_model.h5
# 55/55 [==============================] - 37s 642ms/step - loss: 0.2161 - accuracy: 0.9978 - dice_coeff: 0.7962 - iou: 0.6679 - val_loss: 0.2243 - val_accuracy: 0.9986 - val_dice_coeff: 0.7855 - val_iou: 0.6568 - lr: 1.2500e-04
# Epoch 52/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9978 - dice_coeff: 0.7996 - iou: 0.6716
# Epoch 52: val_dice_coeff did not improve from 0.78546
# 55/55 [==============================] - 36s 621ms/step - loss: 0.2166 - accuracy: 0.9978 - dice_coeff: 0.7996 - iou: 0.6716 - val_loss: 0.2261 - val_accuracy: 0.9986 - val_dice_coeff: 0.7837 - val_iou: 0.6540 - lr: 1.2500e-04
# Epoch 53/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9978 - dice_coeff: 0.7976 - iou: 0.6702
# Epoch 53: val_dice_coeff did not improve from 0.78546
# 55/55 [==============================] - 36s 627ms/step - loss: 0.2157 - accuracy: 0.9978 - dice_coeff: 0.7976 - iou: 0.6702 - val_loss: 0.2309 - val_accuracy: 0.9986 - val_dice_coeff: 0.7789 - val_iou: 0.6491 - lr: 1.2500e-04
# Epoch 54/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7970 - iou: 0.6687
# Epoch 54: val_dice_coeff did not improve from 0.78546
# 55/55 [==============================] - 36s 617ms/step - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7970 - iou: 0.6687 - val_loss: 0.2332 - val_accuracy: 0.9986 - val_dice_coeff: 0.7769 - val_iou: 0.6468 - lr: 1.2500e-04
# Epoch 55/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7962 - iou: 0.6664
# Epoch 55: val_dice_coeff improved from 0.78546 to 0.78547, saving model to best_model.h5
# 55/55 [==============================] - 37s 631ms/step - loss: 0.2184 - accuracy: 0.9978 - dice_coeff: 0.7962 - iou: 0.6664 - val_loss: 0.2245 - val_accuracy: 0.9987 - val_dice_coeff: 0.7855 - val_iou: 0.6582 - lr: 1.2500e-04
# Epoch 56/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.9978 - dice_coeff: 0.8068 - iou: 0.6818
# Epoch 56: val_dice_coeff did not improve from 0.78547
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 55/55 [==============================] - 37s 622ms/step - loss: 0.2099 - accuracy: 0.9978 - dice_coeff: 0.8068 - iou: 0.6818 - val_loss: 0.2523 - val_accuracy: 0.9984 - val_dice_coeff: 0.7592 - val_iou: 0.6230 - lr: 1.2500e-04
# Epoch 57/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9979 - dice_coeff: 0.8020 - iou: 0.6753
# Epoch 57: val_dice_coeff did not improve from 0.78547
# 55/55 [==============================] - 36s 631ms/step - loss: 0.2114 - accuracy: 0.9979 - dice_coeff: 0.8020 - iou: 0.6753 - val_loss: 0.2362 - val_accuracy: 0.9986 - val_dice_coeff: 0.7742 - val_iou: 0.6427 - lr: 6.2500e-05
# Epoch 58/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9979 - dice_coeff: 0.8022 - iou: 0.6750
# Epoch 58: val_dice_coeff did not improve from 0.78547
# 55/55 [==============================] - 36s 627ms/step - loss: 0.2120 - accuracy: 0.9979 - dice_coeff: 0.8022 - iou: 0.6750 - val_loss: 0.2285 - val_accuracy: 0.9986 - val_dice_coeff: 0.7812 - val_iou: 0.6520 - lr: 6.2500e-05
# Epoch 59/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.9979 - dice_coeff: 0.8071 - iou: 0.6817
# Epoch 59: val_dice_coeff did not improve from 0.78547
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2073 - accuracy: 0.9979 - dice_coeff: 0.8071 - iou: 0.6817 - val_loss: 0.2265 - val_accuracy: 0.9986 - val_dice_coeff: 0.7836 - val_iou: 0.6555 - lr: 6.2500e-05
# Epoch 60/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9979 - dice_coeff: 0.8061 - iou: 0.6806
# Epoch 60: val_dice_coeff improved from 0.78547 to 0.78842, saving model to best_model.h5
# 55/55 [==============================] - 36s 636ms/step - loss: 0.2082 - accuracy: 0.9979 - dice_coeff: 0.8061 - iou: 0.6806 - val_loss: 0.2210 - val_accuracy: 0.9986 - val_dice_coeff: 0.7884 - val_iou: 0.6605 - lr: 6.2500e-05
# Epoch 61/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2078 - accuracy: 0.9979 - dice_coeff: 0.8054 - iou: 0.6783
# ...
# Epoch 86: val_dice_coeff did not improve from 0.78986
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 55/55 [==============================] - 45s 809ms/step - loss: 0.2019 - accuracy: 0.9980 - dice_coeff: 0.8124 - iou: 0.6899 - val_loss: 0.2234 - val_accuracy: 0.9987 - val_dice_coeff: 0.7863 - val_iou: 0.6585 - lr: 3.9063e-06
# Epoch 87/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9980 - dice_coeff: 0.8085 - iou: 0.6842
# Epoch 87: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 627ms/step - loss: 0.2039 - accuracy: 0.9980 - dice_coeff: 0.8085 - iou: 0.6842 - val_loss: 0.2235 - val_accuracy: 0.9987 - val_dice_coeff: 0.7862 - val_iou: 0.6584 - lr: 1.9531e-06
# Epoch 88/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9980 - dice_coeff: 0.8195 - iou: 0.6992
# Epoch 88: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 636ms/step - loss: 0.1947 - accuracy: 0.9980 - dice_coeff: 0.8195 - iou: 0.6992 - val_loss: 0.2235 - val_accuracy: 0.9986 - val_dice_coeff: 0.7862 - val_iou: 0.6583 - lr: 1.9531e-06
# Epoch 89/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9980 - dice_coeff: 0.8216 - iou: 0.7011
# Epoch 89: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 629ms/step - loss: 0.1922 - accuracy: 0.9980 - dice_coeff: 0.8216 - iou: 0.7011 - val_loss: 0.2235 - val_accuracy: 0.9986 - val_dice_coeff: 0.7862 - val_iou: 0.6583 - lr: 1.9531e-06
# Epoch 90/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9980 - dice_coeff: 0.8160 - iou: 0.6944
# Epoch 90: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 53s 950ms/step - loss: 0.1987 - accuracy: 0.9980 - dice_coeff: 0.8160 - iou: 0.6944 - val_loss: 0.2231 - val_accuracy: 0.9987 - val_dice_coeff: 0.7866 - val_iou: 0.6588 - lr: 1.9531e-06
# Epoch 91/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9980 - dice_coeff: 0.8146 - iou: 0.6934
# Epoch 91: val_dice_coeff did not improve from 0.78986
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 55/55 [==============================] - 36s 639ms/step - loss: 0.2002 - accuracy: 0.9980 - dice_coeff: 0.8146 - iou: 0.6934 - val_loss: 0.2230 - val_accuracy: 0.9987 - val_dice_coeff: 0.7867 - val_iou: 0.6590 - lr: 1.9531e-06
# Epoch 92/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9980 - dice_coeff: 0.8156 - iou: 0.6926
# Epoch 92: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 33s 561ms/step - loss: 0.1962 - accuracy: 0.9980 - dice_coeff: 0.8156 - iou: 0.6926 - val_loss: 0.2227 - val_accuracy: 0.9987 - val_dice_coeff: 0.7870 - val_iou: 0.6594 - lr: 9.7656e-07
# Epoch 93/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9980 - dice_coeff: 0.8166 - iou: 0.6936
# Epoch 93: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 38s 655ms/step - loss: 0.1959 - accuracy: 0.9980 - dice_coeff: 0.8166 - iou: 0.6936 - val_loss: 0.2229 - val_accuracy: 0.9987 - val_dice_coeff: 0.7868 - val_iou: 0.6590 - lr: 9.7656e-07
# Epoch 94/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.9980 - dice_coeff: 0.8176 - iou: 0.6961
# Epoch 94: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 638ms/step - loss: 0.1964 - accuracy: 0.9980 - dice_coeff: 0.8176 - iou: 0.6961 - val_loss: 0.2230 - val_accuracy: 0.9987 - val_dice_coeff: 0.7867 - val_iou: 0.6589 - lr: 9.7656e-07
# Epoch 95/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9980 - dice_coeff: 0.8176 - iou: 0.6957
# Epoch 95: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 627ms/step - loss: 0.1968 - accuracy: 0.9980 - dice_coeff: 0.8176 - iou: 0.6957 - val_loss: 0.2232 - val_accuracy: 0.9987 - val_dice_coeff: 0.7865 - val_iou: 0.6586 - lr: 9.7656e-07
# Epoch 96/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9980 - dice_coeff: 0.8196 - iou: 0.6981
# Epoch 96: val_dice_coeff did not improve from 0.78986
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 55/55 [==============================] - 37s 631ms/step - loss: 0.1929 - accuracy: 0.9980 - dice_coeff: 0.8196 - iou: 0.6981 - val_loss: 0.2228 - val_accuracy: 0.9987 - val_dice_coeff: 0.7869 - val_iou: 0.6591 - lr: 9.7656e-07
# Epoch 97/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9979 - dice_coeff: 0.8185 - iou: 0.6970
# Epoch 97: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 644ms/step - loss: 0.1970 - accuracy: 0.9979 - dice_coeff: 0.8185 - iou: 0.6970 - val_loss: 0.2233 - val_accuracy: 0.9986 - val_dice_coeff: 0.7864 - val_iou: 0.6585 - lr: 4.8828e-07
# Epoch 98/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9980 - dice_coeff: 0.8138 - iou: 0.6916
# Epoch 98: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 632ms/step - loss: 0.1989 - accuracy: 0.9980 - dice_coeff: 0.8138 - iou: 0.6916 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7866 - val_iou: 0.6588 - lr: 4.8828e-07
# Epoch 99/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9980 - dice_coeff: 0.8191 - iou: 0.6967
# Epoch 99: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 642ms/step - loss: 0.1965 - accuracy: 0.9980 - dice_coeff: 0.8191 - iou: 0.6967 - val_loss: 0.2232 - val_accuracy: 0.9986 - val_dice_coeff: 0.7865 - val_iou: 0.6587 - lr: 4.8828e-07
# Epoch 100/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9980 - dice_coeff: 0.8215 - iou: 0.7005
# Epoch 100: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 638ms/step - loss: 0.1935 - accuracy: 0.9980 - dice_coeff: 0.8215 - iou: 0.7005 - val_loss: 0.2233 - val_accuracy: 0.9986 - val_dice_coeff: 0.7864 - val_iou: 0.6585 - lr: 4.8828e-07
# Epoch 101/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9980 - dice_coeff: 0.8151 - iou: 0.6937
# Epoch 101: val_dice_coeff did not improve from 0.78986
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 55/55 [==============================] - 46s 823ms/step - loss: 0.1976 - accuracy: 0.9980 - dice_coeff: 0.8151 - iou: 0.6937 - val_loss: 0.2229 - val_accuracy: 0.9987 - val_dice_coeff: 0.7868 - val_iou: 0.6590 - lr: 4.8828e-07
# Epoch 102/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9980 - dice_coeff: 0.8161 - iou: 0.6937
# Epoch 102: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 67s 1s/step - loss: 0.1969 - accuracy: 0.9980 - dice_coeff: 0.8161 - iou: 0.6937 - val_loss: 0.2231 - val_accuracy: 0.9986 - val_dice_coeff: 0.7866 - val_iou: 0.6587 - lr: 2.4414e-07
# Epoch 103/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9980 - dice_coeff: 0.8220 - iou: 0.7013
# Epoch 103: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 636ms/step - loss: 0.1923 - accuracy: 0.9980 - dice_coeff: 0.8220 - iou: 0.7013 - val_loss: 0.2233 - val_accuracy: 0.9986 - val_dice_coeff: 0.7864 - val_iou: 0.6584 - lr: 2.4414e-07
# Epoch 104/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9980 - dice_coeff: 0.8070 - iou: 0.6811
# Epoch 104: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 638ms/step - loss: 0.2031 - accuracy: 0.9980 - dice_coeff: 0.8070 - iou: 0.6811 - val_loss: 0.2231 - val_accuracy: 0.9986 - val_dice_coeff: 0.7866 - val_iou: 0.6588 - lr: 2.4414e-07
# Epoch 105/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9980 - dice_coeff: 0.8129 - iou: 0.6895
# Epoch 105: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 634ms/step - loss: 0.2003 - accuracy: 0.9980 - dice_coeff: 0.8129 - iou: 0.6895 - val_loss: 0.2232 - val_accuracy: 0.9986 - val_dice_coeff: 0.7865 - val_iou: 0.6586 - lr: 2.4414e-07
# Epoch 106/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9980 - dice_coeff: 0.8196 - iou: 0.6990
# Epoch 106: val_dice_coeff did not improve from 0.78986
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 55/55 [==============================] - 36s 644ms/step - loss: 0.1952 - accuracy: 0.9980 - dice_coeff: 0.8196 - iou: 0.6990 - val_loss: 0.2232 - val_accuracy: 0.9986 - val_dice_coeff: 0.7865 - val_iou: 0.6586 - lr: 2.4414e-07
# Epoch 107/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9980 - dice_coeff: 0.8134 - iou: 0.6910
# Epoch 107: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 655ms/step - loss: 0.1994 - accuracy: 0.9980 - dice_coeff: 0.8134 - iou: 0.6910 - val_loss: 0.2234 - val_accuracy: 0.9986 - val_dice_coeff: 0.7863 - val_iou: 0.6584 - lr: 1.2207e-07
# Epoch 108/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9980 - dice_coeff: 0.8152 - iou: 0.6929
# Epoch 108: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 650ms/step - loss: 0.1976 - accuracy: 0.9980 - dice_coeff: 0.8152 - iou: 0.6929 - val_loss: 0.2233 - val_accuracy: 0.9986 - val_dice_coeff: 0.7864 - val_iou: 0.6585 - lr: 1.2207e-07
# Epoch 109/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9980 - dice_coeff: 0.8221 - iou: 0.7021
# Epoch 109: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 645ms/step - loss: 0.1913 - accuracy: 0.9980 - dice_coeff: 0.8221 - iou: 0.7021 - val_loss: 0.2235 - val_accuracy: 0.9986 - val_dice_coeff: 0.7862 - val_iou: 0.6583 - lr: 1.2207e-07
# Epoch 110/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9980 - dice_coeff: 0.8134 - iou: 0.6908
# Epoch 110: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 630ms/step - loss: 0.2012 - accuracy: 0.9980 - dice_coeff: 0.8134 - iou: 0.6908 - val_loss: 0.2230 - val_accuracy: 0.9987 - val_dice_coeff: 0.7866 - val_iou: 0.6589 - lr: 1.2207e-07
# Epoch 111/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9980 - dice_coeff: 0.8206 - iou: 0.7001
# Epoch 111: val_dice_coeff did not improve from 0.78986
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 55/55 [==============================] - 37s 634ms/step - loss: 0.1925 - accuracy: 0.9980 - dice_coeff: 0.8206 - iou: 0.7001 - val_loss: 0.2232 - val_accuracy: 0.9987 - val_dice_coeff: 0.7865 - val_iou: 0.6587 - lr: 1.2207e-07
# Epoch 112/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9980 - dice_coeff: 0.8157 - iou: 0.6937
# Epoch 112: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 641ms/step - loss: 0.1995 - accuracy: 0.9980 - dice_coeff: 0.8157 - iou: 0.6937 - val_loss: 0.2232 - val_accuracy: 0.9987 - val_dice_coeff: 0.7865 - val_iou: 0.6587 - lr: 6.1035e-08
# Epoch 113/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9980 - dice_coeff: 0.8138 - iou: 0.6917
# Epoch 113: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 36s 634ms/step - loss: 0.2006 - accuracy: 0.9980 - dice_coeff: 0.8138 - iou: 0.6917 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7867 - val_iou: 0.6589 - lr: 6.1035e-08
# Epoch 114/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9980 - dice_coeff: 0.8191 - iou: 0.6984
# Epoch 114: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 32s 553ms/step - loss: 0.1956 - accuracy: 0.9980 - dice_coeff: 0.8191 - iou: 0.6984 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7867 - val_iou: 0.6588 - lr: 6.1035e-08
# Epoch 115/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9980 - dice_coeff: 0.8175 - iou: 0.6964
# Epoch 115: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 34s 590ms/step - loss: 0.1958 - accuracy: 0.9980 - dice_coeff: 0.8175 - iou: 0.6964 - val_loss: 0.2231 - val_accuracy: 0.9987 - val_dice_coeff: 0.7866 - val_iou: 0.6588 - lr: 6.1035e-08
# Epoch 116/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9980 - dice_coeff: 0.8247 - iou: 0.7049
# Epoch 116: val_dice_coeff did not improve from 0.78986
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 55/55 [==============================] - 37s 649ms/step - loss: 0.1897 - accuracy: 0.9980 - dice_coeff: 0.8247 - iou: 0.7049 - val_loss: 0.2231 - val_accuracy: 0.9987 - val_dice_coeff: 0.7866 - val_iou: 0.6587 - lr: 6.1035e-08
# Epoch 117/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9980 - dice_coeff: 0.8168 - iou: 0.6955
# Epoch 117: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 626ms/step - loss: 0.1967 - accuracy: 0.9980 - dice_coeff: 0.8168 - iou: 0.6955 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7867 - val_iou: 0.6588 - lr: 3.0518e-08
# Epoch 118/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9980 - dice_coeff: 0.8158 - iou: 0.6942
# Epoch 118: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 640ms/step - loss: 0.1955 - accuracy: 0.9980 - dice_coeff: 0.8158 - iou: 0.6942 - val_loss: 0.2228 - val_accuracy: 0.9987 - val_dice_coeff: 0.7869 - val_iou: 0.6592 - lr: 3.0518e-08
# Epoch 119/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9980 - dice_coeff: 0.8247 - iou: 0.7065
# Epoch 119: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 630ms/step - loss: 0.1917 - accuracy: 0.9980 - dice_coeff: 0.8247 - iou: 0.7065 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7867 - val_iou: 0.6589 - lr: 3.0518e-08
# Epoch 120/200
# 55/55 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9980 - dice_coeff: 0.8132 - iou: 0.6906
# Epoch 120: val_dice_coeff did not improve from 0.78986
# 55/55 [==============================] - 37s 637ms/step - loss: 0.2005 - accuracy: 0.9980 - dice_coeff: 0.8132 - iou: 0.6906 - val_loss: 0.2230 - val_accuracy: 0.9986 - val_dice_coeff: 0.7867 - val_iou: 0.6589 - lr: 3.0518e-08
# Epoch 121/200
# 55/55 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9980 - dice_coeff: 0.8145 - iou: 0.6930
# Epoch 121: val_dice_coeff did not improve from 0.78986
# Restoring model weights from the end of the best epoch: 61.
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 55/55 [==============================] - 37s 643ms/step - loss: 0.1973 - accuracy: 0.9980 - dice_coeff: 0.8145 - iou: 0.6930 - val_loss: 0.2229 - val_accuracy: 0.9987 - val_dice_coeff: 0.7868 - val_iou: 0.6590 - lr: 3.0518e-08
# Epoch 121: early stopping
# 2025-02-14 12:01:34.668104: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 13s 1s/step - loss: 0.3110 - accuracy: 0.9985 - dice_coeff: 0.7056 - iou: 0.5581
#
# Generating Training Metrics Visualization...

# %%
print("\nTest Results:")
print(f"Loss: {results[0]:.4f}")
print(f"Accuracy: {results[1]:.4f}")
print(f"Dice Score: {results[2]:.4f}")
print(f"IoU: {results[3]:.4f}")
# Out:
# Test Results:
# Loss: 0.3110
# Accuracy: 0.9985
# Dice Score: 0.7056
# IoU: 0.5581

# %%
print("Generating Augmentation Samples Visualization...")
visualize_augmented_samples(train_gen)
# Out:
# Generating Augmentation Samples Visualization...

# %%
def numpy_dice_coeff(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)

def numpy_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f)
    return (intersection + 0.1) / (union - intersection + 0.1)

def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
print("\nGenerating Segmentation Results Visualization...")
visualize_segmentation_results(model, test_gen)
# Out:
# Generating Segmentation Results Visualization...
# 10/10 [==============================] - 2s 85ms/step

# %%
print(f"\nAll visualizations have been saved to: {OUTPUT_DIRECTORY}")
# Out:
# All visualizations have been saved to: ./output/ISLESfolder

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0009_0038.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0009_0038.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 1s 671ms/step
# Dice Score: 0.9286
# IoU Score: 0.8659

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0013_0045.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0013_0045.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Dice Score: 0.9154
# IoU Score: 0.8437

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0015_0041.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0015_0041.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Dice Score: 0.9785
# IoU Score: 0.9578

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0024_0039.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0024_0039.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Dice Score: 0.8865
# IoU Score: 0.7958

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0031_0036.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0031_0036.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Dice Score: 0.8712
# IoU Score: 0.7717
