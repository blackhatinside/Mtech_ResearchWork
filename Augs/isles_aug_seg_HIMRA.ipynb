# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import keras.backend as K
from scipy.ndimage import gaussian_filter, map_coordinates
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# 2025-02-13 10:39:40.281819: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-13 10:39:40.323838: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-13 10:39:40.916441: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Constants and Paths (unchanged)
BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
AUG_INPUT_PATH = os.path.join(AUG_PATH, "input")
AUG_MASK_PATH = os.path.join(AUG_PATH, "mask")
OUTPUT_DIRECTORY = "./output/ISLESfolder"
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)

# %%
IMG_SIZE = 112
BATCH_SIZE = 4
LEARNINGRATE = 0.001
EPOCHS = 100
EARLYSTOPPING = 40
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
def dice_coeff(y_true, y_pred):
	y_true_f = K.flatten(y_true)
	y_pred_f = K.flatten(y_pred)
	intersection = K.sum(y_true_f * y_pred_f)
	return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def iou(y_true, y_pred):
	intersection = K.sum(y_true * y_pred)
	union = K.sum(y_true + y_pred)
	return (intersection + 0.1) / (union - intersection + 0.1)

def dice_loss(y_true, y_pred):
	return tf.keras.losses.binary_crossentropy(y_true, y_pred) + (1 - dice_coeff(y_true, y_pred))

def single_dice_loss(y_true, y_pred):
    return 1.0 - dice_score(y_true, y_pred)

def binary_crossentropy_loss(y_true, y_pred):
    return tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

def binary_focal_loss(gamma=2., alpha=0.25):
    def focal_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        alpha_t = y_true * alpha + (K.ones_like(y_true) - y_true) * (1 - alpha)
        p_t = y_true * y_pred + (K.ones_like(y_true) - y_true) * (1 - y_pred)
        focal_loss = - alpha_t * K.pow((K.ones_like(y_true) - p_t), gamma) * K.log(p_t)
        return K.mean(focal_loss)
    return focal_loss

# %%
def load_and_preprocess(file_path, is_mask=False):
	img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
	img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
	if not is_mask:
		img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
	else:
		img = img / 255.0
	return img

# %%
# HIMRA Augmentation Functions
def biomechanical_deformation(image, mask):
	"""
	Applies biomechanically realistic deformation using stiffness-weighted elastic deformation.
	"""
	# Get lesion centroid
	lesion_pixels = np.where(mask > 0)
	if len(lesion_pixels[0]) == 0:
		return image  # No deformation if no lesion

	centroid = np.array([np.mean(lesion_pixels[0]), np.mean(lesion_pixels[1])])

	# Simulate tissue stiffness (higher stiffness near lesion)
	stiffness_map = np.exp(-0.01 * ((np.indices(image.shape)[0] - centroid[0])**2 +
								   (np.indices(image.shape)[1] - centroid[1])**2))

	# Create deformation field
	dx = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=5)
	dy = stiffness_map * gaussian_filter(np.random.randn(*image.shape), sigma=5)

	# Apply deformation
	y, x = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
	indices = np.reshape(y + dy, (-1, 1)), np.reshape(x + dx, (-1, 1))
	deformed_image = map_coordinates(image, indices, order=1, mode='reflect').reshape(image.shape)
	deformed_mask = map_coordinates(mask, indices, order=0, mode='constant').reshape(mask.shape)

	return deformed_image, deformed_mask

def simulate_hemodynamics(image, mask):
	"""
	Simulates hemodynamic effects using synthetic ADC map variations.
	"""
	# Create synthetic ADC map
	adc_map = np.random.normal(1.0, 0.2, size=image.shape)
	adc_map = gaussian_filter(adc_map, sigma=3)

	# Apply hemodynamic effect (stronger near lesions)
	if np.sum(mask) > 0:  # Only apply if lesion exists
		adc_map[mask > 0] *= np.random.uniform(0.8, 1.2)

	return image * adc_map, mask

def attention_occlusion(image, mask, attention_map=None):
	"""
	Applies attention-guided occlusion to simulate adversarial conditions.
	"""
	if attention_map is None:
		attention_map = gaussian_filter(np.random.rand(*image.shape), sigma=2)

	# Create occlusion mask
	occlusion_mask = (attention_map > np.percentile(attention_map, 75)).astype(np.float32)
	occlusion_mask = gaussian_filter(occlusion_mask, sigma=2)

	# Apply occlusion
	occluded_image = image * (1 - occlusion_mask)
	return occluded_image, mask

# %%
class HIMRADataGenerator(tf.keras.utils.Sequence):
	def __init__(self, list_IDs, aug_ids=None, batch_size=BATCH_SIZE, shuffle=True):
		self.batch_size = batch_size
		self.list_IDs = list_IDs
		self.aug_ids = aug_ids if aug_ids is not None else []
		self.all_ids = list_IDs + self.aug_ids
		self.shuffle = shuffle
		self.on_epoch_end()

	def __len__(self):
		return int(np.floor(len(self.all_ids) / self.batch_size))

	def __getitem__(self, index):
		indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
		batch_ids = [self.all_ids[k] for k in indexes]
		return self.__data_generation(batch_ids)

	def on_epoch_end(self):
		self.indexes = np.arange(len(self.all_ids))
		if self.shuffle:
			np.random.shuffle(self.indexes)

	def __data_generation(self, batch_ids):
		X, y = [], []
		for case_id in batch_ids:
			is_aug = case_id in self.aug_ids
			input_dir = AUG_INPUT_PATH if is_aug else INPUT_PATH
			mask_dir = AUG_MASK_PATH if is_aug else MASK_PATH

			input_files = sorted([f for f in os.listdir(input_dir)
								if f.startswith(f'slice_{case_id}') and f.endswith('.png')])

			for f in input_files:
				img_path = os.path.join(input_dir, f)
				mask_path = os.path.join(mask_dir, f)

				img = load_and_preprocess(img_path)
				mask = load_and_preprocess(mask_path, is_mask=True)

				# Apply HIMRA Augmentation
				if is_aug:
					img, mask = biomechanical_deformation(img, mask)
					img, mask = simulate_hemodynamics(img, mask)
					img, mask = attention_occlusion(img, mask)

				X.append(img)
				y.append(mask)

		return np.expand_dims(np.array(X), -1), np.array(y)

# %%
def conv_block(inp, filters):
	x = Conv2D(filters, 3, padding='same', use_bias=False)(inp)
	x = BatchNormalization()(x)
	return Activation('relu')(x)

def attention_gate(x, g, filters):
	g1 = Conv2D(filters, 1)(g)
	x1 = Conv2D(filters, 1)(x)
	out = Activation('relu')(add([g1, x1]))
	out = Conv2D(1, 1, activation='sigmoid')(out)
	return multiply([x, out])

# %%
def create_model():
	inputs = Input((IMG_SIZE, IMG_SIZE, 1))

	# Encoder with reduced filters
	x = conv_block(inputs, 32)
	skip1 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 64)
	skip2 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 128)
	skip3 = x
	x = MaxPooling2D()(x)

	x = conv_block(x, 256)
	skip4 = x
	x = MaxPooling2D()(x)

	# Bridge
	x = conv_block(x, 512)

	# Decoder with attention
	x = Conv2DTranspose(256, 3, strides=2, padding='same')(x)
	x = attention_gate(skip4, x, 256)
	x = concatenate([x, skip4])
	x = conv_block(x, 256)

	x = Conv2DTranspose(128, 3, strides=2, padding='same')(x)
	x = attention_gate(skip3, x, 128)
	x = concatenate([x, skip3])
	x = conv_block(x, 128)

	x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
	x = attention_gate(skip2, x, 64)
	x = concatenate([x, skip2])
	x = conv_block(x, 64)

	x = Conv2DTranspose(32, 3, strides=2, padding='same')(x)
	x = attention_gate(skip1, x, 32)
	x = concatenate([x, skip1])
	x = conv_block(x, 32)

	outputs = Conv2D(1, 1, activation='sigmoid')(x)

	model = Model(inputs, outputs)

	model.compile(
		optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNINGRATE),
		loss=dice_loss,
		metrics=['accuracy', dice_coeff, iou]
	)

	return model

# %%
def get_case_ids(path):
	files = sorted([f for f in os.listdir(path) if f.endswith('.png')])
	return sorted(list({f.split('_')[1] for f in files}))

# %%
def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_augmented_samples(train_gen, num_samples=3):
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

case_ids = get_case_ids(INPUT_PATH)
aug_case_ids = get_case_ids(AUG_INPUT_PATH) if os.path.exists(AUG_INPUT_PATH) else []

train_ids, test_ids = train_test_split(case_ids, test_size=0.2, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

print(f"Train: {len(train_ids)}, Val: {len(val_ids)}, Test: {len(test_ids)}, Aug: {len(aug_case_ids)}")

train_gen = HIMRADataGenerator(train_ids, aug_ids=aug_case_ids)
val_gen = HIMRADataGenerator(val_ids, shuffle=False)
test_gen = HIMRADataGenerator(test_ids, shuffle=False)

model = create_model()

print("Model Summary: ", model.summary())

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_dice_coeff', mode='max',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=EARLYSTOPPING, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    workers=4,
    use_multiprocessing=True
)

results = model.evaluate(test_gen)

print("\nGenerating Training Metrics Visualization...")
plot_training_metrics(history)
# Out:
# Train: 160, Val: 40, Test: 50, Aug: 63
# 2025-02-13 10:39:42.187527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14400 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:19:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  288         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   18432       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73728       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 512)    1179648     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  1179904    ['activation_4[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 256)  65792       ['conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  65792       ['activation_3[0][0]']
#
#  add (Add)                      (None, 14, 14, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 256)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 1)    257         ['activation_5[0][0]']
#
#  multiply (Multiply)            (None, 14, 14, 256)  0           ['activation_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 512)  0           ['multiply[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 256)  1179648     ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_6[0][0]']
#  spose)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  16512       ['conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  16512       ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 1)    129         ['activation_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 128)  0           ['activation_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 256)  0           ['multiply_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  294912      ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_8[0][0]']
#  spose)
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   4160        ['conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   4160        ['activation_1[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 1)    65          ['activation_9[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 64)   0           ['activation_1[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 128)  0           ['multiply_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   73728       ['concatenate_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_10[0][0]']
#  spose)                         )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  1056        ['conv2d_transpose_3[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 32  1056        ['activation[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_17[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 32  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  33          ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['activation[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 64  0           ['multiply_3[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 32  18432       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_20[0][0]']
#  rmalization)                   )
#
#  activation_12 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  33          ['activation_12[0][0]']
#
# ==================================================================================================
# Total params: 4,882,373
# Trainable params: 4,879,429
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Model Summary:  None
# Epoch 1/100
# 2025-02-13 10:39:43.974443: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-13 10:39:48.919269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-02-13 10:39:55.677001: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x3b0d4d30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-13 10:39:55.677027: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2025-02-13 10:39:55.680947: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-13 10:39:55.820275: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-02-13 10:39:56.563984: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:39:56.753911: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.63GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:39:56.753959: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.63GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:39:58.050593: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.50GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  1/55 [..............................] - ETA: 28:18 - loss: 1.7600 - accuracy: 0.3976 - dice_coeff: 0.0013 - iou: 6.4223e-04
# 2025-02-13 10:40:21.875559: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:40:22.057289: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.33GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:40:22.057345: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.33GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  4/55 [=>............................] - ETA: 9:53 - loss: 1.5997 - accuracy: 0.7301 - dice_coeff: 0.0061 - iou: 0.0031
# 2025-02-13 10:40:58.737415: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:40:59.027864: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 10:40:59.027930: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 12/55 [=====>........................] - ETA: 10:14 - loss: 1.4632 - accuracy: 0.8671 - dice_coeff: 0.0130 - iou: 0.0066
# 2025-02-13 10:43:01.757931: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 55/55 [==============================] - ETA: 0s - loss: 1.2900 - accuracy: 0.9603 - dice_coeff: 0.0149 - iou: 0.0075
# 2025-02-13 10:51:23.075766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_dice_coeff improved from -inf to 0.00793, saving model to best_model.h5
# 55/55 [==============================] - 721s 13s/step - loss: 1.2900 - accuracy: 0.9603 - dice_coeff: 0.0149 - iou: 0.0075 - val_loss: 1.3013 - val_accuracy: 0.9961 - val_dice_coeff: 0.0079 - val_iou: 0.0040 - lr: 0.0010
# Epoch 2/100
# 55/55 [==============================] - ETA: 0s - loss: 1.1293 - accuracy: 0.9917 - dice_coeff: 0.0226 - iou: 0.0115
# Epoch 2: val_dice_coeff did not improve from 0.00793
# 55/55 [==============================] - 276s 5s/step - loss: 1.1293 - accuracy: 0.9917 - dice_coeff: 0.0226 - iou: 0.0115 - val_loss: 1.1927 - val_accuracy: 0.9961 - val_dice_coeff: 0.0042 - val_iou: 0.0021 - lr: 0.0010
# Epoch 3/100
# 55/55 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.9902 - dice_coeff: 0.0812 - iou: 0.0430
# Epoch 3: val_dice_coeff did not improve from 0.00793
# 55/55 [==============================] - 219s 4s/step - loss: 1.0029 - accuracy: 0.9902 - dice_coeff: 0.0812 - iou: 0.0430 - val_loss: 1.0901 - val_accuracy: 0.9961 - val_dice_coeff: 0.0042 - val_iou: 0.0021 - lr: 0.0010
# Epoch 4/100
# 55/55 [==============================] - ETA: 0s - loss: 0.8709 - accuracy: 0.9928 - dice_coeff: 0.1678 - iou: 0.0946
# Epoch 4: val_dice_coeff improved from 0.00793 to 0.01090, saving model to best_model.h5
# 55/55 [==============================] - 156s 3s/step - loss: 0.8709 - accuracy: 0.9928 - dice_coeff: 0.1678 - iou: 0.0946 - val_loss: 1.0340 - val_accuracy: 0.9962 - val_dice_coeff: 0.0109 - val_iou: 0.0055 - lr: 0.0010
# Epoch 5/100
# 55/55 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.9948 - dice_coeff: 0.3180 - iou: 0.1967
# Epoch 5: val_dice_coeff improved from 0.01090 to 0.06035, saving model to best_model.h5
# 55/55 [==============================] - 176s 3s/step - loss: 0.7047 - accuracy: 0.9948 - dice_coeff: 0.3180 - iou: 0.1967 - val_loss: 0.9642 - val_accuracy: 0.9963 - val_dice_coeff: 0.0603 - val_iou: 0.0315 - lr: 0.0010
# Epoch 6/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.9955 - dice_coeff: 0.4367 - iou: 0.2911
# Epoch 6: val_dice_coeff improved from 0.06035 to 0.21581, saving model to best_model.h5
# 55/55 [==============================] - 87s 2s/step - loss: 0.5782 - accuracy: 0.9955 - dice_coeff: 0.4367 - iou: 0.2911 - val_loss: 0.8088 - val_accuracy: 0.9958 - val_dice_coeff: 0.2158 - val_iou: 0.1262 - lr: 0.0010
# Epoch 7/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.9958 - dice_coeff: 0.5342 - iou: 0.3753
# Epoch 7: val_dice_coeff improved from 0.21581 to 0.40205, saving model to best_model.h5
# 55/55 [==============================] - 81s 1s/step - loss: 0.4842 - accuracy: 0.9958 - dice_coeff: 0.5342 - iou: 0.3753 - val_loss: 0.6207 - val_accuracy: 0.9969 - val_dice_coeff: 0.4021 - val_iou: 0.2646 - lr: 0.0010
# Epoch 8/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.9960 - dice_coeff: 0.5643 - iou: 0.4036
# Epoch 8: val_dice_coeff improved from 0.40205 to 0.45134, saving model to best_model.h5
# 55/55 [==============================] - 67s 876ms/step - loss: 0.4543 - accuracy: 0.9960 - dice_coeff: 0.5643 - iou: 0.4036 - val_loss: 0.5696 - val_accuracy: 0.9974 - val_dice_coeff: 0.4513 - val_iou: 0.3058 - lr: 0.0010
# Epoch 9/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.9964 - dice_coeff: 0.6300 - iou: 0.4685
# Epoch 9: val_dice_coeff improved from 0.45134 to 0.52109, saving model to best_model.h5
# 55/55 [==============================] - 74s 1s/step - loss: 0.3942 - accuracy: 0.9964 - dice_coeff: 0.6300 - iou: 0.4685 - val_loss: 0.5028 - val_accuracy: 0.9971 - val_dice_coeff: 0.5211 - val_iou: 0.3695 - lr: 0.0010
# Epoch 10/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3845 - accuracy: 0.9965 - dice_coeff: 0.6347 - iou: 0.4746
# Epoch 10: val_dice_coeff improved from 0.52109 to 0.59648, saving model to best_model.h5
# 55/55 [==============================] - 116s 2s/step - loss: 0.3845 - accuracy: 0.9965 - dice_coeff: 0.6347 - iou: 0.4746 - val_loss: 0.4221 - val_accuracy: 0.9977 - val_dice_coeff: 0.5965 - val_iou: 0.4421 - lr: 0.0010
# Epoch 11/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.9965 - dice_coeff: 0.6513 - iou: 0.4938
# Epoch 11: val_dice_coeff improved from 0.59648 to 0.62791, saving model to best_model.h5
# 55/55 [==============================] - 56s 1s/step - loss: 0.3703 - accuracy: 0.9965 - dice_coeff: 0.6513 - iou: 0.4938 - val_loss: 0.3899 - val_accuracy: 0.9978 - val_dice_coeff: 0.6279 - val_iou: 0.4748 - lr: 0.0010
# Epoch 12/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.9966 - dice_coeff: 0.6402 - iou: 0.4820
# Epoch 12: val_dice_coeff improved from 0.62791 to 0.64440, saving model to best_model.h5
# 55/55 [==============================] - 82s 1s/step - loss: 0.3806 - accuracy: 0.9966 - dice_coeff: 0.6402 - iou: 0.4820 - val_loss: 0.3717 - val_accuracy: 0.9979 - val_dice_coeff: 0.6444 - val_iou: 0.4926 - lr: 0.0010
# Epoch 13/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.9966 - dice_coeff: 0.6502 - iou: 0.4945
# Epoch 13: val_dice_coeff did not improve from 0.64440
# 55/55 [==============================] - 36s 621ms/step - loss: 0.3731 - accuracy: 0.9966 - dice_coeff: 0.6502 - iou: 0.4945 - val_loss: 0.4590 - val_accuracy: 0.9975 - val_dice_coeff: 0.5591 - val_iou: 0.4079 - lr: 0.0010
# Epoch 14/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.9965 - dice_coeff: 0.6422 - iou: 0.4837
# Epoch 14: val_dice_coeff did not improve from 0.64440
# 55/55 [==============================] - 120s 2s/step - loss: 0.3793 - accuracy: 0.9965 - dice_coeff: 0.6422 - iou: 0.4837 - val_loss: 0.3740 - val_accuracy: 0.9979 - val_dice_coeff: 0.6416 - val_iou: 0.4898 - lr: 0.0010
# Epoch 15/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.9967 - dice_coeff: 0.6604 - iou: 0.5032
# Epoch 15: val_dice_coeff improved from 0.64440 to 0.66675, saving model to best_model.h5
# 55/55 [==============================] - 36s 617ms/step - loss: 0.3614 - accuracy: 0.9967 - dice_coeff: 0.6604 - iou: 0.5032 - val_loss: 0.3494 - val_accuracy: 0.9981 - val_dice_coeff: 0.6667 - val_iou: 0.5170 - lr: 0.0010
# Epoch 16/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.9967 - dice_coeff: 0.6769 - iou: 0.5233
# Epoch 16: val_dice_coeff did not improve from 0.66675
# 55/55 [==============================] - 59s 1s/step - loss: 0.3465 - accuracy: 0.9967 - dice_coeff: 0.6769 - iou: 0.5233 - val_loss: 0.3570 - val_accuracy: 0.9980 - val_dice_coeff: 0.6586 - val_iou: 0.5094 - lr: 0.0010
# Epoch 17/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.9969 - dice_coeff: 0.6904 - iou: 0.5366
# Epoch 17: val_dice_coeff did not improve from 0.66675
# 55/55 [==============================] - 90s 2s/step - loss: 0.3290 - accuracy: 0.9969 - dice_coeff: 0.6904 - iou: 0.5366 - val_loss: 0.3862 - val_accuracy: 0.9978 - val_dice_coeff: 0.6290 - val_iou: 0.4785 - lr: 0.0010
# Epoch 18/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.9969 - dice_coeff: 0.6930 - iou: 0.5410
# Epoch 18: val_dice_coeff did not improve from 0.66675
# 55/55 [==============================] - 61s 887ms/step - loss: 0.3293 - accuracy: 0.9969 - dice_coeff: 0.6930 - iou: 0.5410 - val_loss: 0.3572 - val_accuracy: 0.9979 - val_dice_coeff: 0.6610 - val_iou: 0.5131 - lr: 0.0010
# Epoch 19/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.9968 - dice_coeff: 0.6828 - iou: 0.5299
# Epoch 19: val_dice_coeff did not improve from 0.66675
# 55/55 [==============================] - 51s 914ms/step - loss: 0.3402 - accuracy: 0.9968 - dice_coeff: 0.6828 - iou: 0.5299 - val_loss: 0.3632 - val_accuracy: 0.9978 - val_dice_coeff: 0.6541 - val_iou: 0.5003 - lr: 0.0010
# Epoch 20/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.9969 - dice_coeff: 0.7017 - iou: 0.5492
# Epoch 20: val_dice_coeff improved from 0.66675 to 0.66905, saving model to best_model.h5
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 [==============================] - 36s 616ms/step - loss: 0.3192 - accuracy: 0.9969 - dice_coeff: 0.7017 - iou: 0.5492 - val_loss: 0.3495 - val_accuracy: 0.9980 - val_dice_coeff: 0.6691 - val_iou: 0.5226 - lr: 0.0010
# Epoch 21/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.9970 - dice_coeff: 0.6992 - iou: 0.5462
# Epoch 21: val_dice_coeff improved from 0.66905 to 0.72470, saving model to best_model.h5
# 55/55 [==============================] - 78s 1s/step - loss: 0.3178 - accuracy: 0.9970 - dice_coeff: 0.6992 - iou: 0.5462 - val_loss: 0.2895 - val_accuracy: 0.9983 - val_dice_coeff: 0.7247 - val_iou: 0.5817 - lr: 5.0000e-04
# Epoch 22/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.9971 - dice_coeff: 0.7027 - iou: 0.5552
# Epoch 22: val_dice_coeff did not improve from 0.72470
# 55/55 [==============================] - 36s 629ms/step - loss: 0.3184 - accuracy: 0.9971 - dice_coeff: 0.7027 - iou: 0.5552 - val_loss: 0.3477 - val_accuracy: 0.9979 - val_dice_coeff: 0.6726 - val_iou: 0.5270 - lr: 5.0000e-04
# Epoch 23/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.9971 - dice_coeff: 0.7109 - iou: 0.5618
# Epoch 23: val_dice_coeff did not improve from 0.72470
# 55/55 [==============================] - 54s 943ms/step - loss: 0.3098 - accuracy: 0.9971 - dice_coeff: 0.7109 - iou: 0.5618 - val_loss: 0.2902 - val_accuracy: 0.9983 - val_dice_coeff: 0.7237 - val_iou: 0.5817 - lr: 5.0000e-04
# Epoch 24/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9972 - dice_coeff: 0.7232 - iou: 0.5761
# Epoch 24: val_dice_coeff did not improve from 0.72470
# 55/55 [==============================] - 53s 940ms/step - loss: 0.2937 - accuracy: 0.9972 - dice_coeff: 0.7232 - iou: 0.5761 - val_loss: 0.3248 - val_accuracy: 0.9980 - val_dice_coeff: 0.6891 - val_iou: 0.5409 - lr: 5.0000e-04
# Epoch 25/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.9972 - dice_coeff: 0.7327 - iou: 0.5868
# Epoch 25: val_dice_coeff improved from 0.72470 to 0.74489, saving model to best_model.h5
# 55/55 [==============================] - 32s 573ms/step - loss: 0.2863 - accuracy: 0.9972 - dice_coeff: 0.7327 - iou: 0.5868 - val_loss: 0.2673 - val_accuracy: 0.9984 - val_dice_coeff: 0.7449 - val_iou: 0.6060 - lr: 5.0000e-04
# Epoch 26/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9972 - dice_coeff: 0.7277 - iou: 0.5804
# Epoch 26: val_dice_coeff did not improve from 0.74489
# 55/55 [==============================] - 36s 640ms/step - loss: 0.2914 - accuracy: 0.9972 - dice_coeff: 0.7277 - iou: 0.5804 - val_loss: 0.2711 - val_accuracy: 0.9984 - val_dice_coeff: 0.7420 - val_iou: 0.6030 - lr: 5.0000e-04
# Epoch 27/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.9972 - dice_coeff: 0.7430 - iou: 0.5991
# Epoch 27: val_dice_coeff did not improve from 0.74489
# 55/55 [==============================] - 36s 622ms/step - loss: 0.2758 - accuracy: 0.9972 - dice_coeff: 0.7430 - iou: 0.5991 - val_loss: 0.2699 - val_accuracy: 0.9984 - val_dice_coeff: 0.7423 - val_iou: 0.6032 - lr: 5.0000e-04
# Epoch 28/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.9973 - dice_coeff: 0.7334 - iou: 0.5873
# Epoch 28: val_dice_coeff did not improve from 0.74489
# 55/55 [==============================] - 68s 1s/step - loss: 0.2847 - accuracy: 0.9973 - dice_coeff: 0.7334 - iou: 0.5873 - val_loss: 0.2688 - val_accuracy: 0.9984 - val_dice_coeff: 0.7433 - val_iou: 0.6048 - lr: 5.0000e-04
# Epoch 29/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9974 - dice_coeff: 0.7444 - iou: 0.6015
# Epoch 29: val_dice_coeff did not improve from 0.74489
# 55/55 [==============================] - 36s 620ms/step - loss: 0.2733 - accuracy: 0.9974 - dice_coeff: 0.7444 - iou: 0.6015 - val_loss: 0.2782 - val_accuracy: 0.9983 - val_dice_coeff: 0.7348 - val_iou: 0.5951 - lr: 5.0000e-04
# Epoch 30/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.9972 - dice_coeff: 0.7246 - iou: 0.5803
# Epoch 30: val_dice_coeff did not improve from 0.74489
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 [==============================] - 32s 574ms/step - loss: 0.2938 - accuracy: 0.9972 - dice_coeff: 0.7246 - iou: 0.5803 - val_loss: 0.2944 - val_accuracy: 0.9982 - val_dice_coeff: 0.7191 - val_iou: 0.5760 - lr: 5.0000e-04
# Epoch 31/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.9973 - dice_coeff: 0.7478 - iou: 0.6072
# Epoch 31: val_dice_coeff improved from 0.74489 to 0.76158, saving model to best_model.h5
# 55/55 [==============================] - 38s 674ms/step - loss: 0.2711 - accuracy: 0.9973 - dice_coeff: 0.7478 - iou: 0.6072 - val_loss: 0.2493 - val_accuracy: 0.9984 - val_dice_coeff: 0.7616 - val_iou: 0.6266 - lr: 2.5000e-04
# Epoch 32/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.9974 - dice_coeff: 0.7432 - iou: 0.5997
# Epoch 32: val_dice_coeff did not improve from 0.76158
# 55/55 [==============================] - 54s 980ms/step - loss: 0.2754 - accuracy: 0.9974 - dice_coeff: 0.7432 - iou: 0.5997 - val_loss: 0.2499 - val_accuracy: 0.9984 - val_dice_coeff: 0.7614 - val_iou: 0.6269 - lr: 2.5000e-04
# Epoch 33/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2633 - accuracy: 0.9973 - dice_coeff: 0.7524 - iou: 0.6119
# Epoch 33: val_dice_coeff improved from 0.76158 to 0.76902, saving model to best_model.h5
# 55/55 [==============================] - 37s 643ms/step - loss: 0.2633 - accuracy: 0.9973 - dice_coeff: 0.7524 - iou: 0.6119 - val_loss: 0.2418 - val_accuracy: 0.9985 - val_dice_coeff: 0.7690 - val_iou: 0.6364 - lr: 2.5000e-04
# Epoch 34/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9974 - dice_coeff: 0.7573 - iou: 0.6180
# Epoch 34: val_dice_coeff did not improve from 0.76902
# 55/55 [==============================] - 32s 563ms/step - loss: 0.2641 - accuracy: 0.9974 - dice_coeff: 0.7573 - iou: 0.6180 - val_loss: 0.2447 - val_accuracy: 0.9985 - val_dice_coeff: 0.7663 - val_iou: 0.6341 - lr: 2.5000e-04
# Epoch 35/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9974 - dice_coeff: 0.7525 - iou: 0.6142
# Epoch 35: val_dice_coeff did not improve from 0.76902
# 55/55 [==============================] - 49s 877ms/step - loss: 0.2644 - accuracy: 0.9974 - dice_coeff: 0.7525 - iou: 0.6142 - val_loss: 0.2442 - val_accuracy: 0.9985 - val_dice_coeff: 0.7668 - val_iou: 0.6337 - lr: 2.5000e-04
# Epoch 36/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2598 - accuracy: 0.9974 - dice_coeff: 0.7571 - iou: 0.6154
# Epoch 36: val_dice_coeff improved from 0.76902 to 0.77009, saving model to best_model.h5
# 55/55 [==============================] - 36s 627ms/step - loss: 0.2598 - accuracy: 0.9974 - dice_coeff: 0.7571 - iou: 0.6154 - val_loss: 0.2408 - val_accuracy: 0.9985 - val_dice_coeff: 0.7701 - val_iou: 0.6380 - lr: 2.5000e-04
# Epoch 37/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.9974 - dice_coeff: 0.7588 - iou: 0.6186
# Epoch 37: val_dice_coeff did not improve from 0.77009
# 55/55 [==============================] - 48s 849ms/step - loss: 0.2584 - accuracy: 0.9974 - dice_coeff: 0.7588 - iou: 0.6186 - val_loss: 0.2474 - val_accuracy: 0.9985 - val_dice_coeff: 0.7644 - val_iou: 0.6315 - lr: 2.5000e-04
# Epoch 38/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9975 - dice_coeff: 0.7563 - iou: 0.6174
# Epoch 38: val_dice_coeff did not improve from 0.77009
# 55/55 [==============================] - 37s 649ms/step - loss: 0.2609 - accuracy: 0.9975 - dice_coeff: 0.7563 - iou: 0.6174 - val_loss: 0.2453 - val_accuracy: 0.9985 - val_dice_coeff: 0.7653 - val_iou: 0.6330 - lr: 2.5000e-04
# Epoch 39/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.9975 - dice_coeff: 0.7568 - iou: 0.6180
# Epoch 39: val_dice_coeff did not improve from 0.77009
# 55/55 [==============================] - 36s 627ms/step - loss: 0.2616 - accuracy: 0.9975 - dice_coeff: 0.7568 - iou: 0.6180 - val_loss: 0.2567 - val_accuracy: 0.9985 - val_dice_coeff: 0.7546 - val_iou: 0.6208 - lr: 2.5000e-04
# Epoch 40/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.9974 - dice_coeff: 0.7598 - iou: 0.6200
# Epoch 40: val_dice_coeff did not improve from 0.77009
# 55/55 [==============================] - 37s 635ms/step - loss: 0.2584 - accuracy: 0.9974 - dice_coeff: 0.7598 - iou: 0.6200 - val_loss: 0.2458 - val_accuracy: 0.9985 - val_dice_coeff: 0.7652 - val_iou: 0.6321 - lr: 2.5000e-04
# Epoch 41/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9975 - dice_coeff: 0.7665 - iou: 0.6302
# Epoch 41: val_dice_coeff did not improve from 0.77009
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 [==============================] - 56s 1s/step - loss: 0.2510 - accuracy: 0.9975 - dice_coeff: 0.7665 - iou: 0.6302 - val_loss: 0.2479 - val_accuracy: 0.9985 - val_dice_coeff: 0.7638 - val_iou: 0.6311 - lr: 2.5000e-04
# Epoch 42/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9975 - dice_coeff: 0.7721 - iou: 0.6357
# Epoch 42: val_dice_coeff did not improve from 0.77009
# 55/55 [==============================] - 33s 581ms/step - loss: 0.2458 - accuracy: 0.9975 - dice_coeff: 0.7721 - iou: 0.6357 - val_loss: 0.2409 - val_accuracy: 0.9985 - val_dice_coeff: 0.7691 - val_iou: 0.6380 - lr: 1.2500e-04
# Epoch 43/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.9975 - dice_coeff: 0.7710 - iou: 0.6341
# Epoch 43: val_dice_coeff improved from 0.77009 to 0.77232, saving model to best_model.h5
# 55/55 [==============================] - 51s 923ms/step - loss: 0.2483 - accuracy: 0.9975 - dice_coeff: 0.7710 - iou: 0.6341 - val_loss: 0.2380 - val_accuracy: 0.9986 - val_dice_coeff: 0.7723 - val_iou: 0.6422 - lr: 1.2500e-04
# Epoch 44/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9976 - dice_coeff: 0.7652 - iou: 0.6321
# Epoch 44: val_dice_coeff improved from 0.77232 to 0.77502, saving model to best_model.h5
# 55/55 [==============================] - 54s 958ms/step - loss: 0.2510 - accuracy: 0.9976 - dice_coeff: 0.7652 - iou: 0.6321 - val_loss: 0.2352 - val_accuracy: 0.9986 - val_dice_coeff: 0.7750 - val_iou: 0.6451 - lr: 1.2500e-04
# Epoch 45/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9976 - dice_coeff: 0.7770 - iou: 0.6431
# Epoch 45: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 32s 559ms/step - loss: 0.2406 - accuracy: 0.9976 - dice_coeff: 0.7770 - iou: 0.6431 - val_loss: 0.2473 - val_accuracy: 0.9985 - val_dice_coeff: 0.7635 - val_iou: 0.6308 - lr: 1.2500e-04
# Epoch 46/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9975 - dice_coeff: 0.7768 - iou: 0.6433
# Epoch 46: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 33s 578ms/step - loss: 0.2426 - accuracy: 0.9975 - dice_coeff: 0.7768 - iou: 0.6433 - val_loss: 0.2511 - val_accuracy: 0.9985 - val_dice_coeff: 0.7609 - val_iou: 0.6284 - lr: 1.2500e-04
# Epoch 47/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9976 - dice_coeff: 0.7756 - iou: 0.6423
# Epoch 47: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 38s 654ms/step - loss: 0.2434 - accuracy: 0.9976 - dice_coeff: 0.7756 - iou: 0.6423 - val_loss: 0.2444 - val_accuracy: 0.9985 - val_dice_coeff: 0.7671 - val_iou: 0.6364 - lr: 1.2500e-04
# Epoch 48/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9976 - dice_coeff: 0.7755 - iou: 0.6390
# Epoch 48: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 639ms/step - loss: 0.2414 - accuracy: 0.9976 - dice_coeff: 0.7755 - iou: 0.6390 - val_loss: 0.2419 - val_accuracy: 0.9986 - val_dice_coeff: 0.7689 - val_iou: 0.6377 - lr: 1.2500e-04
# Epoch 49/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9976 - dice_coeff: 0.7711 - iou: 0.6339
# Epoch 49: val_dice_coeff did not improve from 0.77502
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 55/55 [==============================] - 68s 1s/step - loss: 0.2450 - accuracy: 0.9976 - dice_coeff: 0.7711 - iou: 0.6339 - val_loss: 0.2504 - val_accuracy: 0.9985 - val_dice_coeff: 0.7604 - val_iou: 0.6277 - lr: 1.2500e-04
# Epoch 50/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9976 - dice_coeff: 0.7696 - iou: 0.6336
# Epoch 50: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 626ms/step - loss: 0.2481 - accuracy: 0.9976 - dice_coeff: 0.7696 - iou: 0.6336 - val_loss: 0.2494 - val_accuracy: 0.9985 - val_dice_coeff: 0.7612 - val_iou: 0.6293 - lr: 6.2500e-05
# Epoch 51/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9976 - dice_coeff: 0.7778 - iou: 0.6436
# Epoch 51: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 55s 990ms/step - loss: 0.2429 - accuracy: 0.9976 - dice_coeff: 0.7778 - iou: 0.6436 - val_loss: 0.2367 - val_accuracy: 0.9986 - val_dice_coeff: 0.7737 - val_iou: 0.6443 - lr: 6.2500e-05
# Epoch 52/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9978 - dice_coeff: 0.7821 - iou: 0.6518
# Epoch 52: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 641ms/step - loss: 0.2338 - accuracy: 0.9978 - dice_coeff: 0.7821 - iou: 0.6518 - val_loss: 0.2382 - val_accuracy: 0.9986 - val_dice_coeff: 0.7722 - val_iou: 0.6425 - lr: 6.2500e-05
# Epoch 53/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9976 - dice_coeff: 0.7842 - iou: 0.6518
# Epoch 53: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 640ms/step - loss: 0.2343 - accuracy: 0.9976 - dice_coeff: 0.7842 - iou: 0.6518 - val_loss: 0.2464 - val_accuracy: 0.9985 - val_dice_coeff: 0.7640 - val_iou: 0.6323 - lr: 6.2500e-05
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9976 - dice_coeff: 0.7776 - iou: 0.6451
# Epoch 54: val_dice_coeff did not improve from 0.77502
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 55/55 [==============================] - 33s 564ms/step - loss: 0.2392 - accuracy: 0.9976 - dice_coeff: 0.7776 - iou: 0.6451 - val_loss: 0.2398 - val_accuracy: 0.9986 - val_dice_coeff: 0.7705 - val_iou: 0.6407 - lr: 6.2500e-05
# Epoch 55/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9976 - dice_coeff: 0.7830 - iou: 0.6515
# Epoch 55: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 52s 913ms/step - loss: 0.2350 - accuracy: 0.9976 - dice_coeff: 0.7830 - iou: 0.6515 - val_loss: 0.2401 - val_accuracy: 0.9986 - val_dice_coeff: 0.7704 - val_iou: 0.6405 - lr: 3.1250e-05
# Epoch 56/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9976 - dice_coeff: 0.7706 - iou: 0.6368
# Epoch 56: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 647ms/step - loss: 0.2468 - accuracy: 0.9976 - dice_coeff: 0.7706 - iou: 0.6368 - val_loss: 0.2383 - val_accuracy: 0.9986 - val_dice_coeff: 0.7722 - val_iou: 0.6432 - lr: 3.1250e-05
# Epoch 57/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9976 - dice_coeff: 0.7733 - iou: 0.6395
# Epoch 57: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2434 - accuracy: 0.9976 - dice_coeff: 0.7733 - iou: 0.6395 - val_loss: 0.2407 - val_accuracy: 0.9986 - val_dice_coeff: 0.7702 - val_iou: 0.6411 - lr: 3.1250e-05
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 0.9976 - dice_coeff: 0.7795 - iou: 0.6473
# Epoch 58: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 636ms/step - loss: 0.2358 - accuracy: 0.9976 - dice_coeff: 0.7795 - iou: 0.6473 - val_loss: 0.2362 - val_accuracy: 0.9986 - val_dice_coeff: 0.7742 - val_iou: 0.6450 - lr: 3.1250e-05
# Epoch 59/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9977 - dice_coeff: 0.7803 - iou: 0.6462
# Epoch 59: val_dice_coeff did not improve from 0.77502
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 55/55 [==============================] - 36s 627ms/step - loss: 0.2347 - accuracy: 0.9977 - dice_coeff: 0.7803 - iou: 0.6462 - val_loss: 0.2384 - val_accuracy: 0.9986 - val_dice_coeff: 0.7719 - val_iou: 0.6426 - lr: 3.1250e-05
# Epoch 60/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2365 - accuracy: 0.9976 - dice_coeff: 0.7807 - iou: 0.6483
# Epoch 60: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 648ms/step - loss: 0.2365 - accuracy: 0.9976 - dice_coeff: 0.7807 - iou: 0.6483 - val_loss: 0.2368 - val_accuracy: 0.9986 - val_dice_coeff: 0.7736 - val_iou: 0.6448 - lr: 1.5625e-05
# Epoch 61/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9976 - dice_coeff: 0.7828 - iou: 0.6497
# Epoch 61: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 33s 577ms/step - loss: 0.2326 - accuracy: 0.9976 - dice_coeff: 0.7828 - iou: 0.6497 - val_loss: 0.2360 - val_accuracy: 0.9986 - val_dice_coeff: 0.7744 - val_iou: 0.6455 - lr: 1.5625e-05
# Epoch 62/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9976 - dice_coeff: 0.7884 - iou: 0.6574
# Epoch 62: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 38s 659ms/step - loss: 0.2312 - accuracy: 0.9976 - dice_coeff: 0.7884 - iou: 0.6574 - val_loss: 0.2366 - val_accuracy: 0.9986 - val_dice_coeff: 0.7738 - val_iou: 0.6450 - lr: 1.5625e-05
# Epoch 63/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9976 - dice_coeff: 0.7837 - iou: 0.6510
# Epoch 63: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 652ms/step - loss: 0.2329 - accuracy: 0.9976 - dice_coeff: 0.7837 - iou: 0.6510 - val_loss: 0.2372 - val_accuracy: 0.9986 - val_dice_coeff: 0.7732 - val_iou: 0.6447 - lr: 1.5625e-05
# Epoch 64/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.9976 - dice_coeff: 0.7815 - iou: 0.6484
# Epoch 64: val_dice_coeff did not improve from 0.77502
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 55/55 [==============================] - 36s 634ms/step - loss: 0.2363 - accuracy: 0.9976 - dice_coeff: 0.7815 - iou: 0.6484 - val_loss: 0.2375 - val_accuracy: 0.9986 - val_dice_coeff: 0.7730 - val_iou: 0.6443 - lr: 1.5625e-05
# Epoch 65/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9976 - dice_coeff: 0.7768 - iou: 0.6429
# Epoch 65: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 55s 996ms/step - loss: 0.2379 - accuracy: 0.9976 - dice_coeff: 0.7768 - iou: 0.6429 - val_loss: 0.2371 - val_accuracy: 0.9986 - val_dice_coeff: 0.7734 - val_iou: 0.6445 - lr: 7.8125e-06
# Epoch 66/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9976 - dice_coeff: 0.7822 - iou: 0.6480
# Epoch 66: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 586ms/step - loss: 0.2350 - accuracy: 0.9976 - dice_coeff: 0.7822 - iou: 0.6480 - val_loss: 0.2374 - val_accuracy: 0.9986 - val_dice_coeff: 0.7731 - val_iou: 0.6440 - lr: 7.8125e-06
# Epoch 67/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9977 - dice_coeff: 0.7825 - iou: 0.6498
# Epoch 67: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 38s 660ms/step - loss: 0.2346 - accuracy: 0.9977 - dice_coeff: 0.7825 - iou: 0.6498 - val_loss: 0.2379 - val_accuracy: 0.9986 - val_dice_coeff: 0.7726 - val_iou: 0.6437 - lr: 7.8125e-06
# Epoch 68/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9977 - dice_coeff: 0.7790 - iou: 0.6464
# Epoch 68: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 37s 644ms/step - loss: 0.2357 - accuracy: 0.9977 - dice_coeff: 0.7790 - iou: 0.6464 - val_loss: 0.2376 - val_accuracy: 0.9986 - val_dice_coeff: 0.7729 - val_iou: 0.6441 - lr: 7.8125e-06
# Epoch 69/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9976 - dice_coeff: 0.7866 - iou: 0.6561
# Epoch 69: val_dice_coeff did not improve from 0.77502
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 55/55 [==============================] - 36s 637ms/step - loss: 0.2291 - accuracy: 0.9976 - dice_coeff: 0.7866 - iou: 0.6561 - val_loss: 0.2376 - val_accuracy: 0.9986 - val_dice_coeff: 0.7728 - val_iou: 0.6441 - lr: 7.8125e-06
# Epoch 70/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9976 - dice_coeff: 0.7871 - iou: 0.6559
# Epoch 70: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 633ms/step - loss: 0.2288 - accuracy: 0.9976 - dice_coeff: 0.7871 - iou: 0.6559 - val_loss: 0.2377 - val_accuracy: 0.9986 - val_dice_coeff: 0.7728 - val_iou: 0.6440 - lr: 3.9063e-06
# Epoch 71/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9976 - dice_coeff: 0.7847 - iou: 0.6521
# Epoch 71: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 33s 577ms/step - loss: 0.2320 - accuracy: 0.9976 - dice_coeff: 0.7847 - iou: 0.6521 - val_loss: 0.2374 - val_accuracy: 0.9986 - val_dice_coeff: 0.7731 - val_iou: 0.6443 - lr: 3.9063e-06
# Epoch 72/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9977 - dice_coeff: 0.7930 - iou: 0.6631
# Epoch 72: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 33s 587ms/step - loss: 0.2252 - accuracy: 0.9977 - dice_coeff: 0.7930 - iou: 0.6631 - val_loss: 0.2373 - val_accuracy: 0.9986 - val_dice_coeff: 0.7732 - val_iou: 0.6444 - lr: 3.9063e-06
# Epoch 73/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9977 - dice_coeff: 0.7887 - iou: 0.6564
# Epoch 73: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 38s 657ms/step - loss: 0.2280 - accuracy: 0.9977 - dice_coeff: 0.7887 - iou: 0.6564 - val_loss: 0.2371 - val_accuracy: 0.9986 - val_dice_coeff: 0.7734 - val_iou: 0.6446 - lr: 3.9063e-06
# Epoch 74/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9976 - dice_coeff: 0.7841 - iou: 0.6504
# Epoch 74: val_dice_coeff did not improve from 0.77502
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 55/55 [==============================] - 36s 638ms/step - loss: 0.2333 - accuracy: 0.9976 - dice_coeff: 0.7841 - iou: 0.6504 - val_loss: 0.2370 - val_accuracy: 0.9986 - val_dice_coeff: 0.7735 - val_iou: 0.6447 - lr: 3.9063e-06
# Epoch 75/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9977 - dice_coeff: 0.7866 - iou: 0.6549
# Epoch 75: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 638ms/step - loss: 0.2297 - accuracy: 0.9977 - dice_coeff: 0.7866 - iou: 0.6549 - val_loss: 0.2370 - val_accuracy: 0.9986 - val_dice_coeff: 0.7735 - val_iou: 0.6448 - lr: 1.9531e-06
# Epoch 76/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9977 - dice_coeff: 0.7892 - iou: 0.6565
# Epoch 76: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 566ms/step - loss: 0.2280 - accuracy: 0.9977 - dice_coeff: 0.7892 - iou: 0.6565 - val_loss: 0.2370 - val_accuracy: 0.9986 - val_dice_coeff: 0.7735 - val_iou: 0.6448 - lr: 1.9531e-06
# Epoch 77/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9976 - dice_coeff: 0.7876 - iou: 0.6550
# Epoch 77: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 592ms/step - loss: 0.2307 - accuracy: 0.9976 - dice_coeff: 0.7876 - iou: 0.6550 - val_loss: 0.2369 - val_accuracy: 0.9986 - val_dice_coeff: 0.7735 - val_iou: 0.6448 - lr: 1.9531e-06
# Epoch 78/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9976 - dice_coeff: 0.7853 - iou: 0.6523
# Epoch 78: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 582ms/step - loss: 0.2322 - accuracy: 0.9976 - dice_coeff: 0.7853 - iou: 0.6523 - val_loss: 0.2370 - val_accuracy: 0.9986 - val_dice_coeff: 0.7734 - val_iou: 0.6448 - lr: 1.9531e-06
# Epoch 79/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9976 - dice_coeff: 0.7857 - iou: 0.6543
# Epoch 79: val_dice_coeff did not improve from 0.77502
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 55/55 [==============================] - 38s 669ms/step - loss: 0.2323 - accuracy: 0.9976 - dice_coeff: 0.7857 - iou: 0.6543 - val_loss: 0.2373 - val_accuracy: 0.9986 - val_dice_coeff: 0.7732 - val_iou: 0.6446 - lr: 1.9531e-06
# Epoch 80/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9977 - dice_coeff: 0.7770 - iou: 0.6424
# Epoch 80: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 36s 649ms/step - loss: 0.2390 - accuracy: 0.9977 - dice_coeff: 0.7770 - iou: 0.6424 - val_loss: 0.2374 - val_accuracy: 0.9986 - val_dice_coeff: 0.7731 - val_iou: 0.6444 - lr: 9.7656e-07
# Epoch 81/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9977 - dice_coeff: 0.7817 - iou: 0.6488
# Epoch 81: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 33s 565ms/step - loss: 0.2342 - accuracy: 0.9977 - dice_coeff: 0.7817 - iou: 0.6488 - val_loss: 0.2373 - val_accuracy: 0.9986 - val_dice_coeff: 0.7732 - val_iou: 0.6445 - lr: 9.7656e-07
# Epoch 82/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9976 - dice_coeff: 0.7878 - iou: 0.6557
# Epoch 82: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 589ms/step - loss: 0.2304 - accuracy: 0.9976 - dice_coeff: 0.7878 - iou: 0.6557 - val_loss: 0.2371 - val_accuracy: 0.9986 - val_dice_coeff: 0.7733 - val_iou: 0.6446 - lr: 9.7656e-07
# Epoch 83/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9977 - dice_coeff: 0.7833 - iou: 0.6501
# Epoch 83: val_dice_coeff did not improve from 0.77502
# 55/55 [==============================] - 34s 586ms/step - loss: 0.2333 - accuracy: 0.9977 - dice_coeff: 0.7833 - iou: 0.6501 - val_loss: 0.2372 - val_accuracy: 0.9986 - val_dice_coeff: 0.7733 - val_iou: 0.6446 - lr: 9.7656e-07
# Epoch 84/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9977 - dice_coeff: 0.7867 - iou: 0.6553
# Epoch 84: val_dice_coeff did not improve from 0.77502
# Restoring model weights from the end of the best epoch: 44.
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 55/55 [==============================] - 49s 858ms/step - loss: 0.2329 - accuracy: 0.9977 - dice_coeff: 0.7867 - iou: 0.6553 - val_loss: 0.2371 - val_accuracy: 0.9986 - val_dice_coeff: 0.7734 - val_iou: 0.6447 - lr: 9.7656e-07
# Epoch 84: early stopping
# 2025-02-13 12:06:24.283815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 14s 1s/step - loss: 0.3496 - accuracy: 0.9984 - dice_coeff: 0.6713 - iou: 0.5203
#
# Generating Training Metrics Visualization...
# Process Keras_worker_ForkPoolWorker-1333:
# Process Keras_worker_ForkPoolWorker-1336:
# Process Keras_worker_ForkPoolWorker-1334:
# Process Keras_worker_ForkPoolWorker-1335:
# Traceback (most recent call last):
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/adi_ani_tf/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
print("\nTest Results:")
print(f"Loss: {results[0]:.4f}")
print(f"Accuracy: {results[1]:.4f}")
print(f"Dice Score: {results[2]:.4f}")
print(f"IoU: {results[3]:.4f}")
# Out:
# Test Results:
# Loss: 0.3496
# Accuracy: 0.9984
# Dice Score: 0.6713
# IoU: 0.5203

# %%
print("Generating Augmentation Samples Visualization...")
visualize_augmented_samples(train_gen)
# Out:
# Generating Augmentation Samples Visualization...

# %%
def numpy_dice_coeff(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)

def numpy_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f)
    return (intersection + 0.1) / (union - intersection + 0.1)

def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
print("\nGenerating Segmentation Results Visualization...")
visualize_segmentation_results(model, test_gen)
# Out:
# Generating Segmentation Results Visualization...
# 10/10 [==============================] - 2s 84ms/step

# %%
print(f"\nAll visualizations have been saved to: {OUTPUT_DIRECTORY}")
# Out:
# All visualizations have been saved to: ./output/ISLESfolder

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0009_0038.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0009_0038.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 1s 681ms/step
# Dice Score: 0.9398
# IoU Score: 0.8859

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0013_0045.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0013_0045.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Dice Score: 0.9294
# IoU Score: 0.8679

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0015_0041.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0015_0041.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Dice Score: 0.9639
# IoU Score: 0.9301

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0024_0039.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0024_0039.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Dice Score: 0.8703
# IoU Score: 0.7701

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0031_0036.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0031_0036.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Dice Score: 0.8799
# IoU Score: 0.7855
