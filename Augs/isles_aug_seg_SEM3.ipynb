# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import keras.backend as K
import matplotlib.pyplot as plt
from datetime import datetime

# Path configurations
BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
AUG_INPUT_PATH = os.path.join(AUG_PATH, "input")
AUG_MASK_PATH = os.path.join(AUG_PATH, "mask")
OUTPUT_DIRECTORY = "./output/ISLESfolder"
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)

# Model parameters
IMG_SIZE = 112
BATCH_SIZE = 4
LEARNINGRATE = 0.001
EPOCHS = 100
EARLYSTOPPING = 40
scaler = MinMaxScaler(feature_range=(-1, 1))

def dice_coeff(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true + y_pred)
    return (intersection + 0.1) / (union - intersection + 0.1)

def dice_loss(y_true, y_pred):
    return tf.keras.losses.binary_crossentropy(y_true, y_pred) + (1 - dice_coeff(y_true, y_pred))

def conv_block(inp, filters):
    x = Conv2D(filters, 3, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

def attention_gate(x, g, filters):
    g1 = Conv2D(filters, 1)(g)
    x1 = Conv2D(filters, 1)(x)
    out = Activation('relu')(add([g1, x1]))
    out = Conv2D(1, 1, activation='sigmoid')(out)
    return multiply([x, out])

def get_case_ids(path):
    files = sorted([f for f in os.listdir(path) if f.endswith('.png')])
    return sorted(list({f.split('_')[1] for f in files}))

def load_and_preprocess(file_path, is_mask=False):
    img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    if not is_mask:
        img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
    else:
        img = img / 255.0
    return img

def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

def visualize_augmented_samples(train_gen, num_samples=3):
    """
    Display augmented samples with their corresponding masks
    """
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = float(dice_coeff(true_masks[idx], predictions[idx, :, :, 0]))
        iou_score = float(iou(true_masks[idx], predictions[idx, :, :, 0]))
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_IDs, aug_ids=None, batch_size=BATCH_SIZE, shuffle=True):
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.aug_ids = aug_ids if aug_ids is not None else []
        self.all_ids = list_IDs + self.aug_ids
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.all_ids) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_ids = [self.all_ids[k] for k in indexes]
        return self.__data_generation(batch_ids)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.all_ids))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, batch_ids):
        X, y = [], []
        for case_id in batch_ids:
            is_aug = case_id in self.aug_ids
            input_dir = AUG_INPUT_PATH if is_aug else INPUT_PATH
            mask_dir = AUG_MASK_PATH if is_aug else MASK_PATH

            input_files = sorted([f for f in os.listdir(input_dir)
                                if f.startswith(f'slice_{case_id}') and f.endswith('.png')])

            for f in input_files:
                img_path = os.path.join(input_dir, f)
                mask_path = os.path.join(mask_dir, f)

                X.append(load_and_preprocess(img_path))
                y.append(load_and_preprocess(mask_path, is_mask=True))

        return np.expand_dims(np.array(X), -1), np.array(y)

def create_model():
    inputs = Input((IMG_SIZE, IMG_SIZE, 1))

    # Encoder
    x = conv_block(inputs, 32)
    skip1 = x
    x = MaxPooling2D()(x)

    x = conv_block(x, 64)
    skip2 = x
    x = MaxPooling2D()(x)

    x = conv_block(x, 128)
    skip3 = x
    x = MaxPooling2D()(x)

    x = conv_block(x, 256)
    skip4 = x
    x = MaxPooling2D()(x)

    # Bridge
    x = conv_block(x, 512)

    # Decoder with attention
    x = Conv2DTranspose(256, 3, strides=2, padding='same')(x)
    x = attention_gate(skip4, x, 256)
    x = concatenate([x, skip4])
    x = conv_block(x, 256)

    x = Conv2DTranspose(128, 3, strides=2, padding='same')(x)
    x = attention_gate(skip3, x, 128)
    x = concatenate([x, skip3])
    x = conv_block(x, 128)

    x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
    x = attention_gate(skip2, x, 64)
    x = concatenate([x, skip2])
    x = conv_block(x, 64)

    x = Conv2DTranspose(32, 3, strides=2, padding='same')(x)
    x = attention_gate(skip1, x, 32)
    x = concatenate([x, skip1])
    x = conv_block(x, 32)

    outputs = Conv2D(1, 1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNINGRATE),
        loss=dice_loss,
        metrics=['accuracy', dice_coeff, iou]
    )

    return model
# Out:
# 2025-02-13 17:28:06.222003: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-13 17:28:06.263774: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-13 17:28:06.926914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# GPU memory growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# Data preparation
case_ids = get_case_ids(INPUT_PATH)
aug_case_ids = get_case_ids(AUG_INPUT_PATH) if os.path.exists(AUG_INPUT_PATH) else []

train_ids, test_ids = train_test_split(case_ids, test_size=0.2, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

print(f"\nDataset Distribution:")
print(f"Train: {len(train_ids)}, Validation: {len(val_ids)}")
print(f"Test: {len(test_ids)}, Augmented: {len(aug_case_ids)}\n")

# Initialize generators
train_gen = DataGenerator(train_ids, aug_ids=aug_case_ids)
val_gen = DataGenerator(val_ids, shuffle=False)
test_gen = DataGenerator(test_ids, shuffle=False)

# Create and compile model
model = create_model()
print("\nModel Architecture Summary:")
model.summary()

# Training callbacks
callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_dice_coeff', mode='max',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=EARLYSTOPPING,
                 restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

# Model training
print("\nInitiating Model Training...")
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    workers=4,
    use_multiprocessing=True
)

# Model evaluation
print("\nEvaluating Model Performance...")
results = model.evaluate(test_gen)
print("\nTest Results:")
print(f"Loss: {results[0]:.4f}")
print(f"Accuracy: {results[1]:.4f}")
print(f"Dice Score: {results[2]:.4f}")
print(f"IoU: {results[3]:.4f}")
# Out:
# Dataset Distribution:
# Train: 160, Validation: 40
# Test: 50, Augmented: 63
# 2025-02-13 17:28:07.895656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14400 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:19:00.0, compute capability: 8.6
# Model Architecture Summary:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  288         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   18432       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73728       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 512)    1179648     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 512)   2048        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  1179904    ['activation_4[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 256)  65792       ['conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  65792       ['activation_3[0][0]']
#
#  add (Add)                      (None, 14, 14, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 256)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 1)    257         ['activation_5[0][0]']
#
#  multiply (Multiply)            (None, 14, 14, 256)  0           ['activation_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 512)  0           ['multiply[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 256)  1179648     ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_6[0][0]']
#  spose)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  16512       ['conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  16512       ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 1)    129         ['activation_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 128)  0           ['activation_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 256)  0           ['multiply_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  294912      ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_8[0][0]']
#  spose)
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   4160        ['conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   4160        ['activation_1[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 1)    65          ['activation_9[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 64)   0           ['activation_1[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 128)  0           ['multiply_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   73728       ['concatenate_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_10[0][0]']
#  spose)                         )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  1056        ['conv2d_transpose_3[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 32  1056        ['activation[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_17[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 32  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  33          ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['activation[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 64  0           ['multiply_3[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 32  18432       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_20[0][0]']
#  rmalization)                   )
#
#  activation_12 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  33          ['activation_12[0][0]']
#
# ==================================================================================================
# Total params: 4,882,373
# Trainable params: 4,879,429
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
#
# Initiating Model Training...
# Epoch 1/100
# 2025-02-13 17:28:08.876810: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-13 17:28:13.389052: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-02-13 17:28:20.294751: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.87GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.658053: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x46d7f0c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-13 17:28:20.658079: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2025-02-13 17:28:20.661782: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-13 17:28:20.791638: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-02-13 17:28:20.977703: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977767: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977784: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977800: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977814: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977829: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977843: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977857: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-02-13 17:28:20.977871: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 55/55 [==============================] - ETA: 0s - loss: 1.4490 - accuracy: 0.9043 - dice_coeff: 0.0143 - iou: 0.0072
# 2025-02-13 17:38:54.495657: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_dice_coeff improved from -inf to 0.00817, saving model to best_model.h5
# 55/55 [==============================] - 668s 12s/step - loss: 1.4490 - accuracy: 0.9043 - dice_coeff: 0.0143 - iou: 0.0072 - val_loss: 1.3992 - val_accuracy: 0.9960 - val_dice_coeff: 0.0082 - val_iou: 0.0041 - lr: 0.0010
# Epoch 2/100
# 55/55 [==============================] - ETA: 0s - loss: 1.2022 - accuracy: 0.9928 - dice_coeff: 0.0224 - iou: 0.0114
# Epoch 2: val_dice_coeff did not improve from 0.00817
# 55/55 [==============================] - 295s 5s/step - loss: 1.2022 - accuracy: 0.9928 - dice_coeff: 0.0224 - iou: 0.0114 - val_loss: 1.3311 - val_accuracy: 0.9961 - val_dice_coeff: 0.0042 - val_iou: 0.0021 - lr: 0.0010
# Epoch 3/100
# 55/55 [==============================] - ETA: 0s - loss: 1.0959 - accuracy: 0.9930 - dice_coeff: 0.0466 - iou: 0.0240
# Epoch 3: val_dice_coeff did not improve from 0.00817
# 55/55 [==============================] - 128s 2s/step - loss: 1.0959 - accuracy: 0.9930 - dice_coeff: 0.0466 - iou: 0.0240 - val_loss: 1.2257 - val_accuracy: 0.9961 - val_dice_coeff: 0.0046 - val_iou: 0.0023 - lr: 0.0010
# Epoch 4/100
# 43/55 [======================>.......] - ETA: 43s - loss: 1.0198 - accuracy: 0.9925 - dice_coeff: 0.0745 - iou: 0.0393
# 2025-02-13 17:49:03.850132: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 55/55 [==============================] - ETA: 0s - loss: 1.0088 - accuracy: 0.9925 - dice_coeff: 0.0802 - iou: 0.0425
# Epoch 4: val_dice_coeff did not improve from 0.00817
# 55/55 [==============================] - 233s 4s/step - loss: 1.0088 - accuracy: 0.9925 - dice_coeff: 0.0802 - iou: 0.0425 - val_loss: 1.1603 - val_accuracy: 0.9962 - val_dice_coeff: 0.0076 - val_iou: 0.0038 - lr: 0.0010
# Epoch 5/100
# 55/55 [==============================] - ETA: 0s - loss: 0.8915 - accuracy: 0.9928 - dice_coeff: 0.1585 - iou: 0.0881
# Epoch 5: val_dice_coeff improved from 0.00817 to 0.00982, saving model to best_model.h5
# 55/55 [==============================] - 141s 3s/step - loss: 0.8915 - accuracy: 0.9928 - dice_coeff: 0.1585 - iou: 0.0881 - val_loss: 1.0570 - val_accuracy: 0.9963 - val_dice_coeff: 0.0098 - val_iou: 0.0049 - lr: 0.0010
# Epoch 6/100
# 55/55 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.9952 - dice_coeff: 0.3006 - iou: 0.1832
# Epoch 6: val_dice_coeff improved from 0.00982 to 0.05923, saving model to best_model.h5
# 55/55 [==============================] - 60s 1s/step - loss: 0.7219 - accuracy: 0.9952 - dice_coeff: 0.3006 - iou: 0.1832 - val_loss: 0.9710 - val_accuracy: 0.9966 - val_dice_coeff: 0.0592 - val_iou: 0.0309 - lr: 0.0010
# Epoch 7/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.9958 - dice_coeff: 0.4552 - iou: 0.3038
# Epoch 7: val_dice_coeff improved from 0.05923 to 0.26996, saving model to best_model.h5
# 55/55 [==============================] - 55s 986ms/step - loss: 0.5563 - accuracy: 0.9958 - dice_coeff: 0.4552 - iou: 0.3038 - val_loss: 0.7537 - val_accuracy: 0.9965 - val_dice_coeff: 0.2700 - val_iou: 0.1617 - lr: 0.0010
# Epoch 8/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.9959 - dice_coeff: 0.5198 - iou: 0.3643
# Epoch 8: val_dice_coeff improved from 0.26996 to 0.37754, saving model to best_model.h5
# 55/55 [==============================] - 107s 2s/step - loss: 0.4935 - accuracy: 0.9959 - dice_coeff: 0.5198 - iou: 0.3643 - val_loss: 0.6453 - val_accuracy: 0.9976 - val_dice_coeff: 0.3775 - val_iou: 0.2439 - lr: 0.0010
# Epoch 9/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4066 - accuracy: 0.9966 - dice_coeff: 0.6080 - iou: 0.4489
# Epoch 9: val_dice_coeff improved from 0.37754 to 0.49841, saving model to best_model.h5
# 55/55 [==============================] - 140s 3s/step - loss: 0.4066 - accuracy: 0.9966 - dice_coeff: 0.6080 - iou: 0.4489 - val_loss: 0.5219 - val_accuracy: 0.9976 - val_dice_coeff: 0.4984 - val_iou: 0.3472 - lr: 0.0010
# Epoch 10/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.9967 - dice_coeff: 0.6534 - iou: 0.4946
# Epoch 10: val_dice_coeff improved from 0.49841 to 0.56508, saving model to best_model.h5
# 55/55 [==============================] - 55s 984ms/step - loss: 0.3622 - accuracy: 0.9967 - dice_coeff: 0.6534 - iou: 0.4946 - val_loss: 0.4534 - val_accuracy: 0.9978 - val_dice_coeff: 0.5651 - val_iou: 0.4111 - lr: 0.0010
# Epoch 11/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3539 - accuracy: 0.9968 - dice_coeff: 0.6609 - iou: 0.5043
# Epoch 11: val_dice_coeff did not improve from 0.56508
# 55/55 [==============================] - 52s 927ms/step - loss: 0.3539 - accuracy: 0.9968 - dice_coeff: 0.6609 - iou: 0.5043 - val_loss: 0.5659 - val_accuracy: 0.9972 - val_dice_coeff: 0.4597 - val_iou: 0.3183 - lr: 0.0010
# Epoch 12/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.9969 - dice_coeff: 0.6682 - iou: 0.5146
# Epoch 12: val_dice_coeff improved from 0.56508 to 0.64259, saving model to best_model.h5
# 55/55 [==============================] - 55s 991ms/step - loss: 0.3499 - accuracy: 0.9969 - dice_coeff: 0.6682 - iou: 0.5146 - val_loss: 0.3759 - val_accuracy: 0.9979 - val_dice_coeff: 0.6426 - val_iou: 0.4931 - lr: 0.0010
# Epoch 13/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.9967 - dice_coeff: 0.6599 - iou: 0.5032
# Epoch 13: val_dice_coeff did not improve from 0.64259
# 55/55 [==============================] - 46s 819ms/step - loss: 0.3572 - accuracy: 0.9967 - dice_coeff: 0.6599 - iou: 0.5032 - val_loss: 0.4445 - val_accuracy: 0.9976 - val_dice_coeff: 0.5749 - val_iou: 0.4263 - lr: 0.0010
# Epoch 14/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.9967 - dice_coeff: 0.6709 - iou: 0.5125
# Epoch 14: val_dice_coeff did not improve from 0.64259
# 55/55 [==============================] - 71s 1s/step - loss: 0.3492 - accuracy: 0.9967 - dice_coeff: 0.6709 - iou: 0.5125 - val_loss: 0.3778 - val_accuracy: 0.9980 - val_dice_coeff: 0.6417 - val_iou: 0.4951 - lr: 0.0010
# Epoch 15/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.9971 - dice_coeff: 0.6913 - iou: 0.5404
# Epoch 15: val_dice_coeff did not improve from 0.64259
# 55/55 [==============================] - 53s 949ms/step - loss: 0.3269 - accuracy: 0.9971 - dice_coeff: 0.6913 - iou: 0.5404 - val_loss: 0.4491 - val_accuracy: 0.9970 - val_dice_coeff: 0.5785 - val_iou: 0.4280 - lr: 0.0010
# Epoch 16/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9971 - dice_coeff: 0.7168 - iou: 0.5647
# Epoch 16: val_dice_coeff did not improve from 0.64259
# 55/55 [==============================] - 55s 978ms/step - loss: 0.3032 - accuracy: 0.9971 - dice_coeff: 0.7168 - iou: 0.5647 - val_loss: 0.4528 - val_accuracy: 0.9968 - val_dice_coeff: 0.5773 - val_iou: 0.4335 - lr: 0.0010
# Epoch 17/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.9972 - dice_coeff: 0.7143 - iou: 0.5683
# Epoch 17: val_dice_coeff did not improve from 0.64259
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 [==============================] - 96s 2s/step - loss: 0.3040 - accuracy: 0.9972 - dice_coeff: 0.7143 - iou: 0.5683 - val_loss: 0.4576 - val_accuracy: 0.9975 - val_dice_coeff: 0.5590 - val_iou: 0.4117 - lr: 0.0010
# Epoch 18/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9972 - dice_coeff: 0.7247 - iou: 0.5781
# Epoch 18: val_dice_coeff improved from 0.64259 to 0.71970, saving model to best_model.h5
# 55/55 [==============================] - 37s 653ms/step - loss: 0.2904 - accuracy: 0.9972 - dice_coeff: 0.7247 - iou: 0.5781 - val_loss: 0.2930 - val_accuracy: 0.9983 - val_dice_coeff: 0.7197 - val_iou: 0.5772 - lr: 5.0000e-04
# Epoch 19/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9973 - dice_coeff: 0.7372 - iou: 0.5931
# Epoch 19: val_dice_coeff did not improve from 0.71970
# 55/55 [==============================] - 65s 1s/step - loss: 0.2796 - accuracy: 0.9973 - dice_coeff: 0.7372 - iou: 0.5931 - val_loss: 0.3271 - val_accuracy: 0.9981 - val_dice_coeff: 0.6908 - val_iou: 0.5476 - lr: 5.0000e-04
# Epoch 20/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.9974 - dice_coeff: 0.7430 - iou: 0.6031
# Epoch 20: val_dice_coeff did not improve from 0.71970
# 55/55 [==============================] - 31s 556ms/step - loss: 0.2726 - accuracy: 0.9974 - dice_coeff: 0.7430 - iou: 0.6031 - val_loss: 0.2977 - val_accuracy: 0.9982 - val_dice_coeff: 0.7161 - val_iou: 0.5737 - lr: 5.0000e-04
# Epoch 21/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.9974 - dice_coeff: 0.7236 - iou: 0.5788
# Epoch 21: val_dice_coeff did not improve from 0.71970
# 55/55 [==============================] - 56s 1s/step - loss: 0.2892 - accuracy: 0.9974 - dice_coeff: 0.7236 - iou: 0.5788 - val_loss: 0.3436 - val_accuracy: 0.9979 - val_dice_coeff: 0.6710 - val_iou: 0.5222 - lr: 5.0000e-04
# Epoch 22/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9974 - dice_coeff: 0.7599 - iou: 0.6202
# Epoch 22: val_dice_coeff improved from 0.71970 to 0.73539, saving model to best_model.h5
# 55/55 [==============================] - 55s 995ms/step - loss: 0.2597 - accuracy: 0.9974 - dice_coeff: 0.7599 - iou: 0.6202 - val_loss: 0.2777 - val_accuracy: 0.9983 - val_dice_coeff: 0.7354 - val_iou: 0.5957 - lr: 5.0000e-04
# Epoch 23/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9974 - dice_coeff: 0.7510 - iou: 0.6102
# Epoch 23: val_dice_coeff improved from 0.73539 to 0.74737, saving model to best_model.h5
# 55/55 [==============================] - 51s 905ms/step - loss: 0.2648 - accuracy: 0.9974 - dice_coeff: 0.7510 - iou: 0.6102 - val_loss: 0.2644 - val_accuracy: 0.9984 - val_dice_coeff: 0.7474 - val_iou: 0.6109 - lr: 5.0000e-04
# Epoch 24/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9974 - dice_coeff: 0.7611 - iou: 0.6220
# Epoch 24: val_dice_coeff did not improve from 0.74737
# 55/55 [==============================] - 53s 944ms/step - loss: 0.2544 - accuracy: 0.9974 - dice_coeff: 0.7611 - iou: 0.6220 - val_loss: 0.3120 - val_accuracy: 0.9983 - val_dice_coeff: 0.7052 - val_iou: 0.5696 - lr: 5.0000e-04
# Epoch 25/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.9974 - dice_coeff: 0.7478 - iou: 0.6085
# Epoch 25: val_dice_coeff did not improve from 0.74737
# 55/55 [==============================] - 48s 862ms/step - loss: 0.2716 - accuracy: 0.9974 - dice_coeff: 0.7478 - iou: 0.6085 - val_loss: 0.2866 - val_accuracy: 0.9983 - val_dice_coeff: 0.7263 - val_iou: 0.5828 - lr: 5.0000e-04
# Epoch 26/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9975 - dice_coeff: 0.7684 - iou: 0.6325
# Epoch 26: val_dice_coeff did not improve from 0.74737
# 55/55 [==============================] - 71s 1s/step - loss: 0.2485 - accuracy: 0.9975 - dice_coeff: 0.7684 - iou: 0.6325 - val_loss: 0.3011 - val_accuracy: 0.9981 - val_dice_coeff: 0.7107 - val_iou: 0.5674 - lr: 5.0000e-04
# Epoch 27/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2509 - accuracy: 0.9976 - dice_coeff: 0.7678 - iou: 0.6295
# Epoch 27: val_dice_coeff improved from 0.74737 to 0.75169, saving model to best_model.h5
# 55/55 [==============================] - 44s 777ms/step - loss: 0.2509 - accuracy: 0.9976 - dice_coeff: 0.7678 - iou: 0.6295 - val_loss: 0.2633 - val_accuracy: 0.9985 - val_dice_coeff: 0.7517 - val_iou: 0.6175 - lr: 5.0000e-04
# Epoch 28/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.9975 - dice_coeff: 0.7645 - iou: 0.6297
# Epoch 28: val_dice_coeff did not improve from 0.75169
# 55/55 [==============================] - 45s 807ms/step - loss: 0.2500 - accuracy: 0.9975 - dice_coeff: 0.7645 - iou: 0.6297 - val_loss: 0.3314 - val_accuracy: 0.9980 - val_dice_coeff: 0.6825 - val_iou: 0.5352 - lr: 5.0000e-04
# Epoch 29/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9976 - dice_coeff: 0.7610 - iou: 0.6227
# Epoch 29: val_dice_coeff did not improve from 0.75169
# 55/55 [==============================] - 70s 1s/step - loss: 0.2537 - accuracy: 0.9976 - dice_coeff: 0.7610 - iou: 0.6227 - val_loss: 0.2975 - val_accuracy: 0.9982 - val_dice_coeff: 0.7152 - val_iou: 0.5747 - lr: 5.0000e-04
# Epoch 30/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.9975 - dice_coeff: 0.7465 - iou: 0.6069
# Epoch 30: val_dice_coeff did not improve from 0.75169
# 55/55 [==============================] - 32s 565ms/step - loss: 0.2695 - accuracy: 0.9975 - dice_coeff: 0.7465 - iou: 0.6069 - val_loss: 0.3291 - val_accuracy: 0.9980 - val_dice_coeff: 0.6861 - val_iou: 0.5400 - lr: 5.0000e-04
# Epoch 31/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9974 - dice_coeff: 0.7374 - iou: 0.5966
# Epoch 31: val_dice_coeff did not improve from 0.75169
# 55/55 [==============================] - 55s 979ms/step - loss: 0.2765 - accuracy: 0.9974 - dice_coeff: 0.7374 - iou: 0.5966 - val_loss: 0.2628 - val_accuracy: 0.9985 - val_dice_coeff: 0.7514 - val_iou: 0.6157 - lr: 5.0000e-04
# Epoch 32/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9976 - dice_coeff: 0.7536 - iou: 0.6179
# Epoch 32: val_dice_coeff improved from 0.75169 to 0.75467, saving model to best_model.h5
# 55/55 [==============================] - 33s 577ms/step - loss: 0.2614 - accuracy: 0.9976 - dice_coeff: 0.7536 - iou: 0.6179 - val_loss: 0.2567 - val_accuracy: 0.9985 - val_dice_coeff: 0.7547 - val_iou: 0.6190 - lr: 5.0000e-04
# Epoch 33/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9976 - dice_coeff: 0.7684 - iou: 0.6354
# Epoch 33: val_dice_coeff improved from 0.75467 to 0.75972, saving model to best_model.h5
# 55/55 [==============================] - 45s 811ms/step - loss: 0.2490 - accuracy: 0.9976 - dice_coeff: 0.7684 - iou: 0.6354 - val_loss: 0.2518 - val_accuracy: 0.9985 - val_dice_coeff: 0.7597 - val_iou: 0.6257 - lr: 5.0000e-04
# Epoch 34/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.9975 - dice_coeff: 0.7495 - iou: 0.6088
# Epoch 34: val_dice_coeff did not improve from 0.75972
# 55/55 [==============================] - 33s 585ms/step - loss: 0.2656 - accuracy: 0.9975 - dice_coeff: 0.7495 - iou: 0.6088 - val_loss: 0.2916 - val_accuracy: 0.9984 - val_dice_coeff: 0.7243 - val_iou: 0.5905 - lr: 5.0000e-04
# Epoch 35/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9976 - dice_coeff: 0.7783 - iou: 0.6435
# Epoch 35: val_dice_coeff did not improve from 0.75972
# 55/55 [==============================] - 33s 570ms/step - loss: 0.2372 - accuracy: 0.9976 - dice_coeff: 0.7783 - iou: 0.6435 - val_loss: 0.2658 - val_accuracy: 0.9983 - val_dice_coeff: 0.7463 - val_iou: 0.6078 - lr: 5.0000e-04
# Epoch 36/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9977 - dice_coeff: 0.7781 - iou: 0.6463
# Epoch 36: val_dice_coeff did not improve from 0.75972
# 55/55 [==============================] - 38s 658ms/step - loss: 0.2389 - accuracy: 0.9977 - dice_coeff: 0.7781 - iou: 0.6463 - val_loss: 0.4040 - val_accuracy: 0.9977 - val_dice_coeff: 0.6186 - val_iou: 0.4697 - lr: 5.0000e-04
# Epoch 37/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9976 - dice_coeff: 0.7699 - iou: 0.6329
# Epoch 37: val_dice_coeff did not improve from 0.75972
# 55/55 [==============================] - 44s 792ms/step - loss: 0.2466 - accuracy: 0.9976 - dice_coeff: 0.7699 - iou: 0.6329 - val_loss: 0.2716 - val_accuracy: 0.9984 - val_dice_coeff: 0.7414 - val_iou: 0.6045 - lr: 5.0000e-04
# Epoch 38/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9977 - dice_coeff: 0.7904 - iou: 0.6614
# Epoch 38: val_dice_coeff improved from 0.75972 to 0.76289, saving model to best_model.h5
# 55/55 [==============================] - 38s 669ms/step - loss: 0.2251 - accuracy: 0.9977 - dice_coeff: 0.7904 - iou: 0.6614 - val_loss: 0.2480 - val_accuracy: 0.9984 - val_dice_coeff: 0.7629 - val_iou: 0.6272 - lr: 5.0000e-04
# Epoch 39/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9978 - dice_coeff: 0.7935 - iou: 0.6650
# Epoch 39: val_dice_coeff improved from 0.76289 to 0.77001, saving model to best_model.h5
# 55/55 [==============================] - 78s 1s/step - loss: 0.2208 - accuracy: 0.9978 - dice_coeff: 0.7935 - iou: 0.6650 - val_loss: 0.2419 - val_accuracy: 0.9985 - val_dice_coeff: 0.7700 - val_iou: 0.6371 - lr: 5.0000e-04
# Epoch 40/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9977 - dice_coeff: 0.7804 - iou: 0.6520
# Epoch 40: val_dice_coeff did not improve from 0.77001
# 55/55 [==============================] - 37s 648ms/step - loss: 0.2337 - accuracy: 0.9977 - dice_coeff: 0.7804 - iou: 0.6520 - val_loss: 0.2686 - val_accuracy: 0.9983 - val_dice_coeff: 0.7443 - val_iou: 0.6067 - lr: 5.0000e-04
# Epoch 41/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9977 - dice_coeff: 0.7862 - iou: 0.6581
# Epoch 41: val_dice_coeff did not improve from 0.77001
# 55/55 [==============================] - 50s 899ms/step - loss: 0.2269 - accuracy: 0.9977 - dice_coeff: 0.7862 - iou: 0.6581 - val_loss: 0.2604 - val_accuracy: 0.9984 - val_dice_coeff: 0.7524 - val_iou: 0.6138 - lr: 5.0000e-04
# Epoch 42/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9978 - dice_coeff: 0.7955 - iou: 0.6696
# Epoch 42: val_dice_coeff did not improve from 0.77001
# 55/55 [==============================] - 55s 977ms/step - loss: 0.2188 - accuracy: 0.9978 - dice_coeff: 0.7955 - iou: 0.6696 - val_loss: 0.2638 - val_accuracy: 0.9985 - val_dice_coeff: 0.7501 - val_iou: 0.6197 - lr: 5.0000e-04
# Epoch 43/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.9977 - dice_coeff: 0.7794 - iou: 0.6465
# Epoch 43: val_dice_coeff improved from 0.77001 to 0.77177, saving model to best_model.h5
# 55/55 [==============================] - 37s 647ms/step - loss: 0.2363 - accuracy: 0.9977 - dice_coeff: 0.7794 - iou: 0.6465 - val_loss: 0.2418 - val_accuracy: 0.9986 - val_dice_coeff: 0.7718 - val_iou: 0.6412 - lr: 5.0000e-04
# Epoch 44/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9978 - dice_coeff: 0.8031 - iou: 0.6761
# Epoch 44: val_dice_coeff improved from 0.77177 to 0.77813, saving model to best_model.h5
# 55/55 [==============================] - 37s 649ms/step - loss: 0.2133 - accuracy: 0.9978 - dice_coeff: 0.8031 - iou: 0.6761 - val_loss: 0.2323 - val_accuracy: 0.9986 - val_dice_coeff: 0.7781 - val_iou: 0.6471 - lr: 5.0000e-04
# Epoch 45/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9979 - dice_coeff: 0.8074 - iou: 0.6833
# Epoch 45: val_dice_coeff did not improve from 0.77813
# 55/55 [==============================] - 37s 643ms/step - loss: 0.2084 - accuracy: 0.9979 - dice_coeff: 0.8074 - iou: 0.6833 - val_loss: 0.2440 - val_accuracy: 0.9985 - val_dice_coeff: 0.7667 - val_iou: 0.6339 - lr: 5.0000e-04
# Epoch 46/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9978 - dice_coeff: 0.7890 - iou: 0.6643
# Epoch 46: val_dice_coeff did not improve from 0.77813
# 55/55 [==============================] - 36s 648ms/step - loss: 0.2231 - accuracy: 0.9978 - dice_coeff: 0.7890 - iou: 0.6643 - val_loss: 0.2621 - val_accuracy: 0.9985 - val_dice_coeff: 0.7543 - val_iou: 0.6188 - lr: 5.0000e-04
# Epoch 47/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9978 - dice_coeff: 0.8075 - iou: 0.6837
# Epoch 47: val_dice_coeff did not improve from 0.77813
# 55/55 [==============================] - 37s 657ms/step - loss: 0.2059 - accuracy: 0.9978 - dice_coeff: 0.8075 - iou: 0.6837 - val_loss: 0.2324 - val_accuracy: 0.9985 - val_dice_coeff: 0.7781 - val_iou: 0.6477 - lr: 5.0000e-04
# Epoch 48/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9979 - dice_coeff: 0.8087 - iou: 0.6839
# Epoch 48: val_dice_coeff improved from 0.77813 to 0.78701, saving model to best_model.h5
# 55/55 [==============================] - 34s 591ms/step - loss: 0.2074 - accuracy: 0.9979 - dice_coeff: 0.8087 - iou: 0.6839 - val_loss: 0.2229 - val_accuracy: 0.9986 - val_dice_coeff: 0.7870 - val_iou: 0.6596 - lr: 5.0000e-04
# Epoch 49/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9979 - dice_coeff: 0.8061 - iou: 0.6825
# Epoch 49: val_dice_coeff did not improve from 0.78701
# 55/55 [==============================] - 43s 770ms/step - loss: 0.2044 - accuracy: 0.9979 - dice_coeff: 0.8061 - iou: 0.6825 - val_loss: 0.2266 - val_accuracy: 0.9986 - val_dice_coeff: 0.7837 - val_iou: 0.6543 - lr: 5.0000e-04
# Epoch 50/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9980 - dice_coeff: 0.8116 - iou: 0.6882
# Epoch 50: val_dice_coeff did not improve from 0.78701
# 55/55 [==============================] - 34s 588ms/step - loss: 0.2017 - accuracy: 0.9980 - dice_coeff: 0.8116 - iou: 0.6882 - val_loss: 0.2487 - val_accuracy: 0.9986 - val_dice_coeff: 0.7643 - val_iou: 0.6345 - lr: 5.0000e-04
# Epoch 51/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9979 - dice_coeff: 0.7980 - iou: 0.6726
# Epoch 51: val_dice_coeff did not improve from 0.78701
# 55/55 [==============================] - 33s 586ms/step - loss: 0.2164 - accuracy: 0.9979 - dice_coeff: 0.7980 - iou: 0.6726 - val_loss: 0.2528 - val_accuracy: 0.9985 - val_dice_coeff: 0.7598 - val_iou: 0.6271 - lr: 5.0000e-04
# Epoch 52/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9980 - dice_coeff: 0.8105 - iou: 0.6860
# Epoch 52: val_dice_coeff did not improve from 0.78701
# 55/55 [==============================] - 38s 661ms/step - loss: 0.2026 - accuracy: 0.9980 - dice_coeff: 0.8105 - iou: 0.6860 - val_loss: 0.2266 - val_accuracy: 0.9986 - val_dice_coeff: 0.7837 - val_iou: 0.6543 - lr: 5.0000e-04
# Epoch 53/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9979 - dice_coeff: 0.8045 - iou: 0.6794
# Epoch 53: val_dice_coeff improved from 0.78701 to 0.78886, saving model to best_model.h5
# 55/55 [==============================] - 34s 590ms/step - loss: 0.2088 - accuracy: 0.9979 - dice_coeff: 0.8045 - iou: 0.6794 - val_loss: 0.2223 - val_accuracy: 0.9986 - val_dice_coeff: 0.7889 - val_iou: 0.6608 - lr: 5.0000e-04
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9980 - dice_coeff: 0.8080 - iou: 0.6842
# Epoch 54: val_dice_coeff did not improve from 0.78886
# 55/55 [==============================] - 33s 581ms/step - loss: 0.2072 - accuracy: 0.9980 - dice_coeff: 0.8080 - iou: 0.6842 - val_loss: 0.2326 - val_accuracy: 0.9986 - val_dice_coeff: 0.7784 - val_iou: 0.6501 - lr: 5.0000e-04
# Epoch 55/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9980 - dice_coeff: 0.8124 - iou: 0.6901
# Epoch 55: val_dice_coeff did not improve from 0.78886
# 55/55 [==============================] - 38s 664ms/step - loss: 0.2015 - accuracy: 0.9980 - dice_coeff: 0.8124 - iou: 0.6901 - val_loss: 0.2479 - val_accuracy: 0.9985 - val_dice_coeff: 0.7641 - val_iou: 0.6324 - lr: 5.0000e-04
# Epoch 56/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9980 - dice_coeff: 0.8159 - iou: 0.6946
# Epoch 56: val_dice_coeff improved from 0.78886 to 0.79259, saving model to best_model.h5
# 55/55 [==============================] - 33s 584ms/step - loss: 0.1965 - accuracy: 0.9980 - dice_coeff: 0.8159 - iou: 0.6946 - val_loss: 0.2172 - val_accuracy: 0.9986 - val_dice_coeff: 0.7926 - val_iou: 0.6661 - lr: 5.0000e-04
# Epoch 57/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9980 - dice_coeff: 0.8184 - iou: 0.6978
# Epoch 57: val_dice_coeff did not improve from 0.79259
# 55/55 [==============================] - 46s 815ms/step - loss: 0.1939 - accuracy: 0.9980 - dice_coeff: 0.8184 - iou: 0.6978 - val_loss: 0.2333 - val_accuracy: 0.9986 - val_dice_coeff: 0.7783 - val_iou: 0.6494 - lr: 5.0000e-04
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9980 - dice_coeff: 0.8206 - iou: 0.7004
# Epoch 58: val_dice_coeff did not improve from 0.79259
# 55/55 [==============================] - 33s 586ms/step - loss: 0.1940 - accuracy: 0.9980 - dice_coeff: 0.8206 - iou: 0.7004 - val_loss: 0.2259 - val_accuracy: 0.9986 - val_dice_coeff: 0.7851 - val_iou: 0.6566 - lr: 5.0000e-04
# Epoch 59/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9981 - dice_coeff: 0.8280 - iou: 0.7124
# Epoch 59: val_dice_coeff did not improve from 0.79259
# 55/55 [==============================] - 60s 1s/step - loss: 0.1841 - accuracy: 0.9981 - dice_coeff: 0.8280 - iou: 0.7124 - val_loss: 0.2452 - val_accuracy: 0.9986 - val_dice_coeff: 0.7674 - val_iou: 0.6370 - lr: 5.0000e-04
# Epoch 60/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9980 - dice_coeff: 0.8060 - iou: 0.6825
# Epoch 60: val_dice_coeff did not improve from 0.79259
# 55/55 [==============================] - 32s 564ms/step - loss: 0.2084 - accuracy: 0.9980 - dice_coeff: 0.8060 - iou: 0.6825 - val_loss: 0.2777 - val_accuracy: 0.9984 - val_dice_coeff: 0.7382 - val_iou: 0.6053 - lr: 5.0000e-04
# Epoch 61/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9979 - dice_coeff: 0.8066 - iou: 0.6842
# Epoch 61: val_dice_coeff did not improve from 0.79259
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 [==============================] - 37s 662ms/step - loss: 0.2082 - accuracy: 0.9979 - dice_coeff: 0.8066 - iou: 0.6842 - val_loss: 0.2410 - val_accuracy: 0.9984 - val_dice_coeff: 0.7713 - val_iou: 0.6365 - lr: 5.0000e-04
# Epoch 62/100
# ...
# Epoch 65/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9981 - dice_coeff: 0.8211 - iou: 0.7054
# Epoch 65: val_dice_coeff did not improve from 0.79633
# 55/55 [==============================] - 33s 566ms/step - loss: 0.1900 - accuracy: 0.9981 - dice_coeff: 0.8211 - iou: 0.7054 - val_loss: 0.2157 - val_accuracy: 0.9987 - val_dice_coeff: 0.7943 - val_iou: 0.6694 - lr: 2.5000e-04
# Epoch 66/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9982 - dice_coeff: 0.8280 - iou: 0.7128
# Epoch 66: val_dice_coeff did not improve from 0.79633
# 55/55 [==============================] - 38s 653ms/step - loss: 0.1832 - accuracy: 0.9982 - dice_coeff: 0.8280 - iou: 0.7128 - val_loss: 0.2176 - val_accuracy: 0.9986 - val_dice_coeff: 0.7922 - val_iou: 0.6661 - lr: 2.5000e-04
# Epoch 67/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9982 - dice_coeff: 0.8340 - iou: 0.7203
# Epoch 67: val_dice_coeff improved from 0.79633 to 0.80119, saving model to best_model.h5
# 55/55 [==============================] - 36s 635ms/step - loss: 0.1789 - accuracy: 0.9982 - dice_coeff: 0.8340 - iou: 0.7203 - val_loss: 0.2078 - val_accuracy: 0.9987 - val_dice_coeff: 0.8012 - val_iou: 0.6777 - lr: 2.5000e-04
# Epoch 68/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9982 - dice_coeff: 0.8304 - iou: 0.7152
# Epoch 68: val_dice_coeff did not improve from 0.80119
# 55/55 [==============================] - 53s 956ms/step - loss: 0.1802 - accuracy: 0.9982 - dice_coeff: 0.8304 - iou: 0.7152 - val_loss: 0.2383 - val_accuracy: 0.9986 - val_dice_coeff: 0.7743 - val_iou: 0.6438 - lr: 2.5000e-04
# Epoch 69/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1848 - accuracy: 0.9981 - dice_coeff: 0.8289 - iou: 0.7133
# Epoch 69: val_dice_coeff improved from 0.80119 to 0.80341, saving model to best_model.h5
# 55/55 [==============================] - 35s 604ms/step - loss: 0.1848 - accuracy: 0.9981 - dice_coeff: 0.8289 - iou: 0.7133 - val_loss: 0.2060 - val_accuracy: 0.9987 - val_dice_coeff: 0.8034 - val_iou: 0.6806 - lr: 2.5000e-04
# Epoch 70/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9982 - dice_coeff: 0.8354 - iou: 0.7209
# Epoch 70: val_dice_coeff did not improve from 0.80341
# 55/55 [==============================] - 38s 656ms/step - loss: 0.1773 - accuracy: 0.9982 - dice_coeff: 0.8354 - iou: 0.7209 - val_loss: 0.2178 - val_accuracy: 0.9987 - val_dice_coeff: 0.7927 - val_iou: 0.6666 - lr: 2.5000e-04
# Epoch 71/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9982 - dice_coeff: 0.8323 - iou: 0.7180
# Epoch 71: val_dice_coeff did not improve from 0.80341
# 55/55 [==============================] - 33s 569ms/step - loss: 0.1777 - accuracy: 0.9982 - dice_coeff: 0.8323 - iou: 0.7180 - val_loss: 0.2117 - val_accuracy: 0.9987 - val_dice_coeff: 0.7981 - val_iou: 0.6749 - lr: 2.5000e-04
# Epoch 72/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9982 - dice_coeff: 0.8350 - iou: 0.7207
# Epoch 72: val_dice_coeff did not improve from 0.80341
# 55/55 [==============================] - 38s 656ms/step - loss: 0.1774 - accuracy: 0.9982 - dice_coeff: 0.8350 - iou: 0.7207 - val_loss: 0.2305 - val_accuracy: 0.9986 - val_dice_coeff: 0.7796 - val_iou: 0.6510 - lr: 2.5000e-04
# Epoch 73/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9982 - dice_coeff: 0.8405 - iou: 0.7290
# Epoch 73: val_dice_coeff did not improve from 0.80341
# 55/55 [==============================] - 45s 795ms/step - loss: 0.1717 - accuracy: 0.9982 - dice_coeff: 0.8405 - iou: 0.7290 - val_loss: 0.2189 - val_accuracy: 0.9987 - val_dice_coeff: 0.7922 - val_iou: 0.6667 - lr: 2.5000e-04
# Epoch 74/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9982 - dice_coeff: 0.8431 - iou: 0.7333
# Epoch 74: val_dice_coeff improved from 0.80341 to 0.80447, saving model to best_model.h5
# 55/55 [==============================] - 34s 597ms/step - loss: 0.1698 - accuracy: 0.9982 - dice_coeff: 0.8431 - iou: 0.7333 - val_loss: 0.2053 - val_accuracy: 0.9987 - val_dice_coeff: 0.8045 - val_iou: 0.6819 - lr: 2.5000e-04
# Epoch 75/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9982 - dice_coeff: 0.8434 - iou: 0.7332
# Epoch 75: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 61s 1s/step - loss: 0.1671 - accuracy: 0.9982 - dice_coeff: 0.8434 - iou: 0.7332 - val_loss: 0.2105 - val_accuracy: 0.9987 - val_dice_coeff: 0.7998 - val_iou: 0.6767 - lr: 2.5000e-04
# Epoch 76/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9983 - dice_coeff: 0.8400 - iou: 0.7285
# Epoch 76: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 33s 579ms/step - loss: 0.1703 - accuracy: 0.9983 - dice_coeff: 0.8400 - iou: 0.7285 - val_loss: 0.2117 - val_accuracy: 0.9987 - val_dice_coeff: 0.7980 - val_iou: 0.6730 - lr: 2.5000e-04
# Epoch 77/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9982 - dice_coeff: 0.8427 - iou: 0.7337
# Epoch 77: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 38s 650ms/step - loss: 0.1682 - accuracy: 0.9982 - dice_coeff: 0.8427 - iou: 0.7337 - val_loss: 0.2245 - val_accuracy: 0.9986 - val_dice_coeff: 0.7861 - val_iou: 0.6585 - lr: 2.5000e-04
# Epoch 78/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9982 - dice_coeff: 0.8410 - iou: 0.7291
# Epoch 78: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 36s 637ms/step - loss: 0.1698 - accuracy: 0.9982 - dice_coeff: 0.8410 - iou: 0.7291 - val_loss: 0.2148 - val_accuracy: 0.9987 - val_dice_coeff: 0.7951 - val_iou: 0.6694 - lr: 2.5000e-04
# Epoch 79/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9982 - dice_coeff: 0.8394 - iou: 0.7275
# Epoch 79: val_dice_coeff did not improve from 0.80447
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 [==============================] - 36s 643ms/step - loss: 0.1729 - accuracy: 0.9982 - dice_coeff: 0.8394 - iou: 0.7275 - val_loss: 0.2095 - val_accuracy: 0.9987 - val_dice_coeff: 0.8007 - val_iou: 0.6768 - lr: 2.5000e-04
# Epoch 80/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9983 - dice_coeff: 0.8398 - iou: 0.7300
# Epoch 80: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 52s 932ms/step - loss: 0.1719 - accuracy: 0.9983 - dice_coeff: 0.8398 - iou: 0.7300 - val_loss: 0.2062 - val_accuracy: 0.9987 - val_dice_coeff: 0.8035 - val_iou: 0.6810 - lr: 1.2500e-04
# Epoch 81/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9983 - dice_coeff: 0.8427 - iou: 0.7340
# Epoch 81: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 36s 637ms/step - loss: 0.1668 - accuracy: 0.9983 - dice_coeff: 0.8427 - iou: 0.7340 - val_loss: 0.2077 - val_accuracy: 0.9987 - val_dice_coeff: 0.8021 - val_iou: 0.6791 - lr: 1.2500e-04
# Epoch 82/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9983 - dice_coeff: 0.8486 - iou: 0.7404
# Epoch 82: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 33s 570ms/step - loss: 0.1634 - accuracy: 0.9983 - dice_coeff: 0.8486 - iou: 0.7404 - val_loss: 0.2060 - val_accuracy: 0.9987 - val_dice_coeff: 0.8039 - val_iou: 0.6818 - lr: 1.2500e-04
# Epoch 83/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9983 - dice_coeff: 0.8539 - iou: 0.7495
# Epoch 83: val_dice_coeff did not improve from 0.80447
# 55/55 [==============================] - 77s 1s/step - loss: 0.1587 - accuracy: 0.9983 - dice_coeff: 0.8539 - iou: 0.7495 - val_loss: 0.2056 - val_accuracy: 0.9987 - val_dice_coeff: 0.8042 - val_iou: 0.6824 - lr: 1.2500e-04
# Epoch 84/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9984 - dice_coeff: 0.8485 - iou: 0.7412
# Epoch 84: val_dice_coeff improved from 0.80447 to 0.80819, saving model to best_model.h5
# 55/55 [==============================] - 33s 578ms/step - loss: 0.1613 - accuracy: 0.9984 - dice_coeff: 0.8485 - iou: 0.7412 - val_loss: 0.2019 - val_accuracy: 0.9987 - val_dice_coeff: 0.8082 - val_iou: 0.6869 - lr: 1.2500e-04
# Epoch 85/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9983 - dice_coeff: 0.8539 - iou: 0.7501
# Epoch 85: val_dice_coeff did not improve from 0.80819
# 55/55 [==============================] - 50s 880ms/step - loss: 0.1580 - accuracy: 0.9983 - dice_coeff: 0.8539 - iou: 0.7501 - val_loss: 0.2078 - val_accuracy: 0.9987 - val_dice_coeff: 0.8020 - val_iou: 0.6798 - lr: 1.2500e-04
# Epoch 86/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9984 - dice_coeff: 0.8505 - iou: 0.7441
# Epoch 86: val_dice_coeff did not improve from 0.80819
# 55/55 [==============================] - 32s 563ms/step - loss: 0.1585 - accuracy: 0.9984 - dice_coeff: 0.8505 - iou: 0.7441 - val_loss: 0.2102 - val_accuracy: 0.9987 - val_dice_coeff: 0.8001 - val_iou: 0.6766 - lr: 1.2500e-04
# Epoch 87/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9984 - dice_coeff: 0.8550 - iou: 0.7496
# Epoch 87: val_dice_coeff did not improve from 0.80819
# 55/55 [==============================] - 47s 821ms/step - loss: 0.1566 - accuracy: 0.9984 - dice_coeff: 0.8550 - iou: 0.7496 - val_loss: 0.2050 - val_accuracy: 0.9987 - val_dice_coeff: 0.8047 - val_iou: 0.6832 - lr: 1.2500e-04
# Epoch 88/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9984 - dice_coeff: 0.8529 - iou: 0.7485
# Epoch 88: val_dice_coeff did not improve from 0.80819
# 55/55 [==============================] - 33s 580ms/step - loss: 0.1567 - accuracy: 0.9984 - dice_coeff: 0.8529 - iou: 0.7485 - val_loss: 0.2017 - val_accuracy: 0.9987 - val_dice_coeff: 0.8082 - val_iou: 0.6870 - lr: 1.2500e-04
# Epoch 89/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9984 - dice_coeff: 0.8491 - iou: 0.7440
# Epoch 89: val_dice_coeff did not improve from 0.80819
# 55/55 [==============================] - 33s 577ms/step - loss: 0.1625 - accuracy: 0.9984 - dice_coeff: 0.8491 - iou: 0.7440 - val_loss: 0.2076 - val_accuracy: 0.9987 - val_dice_coeff: 0.8024 - val_iou: 0.6795 - lr: 1.2500e-04
# Epoch 90/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9984 - dice_coeff: 0.8492 - iou: 0.7419
# Epoch 90: val_dice_coeff improved from 0.80819 to 0.80823, saving model to best_model.h5
# 55/55 [==============================] - 34s 596ms/step - loss: 0.1619 - accuracy: 0.9984 - dice_coeff: 0.8492 - iou: 0.7419 - val_loss: 0.2016 - val_accuracy: 0.9988 - val_dice_coeff: 0.8082 - val_iou: 0.6880 - lr: 1.2500e-04
# Epoch 91/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9984 - dice_coeff: 0.8563 - iou: 0.7530
# Epoch 91: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 33s 579ms/step - loss: 0.1556 - accuracy: 0.9984 - dice_coeff: 0.8563 - iou: 0.7530 - val_loss: 0.2098 - val_accuracy: 0.9987 - val_dice_coeff: 0.8004 - val_iou: 0.6774 - lr: 1.2500e-04
# Epoch 92/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9984 - dice_coeff: 0.8536 - iou: 0.7494
# Epoch 92: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 37s 651ms/step - loss: 0.1564 - accuracy: 0.9984 - dice_coeff: 0.8536 - iou: 0.7494 - val_loss: 0.2071 - val_accuracy: 0.9987 - val_dice_coeff: 0.8031 - val_iou: 0.6816 - lr: 1.2500e-04
# Epoch 93/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9984 - dice_coeff: 0.8596 - iou: 0.7576
# Epoch 93: val_dice_coeff did not improve from 0.80823
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 55/55 [==============================] - 37s 640ms/step - loss: 0.1515 - accuracy: 0.9984 - dice_coeff: 0.8596 - iou: 0.7576 - val_loss: 0.2086 - val_accuracy: 0.9987 - val_dice_coeff: 0.8013 - val_iou: 0.6783 - lr: 1.2500e-04
# Epoch 94/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9984 - dice_coeff: 0.8569 - iou: 0.7530
# Epoch 94: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 36s 634ms/step - loss: 0.1535 - accuracy: 0.9984 - dice_coeff: 0.8569 - iou: 0.7530 - val_loss: 0.2063 - val_accuracy: 0.9987 - val_dice_coeff: 0.8036 - val_iou: 0.6814 - lr: 6.2500e-05
# Epoch 95/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9984 - dice_coeff: 0.8568 - iou: 0.7541
# Epoch 95: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 46s 810ms/step - loss: 0.1534 - accuracy: 0.9984 - dice_coeff: 0.8568 - iou: 0.7541 - val_loss: 0.2059 - val_accuracy: 0.9987 - val_dice_coeff: 0.8040 - val_iou: 0.6826 - lr: 6.2500e-05
# Epoch 96/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9984 - dice_coeff: 0.8559 - iou: 0.7512
# Epoch 96: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 34s 587ms/step - loss: 0.1545 - accuracy: 0.9984 - dice_coeff: 0.8559 - iou: 0.7512 - val_loss: 0.2030 - val_accuracy: 0.9987 - val_dice_coeff: 0.8070 - val_iou: 0.6856 - lr: 6.2500e-05
# Epoch 97/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9984 - dice_coeff: 0.8621 - iou: 0.7614
# Epoch 97: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 37s 657ms/step - loss: 0.1495 - accuracy: 0.9984 - dice_coeff: 0.8621 - iou: 0.7614 - val_loss: 0.2033 - val_accuracy: 0.9987 - val_dice_coeff: 0.8066 - val_iou: 0.6854 - lr: 6.2500e-05
# Epoch 98/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9984 - dice_coeff: 0.8626 - iou: 0.7618
# Epoch 98: val_dice_coeff did not improve from 0.80823
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 55/55 [==============================] - 37s 637ms/step - loss: 0.1496 - accuracy: 0.9984 - dice_coeff: 0.8626 - iou: 0.7618 - val_loss: 0.2053 - val_accuracy: 0.9987 - val_dice_coeff: 0.8046 - val_iou: 0.6833 - lr: 6.2500e-05
# Epoch 99/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9984 - dice_coeff: 0.8595 - iou: 0.7576
# Epoch 99: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 48s 851ms/step - loss: 0.1519 - accuracy: 0.9984 - dice_coeff: 0.8595 - iou: 0.7576 - val_loss: 0.2028 - val_accuracy: 0.9987 - val_dice_coeff: 0.8070 - val_iou: 0.6862 - lr: 3.1250e-05
# Epoch 100/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9984 - dice_coeff: 0.8569 - iou: 0.7532
# Epoch 100: val_dice_coeff did not improve from 0.80823
# 55/55 [==============================] - 37s 644ms/step - loss: 0.1524 - accuracy: 0.9984 - dice_coeff: 0.8569 - iou: 0.7532 - val_loss: 0.2044 - val_accuracy: 0.9987 - val_dice_coeff: 0.8056 - val_iou: 0.6844 - lr: 3.1250e-05
#
# Evaluating Model Performance...
# 2025-02-13 19:04:44.114663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 13s 1s/step - loss: 0.2896 - accuracy: 0.9986 - dice_coeff: 0.7279 - iou: 0.5846
#
# Test Results:
# Loss: 0.2896
# Accuracy: 0.9986
# Dice Score: 0.7279
# IoU: 0.5846

# %%
def plot_training_metrics(history):
    """
    Visualize training and validation metrics over epochs
    """
    metrics = ['loss', 'dice_coeff', 'iou', 'accuracy']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training Metrics Over Epochs', fontsize=16)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        ax.plot(history.history[metric], label=f'Training {metric}')
        ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        ax.set_title(f'{metric.replace("_", " ").title()} vs Epochs')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.replace("_", " ").title())
        ax.legend(loc='best')
        ax.grid(True)

    plt.tight_layout()
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'training_metrics_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def visualize_augmented_samples(train_gen, num_samples=3):
    plt.figure(figsize=(15, 10))

    for batch_x, batch_y in train_gen:
        aug_images = batch_x
        aug_masks = batch_y
        break

    for idx in range(min(num_samples, len(aug_images))):
        # Augmented Image
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(aug_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Augmented Image {idx+1}')
        plt.axis('off')

        # Corresponding Mask
        plt.subplot(2, num_samples, num_samples + idx + 1)
        plt.imshow(aug_masks[idx], cmap='gray')
        plt.title(f'Augmented Mask {idx+1}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'augmentation_samples_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()


def numpy_dice_coeff(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)

def numpy_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f)
    return (intersection + 0.1) / (union - intersection + 0.1)


def visualize_segmentation_results(model, test_gen, num_samples=3):
    for batch_x, batch_y in test_gen:
        test_images = batch_x
        true_masks = batch_y
        break

    predictions = model.predict(test_images)
    predictions = (predictions > 0.5).astype(np.float32)  # Change to float32 instead of uint8

    plt.figure(figsize=(15, 20))

    for idx in range(min(num_samples, len(test_images))):
        plt.subplot(num_samples, 2, 2*idx + 1)
        plt.imshow(test_images[idx, :, :, 0], cmap='gray')
        plt.title(f'Input DWI Image {idx+1}')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*idx + 2)
        plt.imshow(predictions[idx, :, :, 0], cmap='gray')
        dice_score = numpy_dice_coeff(true_masks[idx], predictions[idx, :, :, 0])
        iou_score = numpy_iou(true_masks[idx], predictions[idx, :, :, 0])
        plt.title(f'Predicted Segmentation {idx+1}\n' +
                 f'Dice: {dice_score:.4f}, IoU: {iou_score:.4f}')
        plt.axis('off')

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIRECTORY, f'segmentation_results_{timestamp}.png'),
                bbox_inches='tight', dpi=300)
    plt.close()

# %%
print("\nGenerating Training Metrics Visualization...")
plot_training_metrics(history)

print("Generating Augmentation Samples Visualization...")
visualize_augmented_samples(train_gen)

print("\nGenerating Segmentation Results Visualization...")
visualize_segmentation_results(model, test_gen)
# Out:
# Generating Training Metrics Visualization...
# Generating Augmentation Samples Visualization...
#
# Generating Segmentation Results Visualization...
# 10/10 [==============================] - 2s 86ms/step

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0009_0038.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0009_0038.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 1s 644ms/step
# Dice Score: 0.9766
# IoU Score: 0.9539

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0013_0045.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0013_0045.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Dice Score: 0.9578
# IoU Score: 0.9188

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0015_0041.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0015_0041.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Dice Score: 0.9754
# IoU Score: 0.9518

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0024_0039.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0024_0039.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Dice Score: 0.9108
# IoU Score: 0.8359

# %%
# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0031_0036.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0031_0036.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Dice Score: 0.8823
# IoU Score: 0.7892

# %%
import os
import cv2
import numpy as np

BASE_PATH = "/home/user/adithyaes/dataset/isles2022_png"
AUG_PATH = "/home/user/adithyaes/dataset/isles2022_png_aug"
INPUT_PATH = os.path.join(BASE_PATH, "input")
MASK_PATH = os.path.join(BASE_PATH, "mask")
IMG_SIZE = 112


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1, 1))









def load_and_preprocess(file_path, is_mask=False):
	img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
	img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
	if not is_mask:
		img = scaler.fit_transform(img.reshape(-1, 1)).reshape(img.shape)
	else:
		img = img / 255.0
	return img


# Load specific image
test_image_path = os.path.join(INPUT_PATH, "slice_sub-strokecase0036_0056.png")
test_mask_path = os.path.join(MASK_PATH, "slice_sub-strokecase0036_0056.png")

# Load and preprocess
test_image = load_and_preprocess(test_image_path)
test_image = np.expand_dims(test_image, axis=[0,-1])
test_mask = load_and_preprocess(test_mask_path, is_mask=True)

# Predict
prediction = model.predict(test_image)
prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]

# Calculate metrics
dice = numpy_dice_coeff(test_mask, prediction)
iou = numpy_iou(test_mask, prediction)

print(f"Dice Score: {dice:.4f}")
print(f"IoU Score: {iou:.4f}")

# Visualize
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(test_image[0,:,:,0], cmap='gray')
plt.title('Input Image')
plt.subplot(132)
plt.imshow(test_mask, cmap='gray')
plt.title('Ground Truth')
plt.subplot(133)
plt.imshow(prediction, cmap='gray')
plt.title(f'Prediction\nDice: {dice:.4f}, IoU: {iou:.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 43
#      40 test_mask = load_and_preprocess(test_mask_path, is_mask=True)
#      42 # Predict
# ---> 43 prediction = model.predict(test_image)
#      44 prediction = (prediction > 0.5).astype(np.float32)[0,:,:,0]
#      46 # Calculate metrics
#
# NameError: name 'model' is not defined
